# %% [markdown]
# ## Converting the zju datasets into sfm for gaussian splatting

# %%
# All imports here
import os
from parameter_reader import CameraParametersExtractor
from database import COLMAPDatabase, blob_to_array

# %% [markdown]
# Given:
# - intri.yml
# - extri.yml

# %%
# The File Struture Should Be 
'''
/path/to/your/
│
├── intri.yml
├── entri.yml
│
├── inputs/      # Base directory for all image groups
│   ├── camera_grp1/  # Images from camera group 1
│   │   ├── image1.jpg
│   │   ├── image2.jpg
│   │   └── ...
│   │
│   ├── camera_grp2/  # Images from camera group 2
│   │   ├── image1.jpg
│   │   ├── image2.jpg
│   │   └── ...
│   │
│   └── ...      # More groups as needed
|
├── images/      # Will be created by this code
│   ├── camera_grp1/  # Images from camera group 1
│   │   ├── image1.jpg
│   │   ├── image2.jpg
│   │   └── ...
│   │
│   ├── camera_grp2/  # Images from camera group 2
│   │   ├── image1.jpg
│   │   ├── image2.jpg
│   │   └── ...
│   │
│   └── ...      # More groups as needed
│
└── sparse/      # Will be created by this code 
    ├── cameras.txt 
    ├── images.txt
    ├── points3D.txt
    └── 0/
        ├── cameras.bin
        ├── images.bin
        └── points3D.bin

'''
# Out:
# '\n/path/to/your/\n│\n├── intri.yml\n├── entri.yml\n│\n├── inputs/      # Base directory for all image groups\n│   ├── camera_grp1/  # Images from camera group 1\n│   │   ├── image1.jpg\n│   │   ├── image2.jpg\n│   │   └── ...\n│   │\n│   ├── camera_grp2/  # Images from camera group 2\n│   │   ├── image1.jpg\n│   │   ├── image2.jpg\n│   │   └── ...\n│   │\n│   └── ...      # More groups as needed\n|\n├── images/      # Will be created by this code\n│   ├── camera_grp1/  # Images from camera group 1\n│   │   ├── image1.jpg\n│   │   ├── image2.jpg\n│   │   └── ...\n│   │\n│   ├── camera_grp2/  # Images from camera group 2\n│   │   ├── image1.jpg\n│   │   ├── image2.jpg\n│   │   └── ...\n│   │\n│   └── ...      # More groups as needed\n│\n└── sparse/      # Will be created by this code \n    ├── cameras.txt \n    ├── images.txt\n    ├── points3D.txt\n    └── 0/\n        ├── cameras.bin\n        ├── images.bin\n        └── points3D.bin\n\n'

# %% [markdown]
# #### Set Paths and create Directories

# %%
# Set the paths here
rootdir = "data/mocap_small"
sparsedir = f"{rootdir}/sparse"
imagedir = f"{rootdir}/inputs"
database_path = f"{rootdir}/database.db"
outputdir = f"{sparsedir}/0"
# Create folders and files here
# These are been created according to https://colmap.github.io/faq.html#reconstruct-sparse-dense-model-from-known-camera-poses
# Templates for all files are explained at https://colmap.github.io/format.html#output-format

def create_empty_file(filepath):
    with open(filepath, 'w') as file:
        pass  # No need to write anything, just creating the file

os.makedirs(outputdir, exist_ok=True)
create_empty_file(f"{sparsedir}/points3D.txt")

# %% [markdown]
# #### Run the feature Extractor

# %%
# Now we need need to run colmap feature extractor
command = f"\
    colmap feature_extractor \
    --database_path {rootdir}/database.db \
    --image_path {imagedir} \
    --SiftExtraction.use_gpu 0"
os.system(command)
# Out:
# WARNING: Your current options use the maximum number of threads on the machine to extract features. Exracting SIFT features on the CPU can consume a lot of RAM per thread for large images. Consider reducing the maximum image size and/or the first octave or manually limit the number of extraction threads. Ignore this warning, if your machine has sufficient memory for the current settings.
#
# ==============================================================================
# Feature extraction
# ==============================================================================
#
# Processed file [1/552]
#   Name:            00/000001.jpg
#   Dimensions:      1024 x 1024
#   Camera:          #2 - SIMPLE_RADIAL
#   Focal Length:    1228.80px
#   Features:        1463
# Processed file [2/552]
#   Name:            00/000000.jpg
#   Dimensions:      1024 x 1024
#   Camera:          #1 - SIMPLE_RADIAL
#   Focal Length:    1228.80px
#   Features:        1426
# Processed file [3/552]
#   Name:            00/000005.jpg
#   Dimensions:      1024 x 1024
#   Camera:          #6 - SIMPLE_RADIAL
#   Focal Length:    1228.80px
#   Features:        1421
# Processed file [4/552]
#   Name:            00/000002.jpg
#   Dimensions:      1024 x 1024
#   Camera:          #3 - SIMPLE_RADIAL
#   Focal Length:    1228.80px
#   Features:        1428
# Processed file [5/552]
#   Name:            00/000004.jpg
#   Dimensions:      1024 x 1024
#   Camera:          #5 - SIMPLE_RADIAL
#   Focal Length:    1228.80px
#   Features:        1429
# Processed file [6/552]
#   Name:            00/000003.jpg
#   Dimensions:      1024 x 1024
#   Camera:          #4 - SIMPLE_RADIAL
#   Focal Length:    1228.80px
#   Features:        1454
# Processed file [7/552]
#   Name:            00/000006.jpg
#   Dimensions:      1024 x 1024
#   Camera:          #7 - SIMPLE_RADIAL
#   Focal Length:    1228.80px
#   Features:        1422
# Processed file [8/552]
#   Name:            00/000014.jpg
#   Dimensions:      1024 x 1024
#   Camera:          #15 - SIMPLE_RADIAL
#   Focal Length:    1228.80px
#   Features:        1462
# Processed file [9/552]
#   Name:            00/000015.jpg
#   Dimensions:      1024 x 1024
#   Camera:          #16 - SIMPLE_RADIAL
#   Focal Length:    1228.80px
#   Features:        1447
# Processed file [10/552]
#   Name:            00/000007.jpg
#   Dimensions:      1024 x 1024
#   Camera:          #8 - SIMPLE_RADIAL
#   Focal Length:    1228.80px
#   Features:        1437
# Processed file [11/552]
#   Name:            00/000011.jpg
#   Dimensions:      1024 x 1024
#   Camera:          #12 - SIMPLE_RADIAL
#   Focal Length:    1228.80px
#   Features:        1440
# Processed file [12/552]
#   Name:            00/000012.jpg
#   Dimensions:      1024 x 1024
#   Camera:          #13 - SIMPLE_RADIAL
#   Focal Length:    1228.80px
#   Features:        1425
# Processed file [13/552]
#   Name:            00/000008.jpg
#   Dimensions:      1024 x 1024
#   Camera:          #9 - SIMPLE_RADIAL
#   Focal Length:    1228.80px
#   Features:        1443
# Processed file [14/552]
#   Name:            00/000010.jpg
#   Dimensions:      1024 x 1024
#   Camera:          #11 - SIMPLE_RADIAL
#   Focal Length:    1228.80px
#   Features:        1424
# Processed file [15/552]
#   Name:            00/000013.jpg
#   Dimensions:      1024 x 1024
#   Camera:          #14 - SIMPLE_RADIAL
#   Focal Length:    1228.80px
#   Features:        1433
# Processed file [16/552]
#   Name:            00/000020.jpg
#   Dimensions:      1024 x 1024
#   Camera:          #21 - SIMPLE_RADIAL
#   Focal Length:    1228.80px
#   Features:        1462
# Processed file [17/552]
#   Name:            00/000019.jpg
#   Dimensions:      1024 x 1024
#   Camera:          #20 - SIMPLE_RADIAL
#   Focal Length:    1228.80px
#   Features:        1405
# Processed file [18/552]
#   Name:            01/000003.jpg
#   Dimensions:      1024 x 1024
#   Camera:          #28 - SIMPLE_RADIAL
#   Focal Length:    1228.80px
#   Features:        481
# Processed file [19/552]
#   Name:            00/000009.jpg
#   Dimensions:      1024 x 1024
#   Camera:          #10 - SIMPLE_RADIAL
#   Focal Length:    1228.80px
#   Features:        1428
# Processed file [20/552]
#   Name:            01/000002.jpg
#   Dimensions:      1024 x 1024
#   Camera:          #27 - SIMPLE_RADIAL
#   Focal Length:    1228.80px
#   Features:        494
# Processed file [21/552]
#   Name:            00/000016.jpg
#   Dimensions:      1024 x 1024
#   Camera:          #17 - SIMPLE_RADIAL
#   Focal Length:    1228.80px
#   Features:        1410
# Processed file [22/552]
#   Name:            01/000004.jpg
#   Dimensions:      1024 x 1024
#   Camera:          #29 - SIMPLE_RADIAL
#   Focal Length:    1228.80px
#   Features:        489
# Processed file [23/552]
#   Name:            00/000023.jpg
#   Dimensions:      1024 x 1024
#   Camera:          #24 - SIMPLE_RADIAL
#   Focal Length:    1228.80px
#   Features:        1470
# Processed file [24/552]
#   Name:            00/000022.jpg
#   Dimensions:      1024 x 1024
#   Camera:          #23 - SIMPLE_RADIAL
#   Focal Length:    1228.80px
#   Features:        1454
# Processed file [25/552]
#   Name:            01/000012.jpg
#   Dimensions:      1024 x 1024
#   Camera:          #37 - SIMPLE_RADIAL
#   Focal Length:    1228.80px
#   Features:        484
# Processed file [26/552]
#   Name:            01/000008.jpg
#   Dimensions:      1024 x 1024
#   Camera:          #33 - SIMPLE_RADIAL
#   Focal Length:    1228.80px
#   Features:        479
# Processed file [27/552]
#   Name:            00/000017.jpg
#   Dimensions:      1024 x 1024
#   Camera:          #18 - SIMPLE_RADIAL
#   Focal Length:    1228.80px
#   Features:        1443
# Processed file [28/552]
#   Name:            00/000018.jpg
#   Dimensions:      1024 x 1024
#   Camera:          #19 - SIMPLE_RADIAL
#   Focal Length:    1228.80px
#   Features:        1466
# Processed file [29/552]
#   Name:            01/000013.jpg
#   Dimensions:      1024 x 1024
#   Camera:          #38 - SIMPLE_RADIAL
#   Focal Length:    1228.80px
#   Features:        484
# Processed file [30/552]
#   Name:            01/000007.jpg
#   Dimensions:      1024 x 1024
#   Camera:          #32 - SIMPLE_RADIAL
#   Focal Length:    1228.80px
#   Features:        489
# Processed file [31/552]
#   Name:            01/000005.jpg
#   Dimensions:      1024 x 1024
#   Camera:          #30 - SIMPLE_RADIAL
#   Focal Length:    1228.80px
#   Features:        470
# Processed file [32/552]
#   Name:            01/000006.jpg
#   Dimensions:      1024 x 1024
#   Camera:          #31 - SIMPLE_RADIAL
#   Focal Length:    1228.80px
#   Features:        478
# Processed file [33/552]
#   Name:            01/000011.jpg
#   Dimensions:      1024 x 1024
#   Camera:          #36 - SIMPLE_RADIAL
#   Focal Length:    1228.80px
#   Features:        494
# Processed file [34/552]
#   Name:            00/000021.jpg
#   Dimensions:      1024 x 1024
#   Camera:          #22 - SIMPLE_RADIAL
#   Focal Length:    1228.80px
#   Features:        1457
# Processed file [35/552]
#   Name:            01/000000.jpg
#   Dimensions:      1024 x 1024
#   Camera:          #25 - SIMPLE_RADIAL
#   Focal Length:    1228.80px
#   Features:        500
# Processed file [36/552]
#   Name:            01/000009.jpg
#   Dimensions:      1024 x 1024
#   Camera:          #34 - SIMPLE_RADIAL
#   Focal Length:    1228.80px
#   Features:        489
# Processed file [37/552]
#   Name:            01/000010.jpg
#   Dimensions:      1024 x 1024
#   Camera:          #35 - SIMPLE_RADIAL
#   Focal Length:    1228.80px
#   Features:        500
# Processed file [38/552]
#   Name:            01/000014.jpg
#   Dimensions:      1024 x 1024
#   Camera:          #39 - SIMPLE_RADIAL
#   Focal Length:    1228.80px
#   Features:        487
# Processed file [39/552]
#   Name:            01/000015.jpg
#   Dimensions:      1024 x 1024
#   Camera:          #40 - SIMPLE_RADIAL
#   Focal Length:    1228.80px
#   Features:        495
# Processed file [40/552]
#   Name:            01/000001.jpg
#   Dimensions:      1024 x 1024
#   Camera:          #26 - SIMPLE_RADIAL
#   Focal Length:    1228.80px
#   Features:        495
# Processed file [41/552]
#   Name:            01/000019.jpg
#   Dimensions:      1024 x 1024
#   Camera:          #44 - SIMPLE_RADIAL
#   Focal Length:    1228.80px
#   Features:        497
# Processed file [42/552]
#   Name:            01/000018.jpg
#   Dimensions:      1024 x 1024
#   Camera:          #43 - SIMPLE_RADIAL
#   Focal Length:    1228.80px
#   Features:        492
# Processed file [43/552]
#   Name:            01/000020.jpg
#   Dimensions:      1024 x 1024
#   Camera:          #45 - SIMPLE_RADIAL
#   Focal Length:    1228.80px
#   Features:        477
# Processed file [44/552]
#   Name:            01/000016.jpg
#   Dimensions:      1024 x 1024
#   Camera:          #41 - SIMPLE_RADIAL
#   Focal Length:    1228.80px
#   Features:        486
# Processed file [45/552]
#   Name:            01/000022.jpg
#   Dimensions:      1024 x 1024
#   Camera:          #47 - SIMPLE_RADIAL
#   Focal Length:    1228.80px
#   Features:        483
# Processed file [46/552]
#   Name:            01/000017.jpg
#   Dimensions:      1024 x 1024
#   Camera:          #42 - SIMPLE_RADIAL
#   Focal Length:    1228.80px
#   Features:        498
# Processed file [47/552]
#   Name:            01/000021.jpg
#   Dimensions:      1024 x 1024
#   Camera:          #46 - SIMPLE_RADIAL
#   Focal Length:    1228.80px
#   Features:        485
# Processed file [48/552]
#   Name:            02/000003.jpg
#   Dimensions:      1024 x 1024
#   Camera:          #52 - SIMPLE_RADIAL
#   Focal Length:    1228.80px
#   Features:        685
# Processed file [49/552]
#   Name:            01/000023.jpg
#   Dimensions:      1024 x 1024
#   Camera:          #48 - SIMPLE_RADIAL
#   Focal Length:    1228.80px
#   Features:        496
# Processed file [50/552]
#   Name:            02/000000.jpg
#   Dimensions:      1024 x 1024
#   Camera:          #49 - SIMPLE_RADIAL
#   Focal Length:    1228.80px
#   Features:        687
# Processed file [51/552]
#   Name:            02/000002.jpg
#   Dimensions:      1024 x 1024
#   Camera:          #51 - SIMPLE_RADIAL
#   Focal Length:    1228.80px
#   Features:        698
# Processed file [52/552]
#   Name:            02/000009.jpg
#   Dimensions:      1024 x 1024
#   Camera:          #58 - SIMPLE_RADIAL
#   Focal Length:    1228.80px
#   Features:        700
# Processed file [53/552]
#   Name:            02/000001.jpg
#   Dimensions:      1024 x 1024
#   Camera:          #50 - SIMPLE_RADIAL
#   Focal Length:    1228.80px
#   Features:        688
# Processed file [54/552]
#   Name:            02/000005.jpg
#   Dimensions:      1024 x 1024
#   Camera:          #54 - SIMPLE_RADIAL
#   Focal Length:    1228.80px
#   Features:        672
# Processed file [55/552]
#   Name:            02/000006.jpg
#   Dimensions:      1024 x 1024
#   Camera:          #55 - SIMPLE_RADIAL
#   Focal Length:    1228.80px
#   Features:        683
# Processed file [56/552]
#   Name:            02/000007.jpg
#   Dimensions:      1024 x 1024
#   Camera:          #56 - SIMPLE_RADIAL
#   Focal Length:    1228.80px
#   Features:        692
# Processed file [57/552]
#   Name:            02/000004.jpg
#   Dimensions:      1024 x 1024
#   Camera:          #53 - SIMPLE_RADIAL
#   Focal Length:    1228.80px
#   Features:        694
# Processed file [58/552]
#   Name:            03/000002.jpg
#   Dimensions:      1024 x 1024
#   Camera:          #75 - SIMPLE_RADIAL
#   Focal Length:    1228.80px
#   Features:        403
# Processed file [59/552]
#   Name:            02/000008.jpg
#   Dimensions:      1024 x 1024
#   Camera:          #57 - SIMPLE_RADIAL
#   Focal Length:    1228.80px
#   Features:        690
# Processed file [60/552]
#   Name:            02/000014.jpg
#   Dimensions:      1024 x 1024
#   Camera:          #63 - SIMPLE_RADIAL
#   Focal Length:    1228.80px
#   Features:        674
# Processed file [61/552]
#   Name:            02/000012.jpg
#   Dimensions:      1024 x 1024
#   Camera:          #61 - SIMPLE_RADIAL
#   Focal Length:    1228.80px
#   Features:        679
# Processed file [62/552]
#   Name:            02/000018.jpg
#   Dimensions:      1024 x 1024
#   Camera:          #67 - SIMPLE_RADIAL
#   Focal Length:    1228.80px
#   Features:        691
# Processed file [63/552]
#   Name:            02/000011.jpg
#   Dimensions:      1024 x 1024
#   Camera:          #60 - SIMPLE_RADIAL
#   Focal Length:    1228.80px
#   Features:        681
# Processed file [64/552]
#   Name:            02/000023.jpg
#   Dimensions:      1024 x 1024
#   Camera:          #72 - SIMPLE_RADIAL
#   Focal Length:    1228.80px
#   Features:        690
# Processed file [65/552]
#   Name:            02/000010.jpg
#   Dimensions:      1024 x 1024
#   Camera:          #59 - SIMPLE_RADIAL
#   Focal Length:    1228.80px
#   Features:        665
# Processed file [66/552]
#   Name:            02/000015.jpg
#   Dimensions:      1024 x 1024
#   Camera:          #64 - SIMPLE_RADIAL
#   Focal Length:    1228.80px
#   Features:        671
# Processed file [67/552]
#   Name:            03/000001.jpg
#   Dimensions:      1024 x 1024
#   Camera:          #74 - SIMPLE_RADIAL
#   Focal Length:    1228.80px
#   Features:        379
# Processed file [68/552]
#   Name:            02/000022.jpg
#   Dimensions:      1024 x 1024
#   Camera:          #71 - SIMPLE_RADIAL
#   Focal Length:    1228.80px
#   Features:        683
# Processed file [69/552]
#   Name:            02/000017.jpg
#   Dimensions:      1024 x 1024
#   Camera:          #66 - SIMPLE_RADIAL
#   Focal Length:    1228.80px
#   Features:        688
# Processed file [70/552]
#   Name:            02/000013.jpg
#   Dimensions:      1024 x 1024
#   Camera:          #62 - SIMPLE_RADIAL
#   Focal Length:    1228.80px
#   Features:        681
# Processed file [71/552]
#   Name:            03/000000.jpg
#   Dimensions:      1024 x 1024
#   Camera:          #73 - SIMPLE_RADIAL
#   Focal Length:    1228.80px
#   Features:        387
# Processed file [72/552]
#   Name:            02/000021.jpg
#   Dimensions:      1024 x 1024
#   Camera:          #70 - SIMPLE_RADIAL
#   Focal Length:    1228.80px
#   Features:        679
# Processed file [73/552]
#   Name:            02/000016.jpg
#   Dimensions:      1024 x 1024
#   Camera:          #65 - SIMPLE_RADIAL
#   Focal Length:    1228.80px
#   Features:        670
# Processed file [74/552]
#   Name:            02/000019.jpg
#   Dimensions:      1024 x 1024
#   Camera:          #68 - SIMPLE_RADIAL
#   Focal Length:    1228.80px
#   Features:        686
# Processed file [75/552]
#   Name:            02/000020.jpg
#   Dimensions:      1024 x 1024
#   Camera:          #69 - SIMPLE_RADIAL
#   Focal Length:    1228.80px
#   Features:        696
# Processed file [76/552]
#   Name:            03/000006.jpg
#   Dimensions:      1024 x 1024
#   Camera:          #79 - SIMPLE_RADIAL
#   Focal Length:    1228.80px
#   Features:        375
# Processed file [77/552]
#   Name:            03/000007.jpg
#   Dimensions:      1024 x 1024
#   Camera:          #80 - SIMPLE_RADIAL
#   Focal Length:    1228.80px
#   Features:        389
# Processed file [78/552]
#   Name:            03/000005.jpg
#   Dimensions:      1024 x 1024
#   Camera:          #78 - SIMPLE_RADIAL
#   Focal Length:    1228.80px
#   Features:        408
# Processed file [79/552]
#   Name:            03/000003.jpg
#   Dimensions:      1024 x 1024
#   Camera:          #76 - SIMPLE_RADIAL
#   Focal Length:    1228.80px
#   Features:        402
# Processed file [80/552]
#   Name:            03/000004.jpg
#   Dimensions:      1024 x 1024
#   Camera:          #77 - SIMPLE_RADIAL
#   Focal Length:    1228.80px
#   Features:        398
# Processed file [81/552]
#   Name:            03/000008.jpg
#   Dimensions:      1024 x 1024
#   Camera:          #81 - SIMPLE_RADIAL
#   Focal Length:    1228.80px
#   Features:        401
# Processed file [82/552]
#   Name:            03/000009.jpg
#   Dimensions:      1024 x 1024
#   Camera:          #82 - SIMPLE_RADIAL
#   Focal Length:    1228.80px
#   Features:        398
# Processed file [83/552]
#   Name:            03/000011.jpg
#   Dimensions:      1024 x 1024
#   Camera:          #84 - SIMPLE_RADIAL
#   Focal Length:    1228.80px
#   Features:        402
# Processed file [84/552]
#   Name:            03/000010.jpg
#   Dimensions:      1024 x 1024
#   Camera:          #83 - SIMPLE_RADIAL
#   Focal Length:    1228.80px
#   Features:        411
# Processed file [85/552]
#   Name:            03/000013.jpg
#   Dimensions:      1024 x 1024
#   Camera:          #86 - SIMPLE_RADIAL
#   Focal Length:    1228.80px
#   Features:        406
# Processed file [86/552]
#   Name:            03/000012.jpg
#   Dimensions:      1024 x 1024
#   Camera:          #85 - SIMPLE_RADIAL
#   Focal Length:    1228.80px
#   Features:        403
# Processed file [87/552]
#   Name:            03/000014.jpg
#   Dimensions:      1024 x 1024
#   Camera:          #87 - SIMPLE_RADIAL
#   Focal Length:    1228.80px
#   Features:        393
# Processed file [88/552]
#   Name:            03/000015.jpg
#   Dimensions:      1024 x 1024
#   Camera:          #88 - SIMPLE_RADIAL
#   Focal Length:    1228.80px
#   Features:        386
# Processed file [89/552]
#   Name:            03/000019.jpg
#   Dimensions:      1024 x 1024
#   Camera:          #92 - SIMPLE_RADIAL
#   Focal Length:    1228.80px
#   Features:        381
# Processed file [90/552]
#   Name:            03/000016.jpg
#   Dimensions:      1024 x 1024
#   Camera:          #89 - SIMPLE_RADIAL
#   Focal Length:    1228.80px
#   Features:        389
# Processed file [91/552]
#   Name:            03/000020.jpg
#   Dimensions:      1024 x 1024
#   Camera:          #93 - SIMPLE_RADIAL
#   Focal Length:    1228.80px
#   Features:        394
# Processed file [92/552]
#   Name:            03/000021.jpg
#   Dimensions:      1024 x 1024
#   Camera:          #94 - SIMPLE_RADIAL
#   Focal Length:    1228.80px
#   Features:        384
# Processed file [93/552]
#   Name:            03/000018.jpg
#   Dimensions:      1024 x 1024
#   Camera:          #91 - SIMPLE_RADIAL
#   Focal Length:    1228.80px
#   Features:        371
# Processed file [94/552]
#   Name:            03/000017.jpg
#   Dimensions:      1024 x 1024
#   Camera:          #90 - SIMPLE_RADIAL
#   Focal Length:    1228.80px
#   Features:        421
# Processed file [95/552]
#   Name:            03/000022.jpg
#   Dimensions:      1024 x 1024
#   Camera:          #95 - SIMPLE_RADIAL
#   Focal Length:    1228.80px
#   Features:        404
# Processed file [96/552]
#   Name:            04/000011.jpg
#   Dimensions:      1024 x 1024
#   Camera:          #108 - SIMPLE_RADIAL
#   Focal Length:    1228.80px
#   Features:        1311
# Processed file [97/552]
#   Name:            04/000006.jpg
#   Dimensions:      1024 x 1024
#   Camera:          #103 - SIMPLE_RADIAL
#   Focal Length:    1228.80px
#   Features:        1295
# Processed file [98/552]
#   Name:            04/000008.jpg
#   Dimensions:      1024 x 1024
#   Camera:          #105 - SIMPLE_RADIAL
#   Focal Length:    1228.80px
#   Features:        1276
# Processed file [99/552]
#   Name:            04/000000.jpg
#   Dimensions:      1024 x 1024
#   Camera:          #97 - SIMPLE_RADIAL
#   Focal Length:    1228.80px
#   Features:        1273
# Processed file [100/552]
#   Name:            04/000005.jpg
#   Dimensions:      1024 x 1024
#   Camera:          #102 - SIMPLE_RADIAL
#   Focal Length:    1228.80px
#   Features:        1290
# Processed file [101/552]
#   Name:            03/000023.jpg
#   Dimensions:      1024 x 1024
#   Camera:          #96 - SIMPLE_RADIAL
#   Focal Length:    1228.80px
#   Features:        398
# Processed file [102/552]
#   Name:            04/000007.jpg
#   Dimensions:      1024 x 1024
#   Camera:          #104 - SIMPLE_RADIAL
#   Focal Length:    1228.80px
#   Features:        1292
# Processed file [103/552]
#   Name:            04/000003.jpg
#   Dimensions:      1024 x 1024
#   Camera:          #100 - SIMPLE_RADIAL
#   Focal Length:    1228.80px
#   Features:        1297
# Processed file [104/552]
#   Name:            04/000004.jpg
#   Dimensions:      1024 x 1024
#   Camera:          #101 - SIMPLE_RADIAL
#   Focal Length:    1228.80px
#   Features:        1289
# Processed file [105/552]
#   Name:            04/000010.jpg
#   Dimensions:      1024 x 1024
#   Camera:          #107 - SIMPLE_RADIAL
#   Focal Length:    1228.80px
#   Features:        1273
# Processed file [106/552]
#   Name:            04/000009.jpg
#   Dimensions:      1024 x 1024
#   Camera:          #106 - SIMPLE_RADIAL
#   Focal Length:    1228.80px
#   Features:        1255
# Processed file [107/552]
#   Name:            04/000014.jpg
#   Dimensions:      1024 x 1024
#   Camera:          #111 - SIMPLE_RADIAL
#   Focal Length:    1228.80px
#   Features:        1292
# Processed file [108/552]
#   Name:            04/000012.jpg
#   Dimensions:      1024 x 1024
#   Camera:          #109 - SIMPLE_RADIAL
#   Focal Length:    1228.80px
#   Features:        1285
# Processed file [109/552]
#   Name:            04/000013.jpg
#   Dimensions:      1024 x 1024
#   Camera:          #110 - SIMPLE_RADIAL
#   Focal Length:    1228.80px
#   Features:        1257
# Processed file [110/552]
#   Name:            04/000002.jpg
#   Dimensions:      1024 x 1024
#   Camera:          #99 - SIMPLE_RADIAL
#   Focal Length:    1228.80px
#   Features:        1271
# Processed file [111/552]
#   Name:            04/000001.jpg
#   Dimensions:      1024 x 1024
#   Camera:          #98 - SIMPLE_RADIAL
#   Focal Length:    1228.80px
#   Features:        1254
# Processed file [112/552]
#   Name:            04/000017.jpg
#   Dimensions:      1024 x 1024
#   Camera:          #114 - SIMPLE_RADIAL
#   Focal Length:    1228.80px
#   Features:        1271
# Processed file [113/552]
#   Name:            04/000015.jpg
#   Dimensions:      1024 x 1024
#   Camera:          #112 - SIMPLE_RADIAL
#   Focal Length:    1228.80px
#   Features:        1252
# Processed file [114/552]
#   Name:            04/000018.jpg
#   Dimensions:      1024 x 1024
#   Camera:          #115 - SIMPLE_RADIAL
#   Focal Length:    1228.80px
#   Features:        1283
# Processed file [115/552]
#   Name:            04/000016.jpg
#   Dimensions:      1024 x 1024
#   Camera:          #113 - SIMPLE_RADIAL
#   Focal Length:    1228.80px
#   Features:        1291
# Processed file [116/552]
#   Name:            04/000022.jpg
#   Dimensions:      1024 x 1024
#   Camera:          #119 - SIMPLE_RADIAL
#   Focal Length:    1228.80px
#   Features:        1272
# Processed file [117/552]
#   Name:            04/000021.jpg
#   Dimensions:      1024 x 1024
#   Camera:          #118 - SIMPLE_RADIAL
#   Focal Length:    1228.80px
#   Features:        1280
# Processed file [118/552]
#   Name:            05/000000.jpg
#   Dimensions:      1024 x 1024
#   Camera:          #121 - SIMPLE_RADIAL
#   Focal Length:    1228.80px
#   Features:        1275
# Processed file [119/552]
#   Name:            04/000020.jpg
#   Dimensions:      1024 x 1024
#   Camera:          #117 - SIMPLE_RADIAL
#   Focal Length:    1228.80px
#   Features:        1320
# Processed file [120/552]
#   Name:            04/000023.jpg
#   Dimensions:      1024 x 1024
#   Camera:          #120 - SIMPLE_RADIAL
#   Focal Length:    1228.80px
#   Features:        1274
# Processed file [121/552]
#   Name:            04/000019.jpg
#   Dimensions:      1024 x 1024
#   Camera:          #116 - SIMPLE_RADIAL
#   Focal Length:    1228.80px
#   Features:        1303
# Processed file [122/552]
#   Name:            05/000001.jpg
#   Dimensions:      1024 x 1024
#   Camera:          #122 - SIMPLE_RADIAL
#   Focal Length:    1228.80px
#   Features:        1247
# Processed file [123/552]
#   Name:            05/000005.jpg
#   Dimensions:      1024 x 1024
#   Camera:          #126 - SIMPLE_RADIAL
#   Focal Length:    1228.80px
#   Features:        1268
# Processed file [124/552]
#   Name:            05/000002.jpg
#   Dimensions:      1024 x 1024
#   Camera:          #123 - SIMPLE_RADIAL
#   Focal Length:    1228.80px
#   Features:        1276
# Processed file [125/552]
#   Name:            05/000004.jpg
#   Dimensions:      1024 x 1024
#   Camera:          #125 - SIMPLE_RADIAL
#   Focal Length:    1228.80px
#   Features:        1262
# Processed file [126/552]
#   Name:            05/000003.jpg
#   Dimensions:      1024 x 1024
#   Camera:          #124 - SIMPLE_RADIAL
#   Focal Length:    1228.80px
#   Features:        1263
# Processed file [127/552]
#   Name:            05/000006.jpg
#   Dimensions:      1024 x 1024
#   Camera:          #127 - SIMPLE_RADIAL
#   Focal Length:    1228.80px
#   Features:        1302
# Processed file [128/552]
#   Name:            05/000007.jpg
#   Dimensions:      1024 x 1024
#   Camera:          #128 - SIMPLE_RADIAL
#   Focal Length:    1228.80px
#   Features:        1288
# Processed file [129/552]
#   Name:            05/000012.jpg
#   Dimensions:      1024 x 1024
#   Camera:          #133 - SIMPLE_RADIAL
#   Focal Length:    1228.80px
#   Features:        1280
# Processed file [130/552]
#   Name:            05/000013.jpg
#   Dimensions:      1024 x 1024
#   Camera:          #134 - SIMPLE_RADIAL
#   Focal Length:    1228.80px
#   Features:        1244
# Processed file [131/552]
#   Name:            05/000008.jpg
#   Dimensions:      1024 x 1024
#   Camera:          #129 - SIMPLE_RADIAL
#   Focal Length:    1228.80px
#   Features:        1273
# Processed file [132/552]
#   Name:            05/000011.jpg
#   Dimensions:      1024 x 1024
#   Camera:          #132 - SIMPLE_RADIAL
#   Focal Length:    1228.80px
#   Features:        1292
# Processed file [133/552]
#   Name:            05/000009.jpg
#   Dimensions:      1024 x 1024
#   Camera:          #130 - SIMPLE_RADIAL
#   Focal Length:    1228.80px
#   Features:        1285
# Processed file [134/552]
#   Name:            05/000010.jpg
#   Dimensions:      1024 x 1024
#   Camera:          #131 - SIMPLE_RADIAL
#   Focal Length:    1228.80px
#   Features:        1290
# Processed file [135/552]
#   Name:            05/000014.jpg
#   Dimensions:      1024 x 1024
#   Camera:          #135 - SIMPLE_RADIAL
#   Focal Length:    1228.80px
#   Features:        1286
# Processed file [136/552]
#   Name:            05/000016.jpg
#   Dimensions:      1024 x 1024
#   Camera:          #137 - SIMPLE_RADIAL
#   Focal Length:    1228.80px
#   Features:        1294
# Processed file [137/552]
#   Name:            05/000021.jpg
#   Dimensions:      1024 x 1024
#   Camera:          #142 - SIMPLE_RADIAL
#   Focal Length:    1228.80px
#   Features:        1296
# Processed file [138/552]
#   Name:            05/000019.jpg
#   Dimensions:      1024 x 1024
#   Camera:          #140 - SIMPLE_RADIAL
#   Focal Length:    1228.80px
#   Features:        1283
# Processed file [139/552]
#   Name:            05/000023.jpg
#   Dimensions:      1024 x 1024
#   Camera:          #144 - SIMPLE_RADIAL
#   Focal Length:    1228.80px
#   Features:        1270
# Processed file [140/552]
#   Name:            05/000015.jpg
#   Dimensions:      1024 x 1024
#   Camera:          #136 - SIMPLE_RADIAL
#   Focal Length:    1228.80px
#   Features:        1262
# Processed file [141/552]
#   Name:            05/000020.jpg
#   Dimensions:      1024 x 1024
#   Camera:          #141 - SIMPLE_RADIAL
#   Focal Length:    1228.80px
#   Features:        1272
# Processed file [142/552]
#   Name:            06/000003.jpg
#   Dimensions:      1024 x 1024
#   Camera:          #148 - SIMPLE_RADIAL
#   Focal Length:    1228.80px
#   Features:        1424
# Processed file [143/552]
#   Name:            06/000005.jpg
#   Dimensions:      1024 x 1024
#   Camera:          #150 - SIMPLE_RADIAL
#   Focal Length:    1228.80px
#   Features:        1433
# Processed file [144/552]
#   Name:            06/000004.jpg
#   Dimensions:      1024 x 1024
#   Camera:          #149 - SIMPLE_RADIAL
#   Focal Length:    1228.80px
#   Features:        1412
# Processed file [145/552]
#   Name:            06/000006.jpg
#   Dimensions:      1024 x 1024
#   Camera:          #151 - SIMPLE_RADIAL
#   Focal Length:    1228.80px
#   Features:        1399
# Processed file [146/552]
#   Name:            06/000000.jpg
#   Dimensions:      1024 x 1024
#   Camera:          #145 - SIMPLE_RADIAL
#   Focal Length:    1228.80px
#   Features:        1417
# Processed file [147/552]
#   Name:            05/000017.jpg
#   Dimensions:      1024 x 1024
#   Camera:          #138 - SIMPLE_RADIAL
#   Focal Length:    1228.80px
#   Features:        1287
# Processed file [148/552]
#   Name:            06/000001.jpg
#   Dimensions:      1024 x 1024
#   Camera:          #146 - SIMPLE_RADIAL
#   Focal Length:    1228.80px
#   Features:        1438
# Processed file [149/552]
#   Name:            05/000018.jpg
#   Dimensions:      1024 x 1024
#   Camera:          #139 - SIMPLE_RADIAL
#   Focal Length:    1228.80px
#   Features:        1281
# Processed file [150/552]
#   Name:            06/000002.jpg
#   Dimensions:      1024 x 1024
#   Camera:          #147 - SIMPLE_RADIAL
#   Focal Length:    1228.80px
#   Features:        1404
# Processed file [151/552]
#   Name:            05/000022.jpg
#   Dimensions:      1024 x 1024
#   Camera:          #143 - SIMPLE_RADIAL
#   Focal Length:    1228.80px
#   Features:        1283
# Processed file [152/552]
#   Name:            06/000008.jpg
#   Dimensions:      1024 x 1024
#   Camera:          #153 - SIMPLE_RADIAL
#   Focal Length:    1228.80px
#   Features:        1420
# Processed file [153/552]
#   Name:            06/000009.jpg
#   Dimensions:      1024 x 1024
#   Camera:          #154 - SIMPLE_RADIAL
#   Focal Length:    1228.80px
#   Features:        1419
# Processed file [154/552]
#   Name:            06/000007.jpg
#   Dimensions:      1024 x 1024
#   Camera:          #152 - SIMPLE_RADIAL
#   Focal Length:    1228.80px
#   Features:        1417
# Processed file [155/552]
#   Name:            06/000011.jpg
#   Dimensions:      1024 x 1024
#   Camera:          #156 - SIMPLE_RADIAL
#   Focal Length:    1228.80px
#   Features:        1416
# Processed file [156/552]
#   Name:            06/000015.jpg
#   Dimensions:      1024 x 1024
#   Camera:          #160 - SIMPLE_RADIAL
#   Focal Length:    1228.80px
#   Features:        1402
# Processed file [157/552]
#   Name:            06/000017.jpg
#   Dimensions:      1024 x 1024
#   Camera:          #162 - SIMPLE_RADIAL
#   Focal Length:    1228.80px
#   Features:        1438
# Processed file [158/552]
#   Name:            06/000016.jpg
#   Dimensions:      1024 x 1024
#   Camera:          #161 - SIMPLE_RADIAL
#   Focal Length:    1228.80px
#   Features:        1430
# Processed file [159/552]
#   Name:            06/000014.jpg
#   Dimensions:      1024 x 1024
#   Camera:          #159 - SIMPLE_RADIAL
#   Focal Length:    1228.80px
#   Features:        1429
# Processed file [160/552]
#   Name:            06/000012.jpg
#   Dimensions:      1024 x 1024
#   Camera:          #157 - SIMPLE_RADIAL
#   Focal Length:    1228.80px
#   Features:        1420
# Processed file [161/552]
#   Name:            06/000013.jpg
#   Dimensions:      1024 x 1024
#   Camera:          #158 - SIMPLE_RADIAL
#   Focal Length:    1228.80px
#   Features:        1405
# Processed file [162/552]
#   Name:            06/000010.jpg
#   Dimensions:      1024 x 1024
#   Camera:          #155 - SIMPLE_RADIAL
#   Focal Length:    1228.80px
#   Features:        1429
# Processed file [163/552]
#   Name:            06/000018.jpg
#   Dimensions:      1024 x 1024
#   Camera:          #163 - SIMPLE_RADIAL
#   Focal Length:    1228.80px
#   Features:        1399
# Processed file [164/552]
#   Name:            06/000020.jpg
#   Dimensions:      1024 x 1024
#   Camera:          #165 - SIMPLE_RADIAL
#   Focal Length:    1228.80px
#   Features:        1422
# Processed file [165/552]
#   Name:            06/000019.jpg
#   Dimensions:      1024 x 1024
#   Camera:          #164 - SIMPLE_RADIAL
#   Focal Length:    1228.80px
#   Features:        1429
# Processed file [166/552]
#   Name:            06/000021.jpg
#   Dimensions:      1024 x 1024
#   Camera:          #166 - SIMPLE_RADIAL
#   Focal Length:    1228.80px
#   Features:        1446
# Processed file [167/552]
#   Name:            06/000022.jpg
#   Dimensions:      1024 x 1024
#   Camera:          #167 - SIMPLE_RADIAL
#   Focal Length:    1228.80px
#   Features:        1433
# Processed file [168/552]
#   Name:            07/000003.jpg
#   Dimensions:      1024 x 1024
#   Camera:          #172 - SIMPLE_RADIAL
#   Focal Length:    1228.80px
#   Features:        1044
# Processed file [169/552]
#   Name:            07/000001.jpg
#   Dimensions:      1024 x 1024
#   Camera:          #170 - SIMPLE_RADIAL
#   Focal Length:    1228.80px
#   Features:        1021
# Processed file [170/552]
#   Name:            07/000005.jpg
#   Dimensions:      1024 x 1024
#   Camera:          #174 - SIMPLE_RADIAL
#   Focal Length:    1228.80px
#   Features:        1042
# Processed file [171/552]
#   Name:            07/000000.jpg
#   Dimensions:      1024 x 1024
#   Camera:          #169 - SIMPLE_RADIAL
#   Focal Length:    1228.80px
#   Features:        1045
# Processed file [172/552]
#   Name:            07/000002.jpg
#   Dimensions:      1024 x 1024
#   Camera:          #171 - SIMPLE_RADIAL
#   Focal Length:    1228.80px
#   Features:        1010
# Processed file [173/552]
#   Name:            07/000013.jpg
#   Dimensions:      1024 x 1024
#   Camera:          #182 - SIMPLE_RADIAL
#   Focal Length:    1228.80px
#   Features:        1046
# Processed file [174/552]
#   Name:            07/000012.jpg
#   Dimensions:      1024 x 1024
#   Camera:          #181 - SIMPLE_RADIAL
#   Focal Length:    1228.80px
#   Features:        1036
# Processed file [175/552]
#   Name:            07/000004.jpg
#   Dimensions:      1024 x 1024
#   Camera:          #173 - SIMPLE_RADIAL
#   Focal Length:    1228.80px
#   Features:        1056
# Processed file [176/552]
#   Name:            06/000023.jpg
#   Dimensions:      1024 x 1024
#   Camera:          #168 - SIMPLE_RADIAL
#   Focal Length:    1228.80px
#   Features:        1437
# Processed file [177/552]
#   Name:            07/000022.jpg
#   Dimensions:      1024 x 1024
#   Camera:          #191 - SIMPLE_RADIAL
#   Focal Length:    1228.80px
#   Features:        1037
# Processed file [178/552]
#   Name:            07/000008.jpg
#   Dimensions:      1024 x 1024
#   Camera:          #177 - SIMPLE_RADIAL
#   Focal Length:    1228.80px
#   Features:        1035
# Processed file [179/552]
#   Name:            07/000019.jpg
#   Dimensions:      1024 x 1024
#   Camera:          #188 - SIMPLE_RADIAL
#   Focal Length:    1228.80px
#   Features:        1032
# Processed file [180/552]
#   Name:            07/000010.jpg
#   Dimensions:      1024 x 1024
#   Camera:          #179 - SIMPLE_RADIAL
#   Focal Length:    1228.80px
#   Features:        1038
# Processed file [181/552]
#   Name:            07/000017.jpg
#   Dimensions:      1024 x 1024
#   Camera:          #186 - SIMPLE_RADIAL
#   Focal Length:    1228.80px
#   Features:        1044
# Processed file [182/552]
#   Name:            07/000016.jpg
#   Dimensions:      1024 x 1024
#   Camera:          #185 - SIMPLE_RADIAL
#   Focal Length:    1228.80px
#   Features:        1041
# Processed file [183/552]
#   Name:            07/000018.jpg
#   Dimensions:      1024 x 1024
#   Camera:          #187 - SIMPLE_RADIAL
#   Focal Length:    1228.80px
#   Features:        1038
# Processed file [184/552]
#   Name:            07/000015.jpg
#   Dimensions:      1024 x 1024
#   Camera:          #184 - SIMPLE_RADIAL
#   Focal Length:    1228.80px
#   Features:        1042
# Processed file [185/552]
#   Name:            07/000009.jpg
#   Dimensions:      1024 x 1024
#   Camera:          #178 - SIMPLE_RADIAL
#   Focal Length:    1228.80px
#   Features:        1042
# Processed file [186/552]
#   Name:            07/000011.jpg
#   Dimensions:      1024 x 1024
#   Camera:          #180 - SIMPLE_RADIAL
#   Focal Length:    1228.80px
#   Features:        1042
# Processed file [187/552]
#   Name:            07/000006.jpg
#   Dimensions:      1024 x 1024
#   Camera:          #175 - SIMPLE_RADIAL
#   Focal Length:    1228.80px
#   Features:        1042
# Processed file [188/552]
#   Name:            07/000020.jpg
#   Dimensions:      1024 x 1024
#   Camera:          #189 - SIMPLE_RADIAL
#   Focal Length:    1228.80px
#   Features:        1043
# Processed file [189/552]
#   Name:            07/000021.jpg
#   Dimensions:      1024 x 1024
#   Camera:          #190 - SIMPLE_RADIAL
#   Focal Length:    1228.80px
#   Features:        1044
# Processed file [190/552]
#   Name:            07/000007.jpg
#   Dimensions:      1024 x 1024
#   Camera:          #176 - SIMPLE_RADIAL
#   Focal Length:    1228.80px
#   Features:        1016
# Processed file [191/552]
#   Name:            07/000014.jpg
#   Dimensions:      1024 x 1024
#   Camera:          #183 - SIMPLE_RADIAL
#   Focal Length:    1228.80px
#   Features:        1064
# Processed file [192/552]
#   Name:            08/000006.jpg
#   Dimensions:      1024 x 1024
#   Camera:          #199 - SIMPLE_RADIAL
#   Focal Length:    1228.80px
#   Features:        994
# Processed file [193/552]
#   Name:            08/000008.jpg
#   Dimensions:      1024 x 1024
#   Camera:          #201 - SIMPLE_RADIAL
#   Focal Length:    1228.80px
#   Features:        990
# Processed file [194/552]
#   Name:            07/000023.jpg
#   Dimensions:      1024 x 1024
#   Camera:          #192 - SIMPLE_RADIAL
#   Focal Length:    1228.80px
#   Features:        1035
# Processed file [195/552]
#   Name:            08/000007.jpg
#   Dimensions:      1024 x 1024
#   Camera:          #200 - SIMPLE_RADIAL
#   Focal Length:    1228.80px
#   Features:        1002
# Processed file [196/552]
#   Name:            08/000005.jpg
#   Dimensions:      1024 x 1024
#   Camera:          #198 - SIMPLE_RADIAL
#   Focal Length:    1228.80px
#   Features:        1009
# Processed file [197/552]
#   Name:            08/000001.jpg
#   Dimensions:      1024 x 1024
#   Camera:          #194 - SIMPLE_RADIAL
#   Focal Length:    1228.80px
#   Features:        1014
# Processed file [198/552]
#   Name:            08/000004.jpg
#   Dimensions:      1024 x 1024
#   Camera:          #197 - SIMPLE_RADIAL
#   Focal Length:    1228.80px
#   Features:        983
# Processed file [199/552]
#   Name:            08/000009.jpg
#   Dimensions:      1024 x 1024
#   Camera:          #202 - SIMPLE_RADIAL
#   Focal Length:    1228.80px
#   Features:        1001
# Processed file [200/552]
#   Name:            08/000012.jpg
#   Dimensions:      1024 x 1024
#   Camera:          #205 - SIMPLE_RADIAL
#   Focal Length:    1228.80px
#   Features:        1013
# Processed file [201/552]
#   Name:            08/000003.jpg
#   Dimensions:      1024 x 1024
#   Camera:          #196 - SIMPLE_RADIAL
#   Focal Length:    1228.80px
#   Features:        993
# Processed file [202/552]
#   Name:            08/000002.jpg
#   Dimensions:      1024 x 1024
#   Camera:          #195 - SIMPLE_RADIAL
#   Focal Length:    1228.80px
#   Features:        1006
# Processed file [203/552]
#   Name:            08/000000.jpg
#   Dimensions:      1024 x 1024
#   Camera:          #193 - SIMPLE_RADIAL
#   Focal Length:    1228.80px
#   Features:        1016
# Processed file [204/552]
#   Name:            08/000010.jpg
#   Dimensions:      1024 x 1024
#   Camera:          #203 - SIMPLE_RADIAL
#   Focal Length:    1228.80px
#   Features:        1034
# Processed file [205/552]
#   Name:            08/000013.jpg
#   Dimensions:      1024 x 1024
#   Camera:          #206 - SIMPLE_RADIAL
#   Focal Length:    1228.80px
#   Features:        1000
# Processed file [206/552]
#   Name:            08/000011.jpg
#   Dimensions:      1024 x 1024
#   Camera:          #204 - SIMPLE_RADIAL
#   Focal Length:    1228.80px
#   Features:        1011
# Processed file [207/552]
#   Name:            08/000014.jpg
#   Dimensions:      1024 x 1024
#   Camera:          #207 - SIMPLE_RADIAL
#   Focal Length:    1228.80px
#   Features:        1023
# Processed file [208/552]
#   Name:            08/000015.jpg
#   Dimensions:      1024 x 1024
#   Camera:          #208 - SIMPLE_RADIAL
#   Focal Length:    1228.80px
#   Features:        1011
# Processed file [209/552]
#   Name:            08/000016.jpg
#   Dimensions:      1024 x 1024
#   Camera:          #209 - SIMPLE_RADIAL
#   Focal Length:    1228.80px
#   Features:        1018
# Processed file [210/552]
#   Name:            08/000021.jpg
#   Dimensions:      1024 x 1024
#   Camera:          #214 - SIMPLE_RADIAL
#   Focal Length:    1228.80px
#   Features:        1016
# Processed file [211/552]
#   Name:            09/000000.jpg
#   Dimensions:      1024 x 1024
#   Camera:          #217 - SIMPLE_RADIAL
#   Focal Length:    1228.80px
#   Features:        947
# Processed file [212/552]
#   Name:            09/000013.jpg
#   Dimensions:      1024 x 1024
#   Camera:          #230 - SIMPLE_RADIAL
#   Focal Length:    1228.80px
#   Features:        943
# Processed file [213/552]
#   Name:            09/000007.jpg
#   Dimensions:      1024 x 1024
#   Camera:          #224 - SIMPLE_RADIAL
#   Focal Length:    1228.80px
#   Features:        967
# Processed file [214/552]
#   Name:            08/000017.jpg
#   Dimensions:      1024 x 1024
#   Camera:          #210 - SIMPLE_RADIAL
#   Focal Length:    1228.80px
#   Features:        1010
# Processed file [215/552]
#   Name:            09/000005.jpg
#   Dimensions:      1024 x 1024
#   Camera:          #222 - SIMPLE_RADIAL
#   Focal Length:    1228.80px
#   Features:        962
# Processed file [216/552]
#   Name:            09/000010.jpg
#   Dimensions:      1024 x 1024
#   Camera:          #227 - SIMPLE_RADIAL
#   Focal Length:    1228.80px
#   Features:        941
# Processed file [217/552]
#   Name:            09/000004.jpg
#   Dimensions:      1024 x 1024
#   Camera:          #221 - SIMPLE_RADIAL
#   Focal Length:    1228.80px
#   Features:        939
# Processed file [218/552]
#   Name:            08/000018.jpg
#   Dimensions:      1024 x 1024
#   Camera:          #211 - SIMPLE_RADIAL
#   Focal Length:    1228.80px
#   Features:        1011
# Processed file [219/552]
#   Name:            08/000020.jpg
#   Dimensions:      1024 x 1024
#   Camera:          #213 - SIMPLE_RADIAL
#   Focal Length:    1228.80px
#   Features:        1018
# Processed file [220/552]
#   Name:            08/000023.jpg
#   Dimensions:      1024 x 1024
#   Camera:          #216 - SIMPLE_RADIAL
#   Focal Length:    1228.80px
#   Features:        1014
# Processed file [221/552]
#   Name:            08/000019.jpg
#   Dimensions:      1024 x 1024
#   Camera:          #212 - SIMPLE_RADIAL
#   Focal Length:    1228.80px
#   Features:        1010
# Processed file [222/552]
#   Name:            09/000012.jpg
#   Dimensions:      1024 x 1024
#   Camera:          #229 - SIMPLE_RADIAL
#   Focal Length:    1228.80px
#   Features:        958
# Processed file [223/552]
#   Name:            09/000006.jpg
#   Dimensions:      1024 x 1024
#   Camera:          #223 - SIMPLE_RADIAL
#   Focal Length:    1228.80px
#   Features:        953
# Processed file [224/552]
#   Name:            09/000001.jpg
#   Dimensions:      1024 x 1024
#   Camera:          #218 - SIMPLE_RADIAL
#   Focal Length:    1228.80px
#   Features:        964
# Processed file [225/552]
#   Name:            08/000022.jpg
#   Dimensions:      1024 x 1024
#   Camera:          #215 - SIMPLE_RADIAL
#   Focal Length:    1228.80px
#   Features:        1015
# Processed file [226/552]
#   Name:            09/000011.jpg
#   Dimensions:      1024 x 1024
#   Camera:          #228 - SIMPLE_RADIAL
#   Focal Length:    1228.80px
#   Features:        964
# Processed file [227/552]
#   Name:            09/000008.jpg
#   Dimensions:      1024 x 1024
#   Camera:          #225 - SIMPLE_RADIAL
#   Focal Length:    1228.80px
#   Features:        978
# Processed file [228/552]
#   Name:            09/000014.jpg
#   Dimensions:      1024 x 1024
#   Camera:          #231 - SIMPLE_RADIAL
#   Focal Length:    1228.80px
#   Features:        955
# Processed file [229/552]
#   Name:            09/000009.jpg
#   Dimensions:      1024 x 1024
#   Camera:          #226 - SIMPLE_RADIAL
#   Focal Length:    1228.80px
#   Features:        934
# Processed file [230/552]
#   Name:            09/000002.jpg
#   Dimensions:      1024 x 1024
#   Camera:          #219 - SIMPLE_RADIAL
#   Focal Length:    1228.80px
#   Features:        925
# Processed file [231/552]
#   Name:            09/000003.jpg
#   Dimensions:      1024 x 1024
#   Camera:          #220 - SIMPLE_RADIAL
#   Focal Length:    1228.80px
#   Features:        987
# Processed file [232/552]
#   Name:            10/000002.jpg
#   Dimensions:      1024 x 1024
#   Camera:          #243 - SIMPLE_RADIAL
#   Focal Length:    1228.80px
#   Features:        742
# Processed file [233/552]
#   Name:            09/000020.jpg
#   Dimensions:      1024 x 1024
#   Camera:          #237 - SIMPLE_RADIAL
#   Focal Length:    1228.80px
#   Features:        973
# Processed file [234/552]
#   Name:            09/000022.jpg
#   Dimensions:      1024 x 1024
#   Camera:          #239 - SIMPLE_RADIAL
#   Focal Length:    1228.80px
#   Features:        951
# Processed file [235/552]
#   Name:            10/000005.jpg
#   Dimensions:      1024 x 1024
#   Camera:          #246 - SIMPLE_RADIAL
#   Focal Length:    1228.80px
#   Features:        735
# Processed file [236/552]
#   Name:            09/000019.jpg
#   Dimensions:      1024 x 1024
#   Camera:          #236 - SIMPLE_RADIAL
#   Focal Length:    1228.80px
#   Features:        962
# Processed file [237/552]
#   Name:            10/000000.jpg
#   Dimensions:      1024 x 1024
#   Camera:          #241 - SIMPLE_RADIAL
#   Focal Length:    1228.80px
#   Features:        742
# Processed file [238/552]
#   Name:            10/000003.jpg
#   Dimensions:      1024 x 1024
#   Camera:          #244 - SIMPLE_RADIAL
#   Focal Length:    1228.80px
#   Features:        734
# Processed file [239/552]
#   Name:            09/000015.jpg
#   Dimensions:      1024 x 1024
#   Camera:          #232 - SIMPLE_RADIAL
#   Focal Length:    1228.80px
#   Features:        956
# Processed file [240/552]
#   Name:            09/000016.jpg
#   Dimensions:      1024 x 1024
#   Camera:          #233 - SIMPLE_RADIAL
#   Focal Length:    1228.80px
#   Features:        937
# Processed file [241/552]
#   Name:            09/000023.jpg
#   Dimensions:      1024 x 1024
#   Camera:          #240 - SIMPLE_RADIAL
#   Focal Length:    1228.80px
#   Features:        958
# Processed file [242/552]
#   Name:            09/000021.jpg
#   Dimensions:      1024 x 1024
#   Camera:          #238 - SIMPLE_RADIAL
#   Focal Length:    1228.80px
#   Features:        966
# Processed file [243/552]
#   Name:            10/000001.jpg
#   Dimensions:      1024 x 1024
#   Camera:          #242 - SIMPLE_RADIAL
#   Focal Length:    1228.80px
#   Features:        744
# Processed file [244/552]
#   Name:            10/000004.jpg
#   Dimensions:      1024 x 1024
#   Camera:          #245 - SIMPLE_RADIAL
#   Focal Length:    1228.80px
#   Features:        730
# Processed file [245/552]
#   Name:            09/000017.jpg
#   Dimensions:      1024 x 1024
#   Camera:          #234 - SIMPLE_RADIAL
#   Focal Length:    1228.80px
#   Features:        965
# Processed file [246/552]
#   Name:            09/000018.jpg
#   Dimensions:      1024 x 1024
#   Camera:          #235 - SIMPLE_RADIAL
#   Focal Length:    1228.80px
#   Features:        946
# Processed file [247/552]
#   Name:            10/000006.jpg
#   Dimensions:      1024 x 1024
#   Camera:          #247 - SIMPLE_RADIAL
#   Focal Length:    1228.80px
#   Features:        743
# Processed file [248/552]
#   Name:            10/000007.jpg
#   Dimensions:      1024 x 1024
#   Camera:          #248 - SIMPLE_RADIAL
#   Focal Length:    1228.80px
#   Features:        733
# Processed file [249/552]
#   Name:            10/000021.jpg
#   Dimensions:      1024 x 1024
#   Camera:          #262 - SIMPLE_RADIAL
#   Focal Length:    1228.80px
#   Features:        712
# Processed file [250/552]
#   Name:            10/000008.jpg
#   Dimensions:      1024 x 1024
#   Camera:          #249 - SIMPLE_RADIAL
#   Focal Length:    1228.80px
#   Features:        721
# Processed file [251/552]
#   Name:            10/000022.jpg
#   Dimensions:      1024 x 1024
#   Camera:          #263 - SIMPLE_RADIAL
#   Focal Length:    1228.80px
#   Features:        721
# Processed file [252/552]
#   Name:            10/000013.jpg
#   Dimensions:      1024 x 1024
#   Camera:          #254 - SIMPLE_RADIAL
#   Focal Length:    1228.80px
#   Features:        717
# Processed file [253/552]
#   Name:            11/000003.jpg
#   Dimensions:      1024 x 1024
#   Camera:          #268 - SIMPLE_RADIAL
#   Focal Length:    1228.80px
#   Features:        806
# Processed file [254/552]
#   Name:            10/000019.jpg
#   Dimensions:      1024 x 1024
#   Camera:          #260 - SIMPLE_RADIAL
#   Focal Length:    1228.80px
#   Features:        703
# Processed file [255/552]
#   Name:            10/000016.jpg
#   Dimensions:      1024 x 1024
#   Camera:          #257 - SIMPLE_RADIAL
#   Focal Length:    1228.80px
#   Features:        747
# Processed file [256/552]
#   Name:            10/000009.jpg
#   Dimensions:      1024 x 1024
#   Camera:          #250 - SIMPLE_RADIAL
#   Focal Length:    1228.80px
#   Features:        723
# Processed file [257/552]
#   Name:            11/000004.jpg
#   Dimensions:      1024 x 1024
#   Camera:          #269 - SIMPLE_RADIAL
#   Focal Length:    1228.80px
#   Features:        801
# Processed file [258/552]
#   Name:            11/000001.jpg
#   Dimensions:      1024 x 1024
#   Camera:          #266 - SIMPLE_RADIAL
#   Focal Length:    1228.80px
#   Features:        813
# Processed file [259/552]
#   Name:            11/000000.jpg
#   Dimensions:      1024 x 1024
#   Camera:          #265 - SIMPLE_RADIAL
#   Focal Length:    1228.80px
#   Features:        803
# Processed file [260/552]
#   Name:            10/000020.jpg
#   Dimensions:      1024 x 1024
#   Camera:          #261 - SIMPLE_RADIAL
#   Focal Length:    1228.80px
#   Features:        731
# Processed file [261/552]
#   Name:            11/000005.jpg
#   Dimensions:      1024 x 1024
#   Camera:          #270 - SIMPLE_RADIAL
#   Focal Length:    1228.80px
#   Features:        808
# Processed file [262/552]
#   Name:            10/000018.jpg
#   Dimensions:      1024 x 1024
#   Camera:          #259 - SIMPLE_RADIAL
#   Focal Length:    1228.80px
#   Features:        725
# Processed file [263/552]
#   Name:            10/000010.jpg
# ...
#   Name:            19/000002.jpg
#   Dimensions:      1024 x 1024
#   Camera:          #459 - SIMPLE_RADIAL
#   Focal Length:    1228.80px
#   Features:        997
# Processed file [466/552]
#   Name:            19/000009.jpg
#   Dimensions:      1024 x 1024
#   Camera:          #466 - SIMPLE_RADIAL
#   Focal Length:    1228.80px
#   Features:        996
# Processed file [467/552]
#   Name:            19/000007.jpg
#   Dimensions:      1024 x 1024
#   Camera:          #464 - SIMPLE_RADIAL
#   Focal Length:    1228.80px
#   Features:        983
# Processed file [468/552]
#   Name:            19/000008.jpg
#   Dimensions:      1024 x 1024
#   Camera:          #465 - SIMPLE_RADIAL
#   Focal Length:    1228.80px
#   Features:        997
# Processed file [469/552]
#   Name:            19/000013.jpg
#   Dimensions:      1024 x 1024
#   Camera:          #470 - SIMPLE_RADIAL
#   Focal Length:    1228.80px
#   Features:        993
# Processed file [470/552]
#   Name:            19/000005.jpg
#   Dimensions:      1024 x 1024
#   Camera:          #462 - SIMPLE_RADIAL
#   Focal Length:    1228.80px
#   Features:        972
# Processed file [471/552]
#   Name:            19/000000.jpg
#   Dimensions:      1024 x 1024
#   Camera:          #457 - SIMPLE_RADIAL
#   Focal Length:    1228.80px
#   Features:        984
# Processed file [472/552]
#   Name:            19/000019.jpg
#   Dimensions:      1024 x 1024
#   Camera:          #476 - SIMPLE_RADIAL
#   Focal Length:    1228.80px
#   Features:        1002
# Processed file [473/552]
#   Name:            19/000018.jpg
#   Dimensions:      1024 x 1024
#   Camera:          #475 - SIMPLE_RADIAL
#   Focal Length:    1228.80px
#   Features:        977
# Processed file [474/552]
#   Name:            19/000021.jpg
#   Dimensions:      1024 x 1024
#   Camera:          #478 - SIMPLE_RADIAL
#   Focal Length:    1228.80px
#   Features:        976
# Processed file [475/552]
#   Name:            19/000023.jpg
#   Dimensions:      1024 x 1024
#   Camera:          #480 - SIMPLE_RADIAL
#   Focal Length:    1228.80px
#   Features:        998
# Processed file [476/552]
#   Name:            20/000002.jpg
#   Dimensions:      1024 x 1024
#   Camera:          #483 - SIMPLE_RADIAL
#   Focal Length:    1228.80px
#   Features:        1098
# Processed file [477/552]
#   Name:            19/000016.jpg
#   Dimensions:      1024 x 1024
#   Camera:          #473 - SIMPLE_RADIAL
#   Focal Length:    1228.80px
#   Features:        999
# Processed file [478/552]
#   Name:            19/000015.jpg
#   Dimensions:      1024 x 1024
#   Camera:          #472 - SIMPLE_RADIAL
#   Focal Length:    1228.80px
#   Features:        1005
# Processed file [479/552]
#   Name:            19/000020.jpg
#   Dimensions:      1024 x 1024
#   Camera:          #477 - SIMPLE_RADIAL
#   Focal Length:    1228.80px
#   Features:        987
# Processed file [480/552]
#   Name:            19/000017.jpg
#   Dimensions:      1024 x 1024
#   Camera:          #474 - SIMPLE_RADIAL
#   Focal Length:    1228.80px
#   Features:        995
# Processed file [481/552]
#   Name:            20/000005.jpg
#   Dimensions:      1024 x 1024
#   Camera:          #486 - SIMPLE_RADIAL
#   Focal Length:    1228.80px
#   Features:        1114
# Processed file [482/552]
#   Name:            19/000022.jpg
#   Dimensions:      1024 x 1024
#   Camera:          #479 - SIMPLE_RADIAL
#   Focal Length:    1228.80px
#   Features:        980
# Processed file [483/552]
#   Name:            20/000004.jpg
#   Dimensions:      1024 x 1024
#   Camera:          #485 - SIMPLE_RADIAL
#   Focal Length:    1228.80px
#   Features:        1129
# Processed file [484/552]
#   Name:            20/000003.jpg
#   Dimensions:      1024 x 1024
#   Camera:          #484 - SIMPLE_RADIAL
#   Focal Length:    1228.80px
#   Features:        1101
# Processed file [485/552]
#   Name:            20/000000.jpg
#   Dimensions:      1024 x 1024
#   Camera:          #481 - SIMPLE_RADIAL
#   Focal Length:    1228.80px
#   Features:        1101
# Processed file [486/552]
#   Name:            20/000001.jpg
#   Dimensions:      1024 x 1024
#   Camera:          #482 - SIMPLE_RADIAL
#   Focal Length:    1228.80px
#   Features:        1117
# Processed file [487/552]
#   Name:            20/000006.jpg
#   Dimensions:      1024 x 1024
#   Camera:          #487 - SIMPLE_RADIAL
#   Focal Length:    1228.80px
#   Features:        1102
# Processed file [488/552]
#   Name:            20/000007.jpg
#   Dimensions:      1024 x 1024
#   Camera:          #488 - SIMPLE_RADIAL
#   Focal Length:    1228.80px
#   Features:        1109
# Processed file [489/552]
#   Name:            20/000010.jpg
#   Dimensions:      1024 x 1024
#   Camera:          #491 - SIMPLE_RADIAL
#   Focal Length:    1228.80px
#   Features:        1110
# Processed file [490/552]
#   Name:            20/000013.jpg
#   Dimensions:      1024 x 1024
#   Camera:          #494 - SIMPLE_RADIAL
#   Focal Length:    1228.80px
#   Features:        1104
# Processed file [491/552]
#   Name:            20/000008.jpg
#   Dimensions:      1024 x 1024
#   Camera:          #489 - SIMPLE_RADIAL
#   Focal Length:    1228.80px
#   Features:        1112
# Processed file [492/552]
#   Name:            20/000011.jpg
#   Dimensions:      1024 x 1024
#   Camera:          #492 - SIMPLE_RADIAL
#   Focal Length:    1228.80px
#   Features:        1108
# Processed file [493/552]
#   Name:            20/000012.jpg
#   Dimensions:      1024 x 1024
#   Camera:          #493 - SIMPLE_RADIAL
#   Focal Length:    1228.80px
#   Features:        1110
# Processed file [494/552]
#   Name:            20/000014.jpg
#   Dimensions:      1024 x 1024
#   Camera:          #495 - SIMPLE_RADIAL
#   Focal Length:    1228.80px
#   Features:        1118
# Processed file [495/552]
#   Name:            20/000019.jpg
#   Dimensions:      1024 x 1024
#   Camera:          #500 - SIMPLE_RADIAL
#   Focal Length:    1228.80px
#   Features:        1099
# Processed file [496/552]
#   Name:            21/000006.jpg
#   Dimensions:      1024 x 1024
#   Camera:          #511 - SIMPLE_RADIAL
#   Focal Length:    1228.80px
#   Features:        1036
# Processed file [497/552]
#   Name:            20/000021.jpg
#   Dimensions:      1024 x 1024
#   Camera:          #502 - SIMPLE_RADIAL
#   Focal Length:    1228.80px
#   Features:        1137
# Processed file [498/552]
#   Name:            20/000009.jpg
#   Dimensions:      1024 x 1024
#   Camera:          #490 - SIMPLE_RADIAL
#   Focal Length:    1228.80px
#   Features:        1097
# Processed file [499/552]
#   Name:            20/000018.jpg
#   Dimensions:      1024 x 1024
#   Camera:          #499 - SIMPLE_RADIAL
#   Focal Length:    1228.80px
#   Features:        1111
# Processed file [500/552]
#   Name:            21/000001.jpg
#   Dimensions:      1024 x 1024
#   Camera:          #506 - SIMPLE_RADIAL
#   Focal Length:    1228.80px
#   Features:        1041
# Processed file [501/552]
#   Name:            20/000023.jpg
#   Dimensions:      1024 x 1024
#   Camera:          #504 - SIMPLE_RADIAL
#   Focal Length:    1228.80px
#   Features:        1112
# Processed file [502/552]
#   Name:            21/000004.jpg
#   Dimensions:      1024 x 1024
#   Camera:          #509 - SIMPLE_RADIAL
#   Focal Length:    1228.80px
#   Features:        1031
# Processed file [503/552]
#   Name:            20/000015.jpg
#   Dimensions:      1024 x 1024
#   Camera:          #496 - SIMPLE_RADIAL
#   Focal Length:    1228.80px
#   Features:        1102
# Processed file [504/552]
#   Name:            21/000005.jpg
#   Dimensions:      1024 x 1024
#   Camera:          #510 - SIMPLE_RADIAL
#   Focal Length:    1228.80px
#   Features:        1045
# Processed file [505/552]
#   Name:            20/000017.jpg
#   Dimensions:      1024 x 1024
#   Camera:          #498 - SIMPLE_RADIAL
#   Focal Length:    1228.80px
#   Features:        1087
# Processed file [506/552]
#   Name:            20/000016.jpg
#   Dimensions:      1024 x 1024
#   Camera:          #497 - SIMPLE_RADIAL
#   Focal Length:    1228.80px
#   Features:        1112
# Processed file [507/552]
#   Name:            21/000000.jpg
#   Dimensions:      1024 x 1024
#   Camera:          #505 - SIMPLE_RADIAL
#   Focal Length:    1228.80px
#   Features:        1047
# Processed file [508/552]
#   Name:            20/000020.jpg
#   Dimensions:      1024 x 1024
#   Camera:          #501 - SIMPLE_RADIAL
#   Focal Length:    1228.80px
#   Features:        1092
# Processed file [509/552]
#   Name:            21/000002.jpg
#   Dimensions:      1024 x 1024
#   Camera:          #507 - SIMPLE_RADIAL
#   Focal Length:    1228.80px
#   Features:        1019
# Processed file [510/552]
#   Name:            21/000003.jpg
#   Dimensions:      1024 x 1024
#   Camera:          #508 - SIMPLE_RADIAL
#   Focal Length:    1228.80px
#   Features:        1017
# Processed file [511/552]
#   Name:            20/000022.jpg
#   Dimensions:      1024 x 1024
#   Camera:          #503 - SIMPLE_RADIAL
#   Focal Length:    1228.80px
#   Features:        1109
# Processed file [512/552]
#   Name:            21/000010.jpg
#   Dimensions:      1024 x 1024
#   Camera:          #515 - SIMPLE_RADIAL
#   Focal Length:    1228.80px
#   Features:        1040
# Processed file [513/552]
#   Name:            21/000022.jpg
#   Dimensions:      1024 x 1024
#   Camera:          #527 - SIMPLE_RADIAL
#   Focal Length:    1228.80px
#   Features:        1049
# Processed file [514/552]
#   Name:            21/000019.jpg
#   Dimensions:      1024 x 1024
#   Camera:          #524 - SIMPLE_RADIAL
#   Focal Length:    1228.80px
#   Features:        1034
# Processed file [515/552]
#   Name:            21/000017.jpg
#   Dimensions:      1024 x 1024
#   Camera:          #522 - SIMPLE_RADIAL
#   Focal Length:    1228.80px
#   Features:        1024
# Processed file [516/552]
#   Name:            21/000016.jpg
#   Dimensions:      1024 x 1024
#   Camera:          #521 - SIMPLE_RADIAL
#   Focal Length:    1228.80px
#   Features:        1026
# Processed file [517/552]
#   Name:            21/000014.jpg
#   Dimensions:      1024 x 1024
#   Camera:          #519 - SIMPLE_RADIAL
#   Focal Length:    1228.80px
#   Features:        1043
# Processed file [518/552]
#   Name:            21/000011.jpg
#   Dimensions:      1024 x 1024
#   Camera:          #516 - SIMPLE_RADIAL
#   Focal Length:    1228.80px
#   Features:        1031
# Processed file [519/552]
#   Name:            21/000018.jpg
#   Dimensions:      1024 x 1024
#   Camera:          #523 - SIMPLE_RADIAL
#   Focal Length:    1228.80px
#   Features:        1039
# Processed file [520/552]
#   Name:            21/000015.jpg
#   Dimensions:      1024 x 1024
#   Camera:          #520 - SIMPLE_RADIAL
#   Focal Length:    1228.80px
#   Features:        1042
# Processed file [521/552]
#   Name:            21/000007.jpg
#   Dimensions:      1024 x 1024
#   Camera:          #512 - SIMPLE_RADIAL
#   Focal Length:    1228.80px
#   Features:        1034
# Processed file [522/552]
#   Name:            21/000013.jpg
#   Dimensions:      1024 x 1024
#   Camera:          #518 - SIMPLE_RADIAL
#   Focal Length:    1228.80px
#   Features:        1037
# Processed file [523/552]
#   Name:            21/000021.jpg
#   Dimensions:      1024 x 1024
#   Camera:          #526 - SIMPLE_RADIAL
#   Focal Length:    1228.80px
#   Features:        1028
# Processed file [524/552]
#   Name:            21/000020.jpg
#   Dimensions:      1024 x 1024
#   Camera:          #525 - SIMPLE_RADIAL
#   Focal Length:    1228.80px
#   Features:        1027
# Processed file [525/552]
#   Name:            21/000008.jpg
#   Dimensions:      1024 x 1024
#   Camera:          #513 - SIMPLE_RADIAL
#   Focal Length:    1228.80px
#   Features:        1043
# Processed file [526/552]
#   Name:            21/000009.jpg
#   Dimensions:      1024 x 1024
#   Camera:          #514 - SIMPLE_RADIAL
#   Focal Length:    1228.80px
#   Features:        1049
# Processed file [527/552]
#   Name:            21/000012.jpg
#   Dimensions:      1024 x 1024
#   Camera:          #517 - SIMPLE_RADIAL
#   Focal Length:    1228.80px
#   Features:        1062
# Processed file [528/552]
#   Name:            22/000003.jpg
#   Dimensions:      1024 x 1024
#   Camera:          #532 - SIMPLE_RADIAL
#   Focal Length:    1228.80px
#   Features:        947
# Processed file [529/552]
#   Name:            21/000023.jpg
#   Dimensions:      1024 x 1024
#   Camera:          #528 - SIMPLE_RADIAL
#   Focal Length:    1228.80px
#   Features:        1057
# Processed file [530/552]
#   Name:            22/000002.jpg
#   Dimensions:      1024 x 1024
#   Camera:          #531 - SIMPLE_RADIAL
#   Focal Length:    1228.80px
#   Features:        955
# Processed file [531/552]
#   Name:            22/000007.jpg
#   Dimensions:      1024 x 1024
#   Camera:          #536 - SIMPLE_RADIAL
#   Focal Length:    1228.80px
#   Features:        960
# Processed file [532/552]
#   Name:            22/000006.jpg
#   Dimensions:      1024 x 1024
#   Camera:          #535 - SIMPLE_RADIAL
#   Focal Length:    1228.80px
#   Features:        954
# Processed file [533/552]
#   Name:            22/000014.jpg
#   Dimensions:      1024 x 1024
#   Camera:          #543 - SIMPLE_RADIAL
#   Focal Length:    1228.80px
#   Features:        953
# Processed file [534/552]
#   Name:            22/000004.jpg
#   Dimensions:      1024 x 1024
#   Camera:          #533 - SIMPLE_RADIAL
#   Focal Length:    1228.80px
#   Features:        962
# Processed file [535/552]
#   Name:            22/000010.jpg
#   Dimensions:      1024 x 1024
#   Camera:          #539 - SIMPLE_RADIAL
#   Focal Length:    1228.80px
#   Features:        969
# Processed file [536/552]
#   Name:            22/000012.jpg
#   Dimensions:      1024 x 1024
#   Camera:          #541 - SIMPLE_RADIAL
#   Focal Length:    1228.80px
#   Features:        964
# Processed file [537/552]
#   Name:            22/000009.jpg
#   Dimensions:      1024 x 1024
#   Camera:          #538 - SIMPLE_RADIAL
#   Focal Length:    1228.80px
#   Features:        977
# Processed file [538/552]
#   Name:            22/000019.jpg
#   Dimensions:      1024 x 1024
#   Camera:          #548 - SIMPLE_RADIAL
#   Focal Length:    1228.80px
#   Features:        984
# Processed file [539/552]
#   Name:            22/000022.jpg
#   Dimensions:      1024 x 1024
#   Camera:          #551 - SIMPLE_RADIAL
#   Focal Length:    1228.80px
#   Features:        987
# Processed file [540/552]
#   Name:            22/000018.jpg
#   Dimensions:      1024 x 1024
#   Camera:          #547 - SIMPLE_RADIAL
#   Focal Length:    1228.80px
#   Features:        958
# Processed file [541/552]
#   Name:            22/000021.jpg
#   Dimensions:      1024 x 1024
#   Camera:          #550 - SIMPLE_RADIAL
#   Focal Length:    1228.80px
#   Features:        983
# Processed file [542/552]
#   Name:            22/000015.jpg
#   Dimensions:      1024 x 1024
#   Camera:          #544 - SIMPLE_RADIAL
#   Focal Length:    1228.80px
#   Features:        932
# Processed file [543/552]
#   Name:            22/000000.jpg
#   Dimensions:      1024 x 1024
#   Camera:          #529 - SIMPLE_RADIAL
#   Focal Length:    1228.80px
#   Features:        965
# Processed file [544/552]
#   Name:            22/000013.jpg
#   Dimensions:      1024 x 1024
#   Camera:          #542 - SIMPLE_RADIAL
#   Focal Length:    1228.80px
#   Features:        968
# Processed file [545/552]
#   Name:            22/000001.jpg
#   Dimensions:      1024 x 1024
#   Camera:          #530 - SIMPLE_RADIAL
#   Focal Length:    1228.80px
#   Features:        936
# Processed file [546/552]
#   Name:            22/000008.jpg
#   Dimensions:      1024 x 1024
#   Camera:          #537 - SIMPLE_RADIAL
#   Focal Length:    1228.80px
#   Features:        982
# Processed file [547/552]
#   Name:            22/000011.jpg
#   Dimensions:      1024 x 1024
#   Camera:          #540 - SIMPLE_RADIAL
#   Focal Length:    1228.80px
#   Features:        953
# Processed file [548/552]
#   Name:            22/000005.jpg
#   Dimensions:      1024 x 1024
#   Camera:          #534 - SIMPLE_RADIAL
#   Focal Length:    1228.80px
#   Features:        967
# Processed file [549/552]
#   Name:            22/000017.jpg
#   Dimensions:      1024 x 1024
#   Camera:          #546 - SIMPLE_RADIAL
#   Focal Length:    1228.80px
#   Features:        934
# Processed file [550/552]
#   Name:            22/000020.jpg
#   Dimensions:      1024 x 1024
#   Camera:          #549 - SIMPLE_RADIAL
#   Focal Length:    1228.80px
#   Features:        959
# Processed file [551/552]
#   Name:            22/000016.jpg
#   Dimensions:      1024 x 1024
#   Camera:          #545 - SIMPLE_RADIAL
#   Focal Length:    1228.80px
#   Features:        953
# Processed file [552/552]
#   Name:            22/000023.jpg
#   Dimensions:      1024 x 1024
#   Camera:          #552 - SIMPLE_RADIAL
#   Focal Length:    1228.80px
#   Features:        980
# Elapsed time: 0.676 [minutes]
# 0

# %% [markdown]
# #### Use the database as a reference to create images.txt

# %%
# This parts creates the images.txt using the ids from database

obj = CameraParametersExtractor(f"{rootdir}/extri.yml")
db = COLMAPDatabase.connect(database_path)
images_list = db.execute("SELECT image_id, name FROM images").fetchall()


names = obj.get_names()
camera_params = {}
image_params = {}
imageslst = []
for name in names:
    param = obj.get_extrinsic_params(name)
    camera_params[name] = list(map(str,[param["QW"], param["QX"], param["QY"], param["QZ"], param["TX"], param["TY"], param["TZ"]]))

for image in images_list:
    image_id, img_path = image
    cam_id = img_path.split("/")[0]
    param = [cam_id]
    param.extend(camera_params[cam_id])
    image_params[image_id] =param
    imageslst.append(
        f"{image_id} {' '.join(camera_params[cam_id])} {name} {img_path}"
    )
    imageslst.append("")

with open(f"{sparsedir}/images.txt", 'w') as file:
    for item in imageslst:
        file.write(f"{item}\n")

# Column names: ['image_id', 'name', 'camera_id', 'prior_qw', 'prior_qx', 'prior_qy', 'prior_qz', 'prior_tx', 'prior_ty', 'prior_tz']
# Connect to the database
# db = COLMAPDatabase.connect(database_path)

# for img_path, (img_id, cam_id, qw, qx, qy, qz, tx, ty, tz) in image_params.items():
#     # Update the camera parameters
#     db.execute("UPDATE images SET image_id=?, camera_id=?, prior_qw=?, prior_qx=?, prior_qy=?, prior_qz=?, prior_tx=?, prior_ty=?, prior_tz=? WHERE name=?", 
#                 (img_id, cam_id, qw, qx, qy, qz, tx, ty, tz, img_path))

db.commit()
db.close()

# %% [markdown]
# #### Create Camera.txt

# %%
# This parts creates the cameras.txt
# TODO - Read the intri.yml - Done
# TODO - Create a list with each line as CAMERA_ID, MODEL, WIDTH, HEIGHT, PARAMS[] - Done
# TODO - Save the text image - Done

int_obj = CameraParametersExtractor(f"{rootdir}/intri.yml")
names = int_obj.get_names()
camera_lst = []
for name in names:
    param = int_obj.get_intrinsic_params(name)
    camera_int = list(map(str,[name ,"SIMPLE_PINHOLE", 1024, 1024, param['focal_length'], param['px'], param['py']]))
    camera_lst.append(" ".join(camera_int))

with open(f"{sparsedir}/cameras.txt", 'w') as file:
    for item in camera_lst:
        file.write(f"{item}\n")

# %% [markdown]
# #### Copy the Contents of camera.txt to the database

# %%
# Using database.py to copy the camera's intrisic parameters
# The source of code - https://github.com/colmap/colmap/blob/main/scripts/python/database.py
from database import COLMAPDatabase, blob_to_array

# Adjust the paths according to your setup
db_path = f'{rootdir}/database.db'  # Path to your COLMAP database
cameras_txt_path = f'{sparsedir}/cameras.txt'  # Path to cameras.txt

# Function to read cameras.txt and return camera parameters
def read_cameras_txt(cameras_txt_path):
    camera_params = {}
    with open(cameras_txt_path, 'r') as file:
        for line in file:
            parts = line.strip().split()
            if len(parts) > 3:  # Simple check to skip incorrect lines
                camera_id = int(parts[0])
                model = parts[1]
                width = int(parts[2])
                height = int(parts[3])
                params = list(map(float, parts[4:]))
                camera_params[camera_id] = (model, width, height, params)
    return camera_params

camera_params = read_cameras_txt(cameras_txt_path)
    
def update_camera_parameters(db_path, camera_params):
    # Connect to the database
    db = COLMAPDatabase.connect(db_path)
    
    for camera_id, (model, width, height, params) in camera_params.items():
        # Convert parameters list to bytes
        params_bytes = COLMAPDatabase.add_camera(
            model=model,
        width=width,
        height=height,
        params=params,
        camera_id=camera_id
        )
        # Update the camera parameters
        db.execute("UPDATE cameras SET model=?, width=?, height=?, params=? WHERE camera_id=?", 
                   (model, width, height, params_bytes, camera_id))
    
    db.commit()
    db.close()

# %% [markdown]
# #### Run the feature Extractor

# %%
# Running the feaure mapper
command = f"colmap exhaustive_matcher \
            --database_path {rootdir}/database.db \
            --SiftMatching.use_gpu 0"

os.system(command)
# Out:
# ==============================================================================
# Exhaustive feature matching
# ==============================================================================
#
# Matching block [1/12, 1/12] in 7.445s
# Matching block [1/12, 2/12] in 13.212s
# Matching block [1/12, 3/12] in 7.801s
# Matching block [1/12, 4/12] in 12.691s
# Matching block [1/12, 5/12] in 14.141s
# Matching block [1/12, 6/12] in 12.870s
# Matching block [1/12, 7/12] in 9.865s
# Matching block [1/12, 8/12] in 14.880s
# Matching block [1/12, 9/12] in 16.168s
# Matching block [1/12, 10/12] in 9.192s
# Matching block [1/12, 11/12] in 13.332s
# Matching block [1/12, 12/12] in 0.364s
# Matching block [2/12, 1/12] in 10.502s
# Matching block [2/12, 2/12] in 7.707s
# Matching block [2/12, 3/12] in 7.649s
# Matching block [2/12, 4/12] in 13.093s
# Matching block [2/12, 5/12] in 14.069s
# Matching block [2/12, 6/12] in 13.286s
# Matching block [2/12, 7/12] in 12.909s
# Matching block [2/12, 8/12] in 15.435s
# Matching block [2/12, 9/12] in 16.033s
# Matching block [2/12, 10/12] in 8.637s
# Matching block [2/12, 11/12] in 14.230s
# Matching block [2/12, 12/12] in 0.350s
# Matching block [3/12, 1/12] in 10.183s
# Matching block [3/12, 2/12] in 6.379s
# Matching block [3/12, 3/12] in 4.415s
# Matching block [3/12, 4/12] in 8.838s
# Matching block [3/12, 5/12] in 9.400s
# Matching block [3/12, 6/12] in 8.490s
# Matching block [3/12, 7/12] in 9.362s
# Matching block [3/12, 8/12] in 10.587s
# Matching block [3/12, 9/12] in 11.400s
# Matching block [3/12, 10/12] in 6.016s
# Matching block [3/12, 11/12] in 9.423s
# Matching block [3/12, 12/12] in 0.307s
# Matching block [4/12, 1/12] in 14.115s
# Matching block [4/12, 2/12] in 12.824s
# Matching block [4/12, 3/12] in 6.144s
# Matching block [4/12, 4/12] in 7.474s
# Matching block [4/12, 5/12] in 12.553s
# Matching block [4/12, 6/12] in 12.719s
# Matching block [4/12, 7/12] in 13.393s
# Matching block [4/12, 8/12] in 14.642s
# Matching block [4/12, 9/12] in 14.536s
# Matching block [4/12, 10/12] in 8.244s
# Matching block [4/12, 11/12] in 12.220s
# Matching block [4/12, 12/12] in 0.243s
# Matching block [5/12, 1/12] in 14.468s
# Matching block [5/12, 2/12] in 14.395s
# Matching block [5/12, 3/12] in 13.609s
# Matching block [5/12, 4/12] in 10.823s
# Matching block [5/12, 5/12] in 8.358s
# Matching block [5/12, 6/12] in 12.349s
# Matching block [5/12, 7/12] in 14.479s
# Matching block [5/12, 8/12] in 14.969s
# Matching block [5/12, 9/12] in 15.446s
# Matching block [5/12, 10/12] in 8.337s
# Matching block [5/12, 11/12] in 13.206s
# Matching block [5/12, 12/12] in 0.318s
# Matching block [6/12, 1/12] in 14.873s
# Matching block [6/12, 2/12] in 12.024s
# Matching block [6/12, 3/12] in 7.513s
# Matching block [6/12, 4/12] in 12.758s
# Matching block [6/12, 5/12] in 10.674s
# Matching block [6/12, 6/12] in 7.214s
# Matching block [6/12, 7/12] in 12.824s
# Matching block [6/12, 8/12] in 15.291s
# Matching block [6/12, 9/12] in 15.795s
# Matching block [6/12, 10/12] in 7.622s
# Matching block [6/12, 11/12] in 13.191s
# Matching block [6/12, 12/12] in 0.355s
# Matching block [7/12, 1/12] in 13.021s
# Matching block [7/12, 2/12] in 12.524s
# Matching block [7/12, 3/12] in 7.834s
# Matching block [7/12, 4/12] in 13.639s
# Matching block [7/12, 5/12] in 14.691s
# Matching block [7/12, 6/12] in 8.922s
# Matching block [7/12, 7/12] in 6.666s
# Matching block [7/12, 8/12] in 13.478s
# Matching block [7/12, 9/12] in 16.210s
# Matching block [7/12, 10/12] in 7.822s
# Matching block [7/12, 11/12] in 12.644s
# Matching block [7/12, 12/12] in 0.229s
# Matching block [8/12, 1/12] in 13.543s
# Matching block [8/12, 2/12] in 13.519s
# Matching block [8/12, 3/12] in 8.591s
# Matching block [8/12, 4/12] in 14.056s
# Matching block [8/12, 5/12] in 15.715s
# Matching block [8/12, 6/12] in 14.407s
# Matching block [8/12, 7/12] in 9.156s
# Matching block [8/12, 8/12] in 8.513s
# Matching block [8/12, 9/12] in 15.729s
# Matching block [8/12, 10/12] in 8.238s
# Matching block [8/12, 11/12] in 13.705s
# Matching block [8/12, 12/12] in 0.362s
# Matching block [9/12, 1/12] in 17.475s
# Matching block [9/12, 2/12] in 16.605s
# Matching block [9/12, 3/12] in 9.828s
# Matching block [9/12, 4/12] in 15.089s
# Matching block [9/12, 5/12] in 16.885s
# Matching block [9/12, 6/12] in 16.580s
# Matching block [9/12, 7/12] in 16.978s
# Matching block [9/12, 8/12] in 12.760s
# Matching block [9/12, 9/12] in 10.461s
# Matching block [9/12, 10/12] in 10.389s
# Matching block [9/12, 11/12] in 15.418s
# Matching block [9/12, 12/12] in 0.383s
# Matching block [10/12, 1/12] in 10.765s
# Matching block [10/12, 2/12] in 9.794s
# Matching block [10/12, 3/12] in 6.128s
# Matching block [10/12, 4/12] in 9.361s
# Matching block [10/12, 5/12] in 9.885s
# Matching block [10/12, 6/12] in 8.525s
# Matching block [10/12, 7/12] in 9.627s
# Matching block [10/12, 8/12] in 10.204s
# Matching block [10/12, 9/12] in 8.330s
# Matching block [10/12, 10/12] in 4.452s
# Matching block [10/12, 11/12] in 9.425s
# Matching block [10/12, 12/12] in 0.430s
# Matching block [11/12, 1/12] in 11.320s
# Matching block [11/12, 2/12] in 10.052s
# Matching block [11/12, 3/12] in 5.787s
# Matching block [11/12, 4/12] in 10.234s
# Matching block [11/12, 5/12] in 10.542s
# Matching block [11/12, 6/12] in 9.886s
# Matching block [11/12, 7/12] in 10.128s
# Matching block [11/12, 8/12] in 10.661s
# Matching block [11/12, 9/12] in 11.761s
# Matching block [11/12, 10/12] in 6.379s
# Matching block [11/12, 11/12] in 6.237s
# Matching block [11/12, 12/12] in 0.218s
# Matching block [12/12, 1/12] in 1.630s
# Matching block [12/12, 2/12] in 1.603s
# Matching block [12/12, 3/12] in 1.137s
# Matching block [12/12, 4/12] in 1.357s
# Matching block [12/12, 5/12] in 1.468s
# Matching block [12/12, 6/12] in 1.440s
# Matching block [12/12, 7/12] in 1.451s
# Matching block [12/12, 8/12] in 1.623s
# Matching block [12/12, 9/12] in 1.732s
# Matching block [12/12, 10/12] in 1.117s
# Matching block [12/12, 11/12] in 0.761s
# Matching block [12/12, 12/12] in 0.162s
# Elapsed time: 23.333 [minutes]
# 0

# %% [markdown]
# #### Run the Image Undistorter

# %%
commd = f"colmap image_undistorter \
    --image_path {imagedir}\
    --input_path {sparsedir} \
    --output_path {outputdir}"

os.system(commd)
# Out:
# ==============================================================================
# Reading reconstruction
# ==============================================================================
#
#  => Reconstruction with 552 images and 0 points
#
# ==============================================================================
# Image undistortion
# ==============================================================================
#
# Undistorted image found; copying to location: data/mocap_small/images/00/000000.jpg
# Undistorted image found; copying to location: Undistorted image found; copying to location: data/mocap_small/images/00/000005.jpgdata/mocap_small/images/00/000006.jpg
#
# Undistorted image found; copying to location: data/mocap_small/images/00/000003.jpg
# Undistorted image found; copying to location: Undistorted image found; copying to location: data/mocap_small/images/00/000012.jpg
# Undistorted image found; copying to location: Undistorted image found; copying to location: data/mocap_small/images/00/000015.jpg
# data/mocap_small/images/00/000008.jpgUndistorted image found; copying to location: Undistorted image found; copying to location: Undistorted image found; copying to location: data/mocap_small/images/00/000007.jpgUndistorted image found; copying to location: Undistorted image found; copying to location:
# Undistorted image found; copying to location: data/mocap_small/images/00/000011.jpgdata/mocap_small/images/00/000019.jpgdata/mocap_small/images/00/000010.jpgUndistorted image found; copying to location: Undistorted image found; copying to location: data/mocap_small/images/00/000017.jpgdata/mocap_small/images/00/000004.jpgUndistorted image found; copying to location: Undistorted image found; copying to location: data/mocap_small/images/00/000002.jpgdata/mocap_small/images/00/000014.jpg
#
# data/mocap_small/images/00/000001.jpg
#
#
#
# data/mocap_small/images/00/000016.jpgUndistorted image found; copying to location: data/mocap_small/images/00/000021.jpg
# Undistorted image found; copying to location: data/mocap_small/images/00/000022.jpgUndistorted image found; copying to location:
# Undistorted image found; copying to location:
# data/mocap_small/images/01/000000.jpg
#
#
# Undistorted image found; copying to location: Undistorted image found; copying to location: Undistorted image found; copying to location: data/mocap_small/images/00/000009.jpg
# data/mocap_small/images/01/000007.jpg
# Undistorted image found; copying to location: data/mocap_small/images/00/000013.jpgUndistorted image found; copying to location: Undistorted image found; copying to location: data/mocap_small/images/01/000011.jpg
# data/mocap_small/images/01/000003.jpgUndistorted image found; copying to location: Undistorted image found; copying to location: data/mocap_small/images/01/000012.jpgdata/mocap_small/images/00/000018.jpg
# Undistorted image found; copying to location:
# Undistorted image found; copying to location: Undistorted image found; copying to location:
# data/mocap_small/images/01/000008.jpgdata/mocap_small/images/01/000006.jpg
# Undistorted image found; copying to location:
# Undistorted image found; copying to location: data/mocap_small/images/01/000009.jpg
# data/mocap_small/images/01/000001.jpgUndistorted image found; copying to location: data/mocap_small/images/01/000005.jpg
# data/mocap_small/images/01/000004.jpgdata/mocap_small/images/01/000002.jpg
# Undistorted image found; copying to location: Undistorted image found; copying to location: data/mocap_small/images/00/000020.jpg
#
#
# Undistorted image found; copying to location: data/mocap_small/images/01/000015.jpg
# data/mocap_small/images/01/000013.jpgdata/mocap_small/images/01/000014.jpg
#
#
#
# Undistorted image found; copying to location: data/mocap_small/images/00/000023.jpg
# Undistorting image [1/552]
# data/mocap_small/images/01/000010.jpg
# Undistorting image [2/552]
# Undistorted image found; copying to location: data/mocap_small/images/01/000016.jpg
# Undistorted image found; copying to location: data/mocap_small/images/01/000018.jpgUndistorted image found; copying to location:
# data/mocap_small/images/01/000017.jpg
# Undistorted image found; copying to location: Undistorted image found; copying to location: data/mocap_small/images/01/000021.jpgdata/mocap_small/images/02/000000.jpg
#
# Undistorted image found; copying to location: data/mocap_small/images/02/000001.jpgUndistorted image found; copying to location: Undistorted image found; copying to location: data/mocap_small/images/02/000007.jpg
# Undistorted image found; copying to location: data/mocap_small/images/01/000019.jpg
# Undistorted image found; copying to location: data/mocap_small/images/02/000009.jpgUndistorted image found; copying to location: Undistorted image found; copying to location: Undistorted image found; copying to location: Undistorted image found; copying to location: Undistorted image found; copying to location: data/mocap_small/images/01/000020.jpg
# Undistorted image found; copying to location: data/mocap_small/images/01/000022.jpgUndistorted image found; copying to location: Undistorted image found; copying to location: data/mocap_small/images/02/000019.jpgUndistorted image found; copying to location: Undistorted image found; copying to location: Undistorted image found; copying to location: Undistorted image found; copying to location: data/mocap_small/images/02/000022.jpgdata/mocap_small/images/02/000015.jpgUndistorted image found; copying to location: Undistorted image found; copying to location: Undistorted image found; copying to location: Undistorted image found; copying to location: data/mocap_small/images/03/000000.jpg
#
# Undistorted image found; copying to location: data/mocap_small/images/02/000003.jpg
# Undistorted image found; copying to location:
# Undistorted image found; copying to location: data/mocap_small/images/02/000011.jpgdata/mocap_small/images/02/000014.jpgdata/mocap_small/images/03/000004.jpgUndistorted image found; copying to location: Undistorted image found; copying to location:
# Undistorted image found; copying to location:
# data/mocap_small/images/02/000006.jpgdata/mocap_small/images/03/000003.jpgUndistorted image found; copying to location: data/mocap_small/images/01/000023.jpg
# Undistorted image found; copying to location: Undistorting image [3/552]data/mocap_small/images/02/000021.jpgUndistorted image found; copying to location: data/mocap_small/images/03/000001.jpg
#
# Undistorted image found; copying to location: data/mocap_small/images/02/000017.jpg
# data/mocap_small/images/02/000010.jpg
#
# data/mocap_small/images/03/000005.jpgdata/mocap_small/images/02/000023.jpgdata/mocap_small/images/02/000020.jpg
# data/mocap_small/images/02/000002.jpg
# Undistorted image found; copying to location: data/mocap_small/images/02/000008.jpg
# Undistorted image found; copying to location: data/mocap_small/images/03/000007.jpg
#
#
# data/mocap_small/images/02/000018.jpgdata/mocap_small/images/02/000012.jpg
# data/mocap_small/images/02/000016.jpg
# data/mocap_small/images/02/000005.jpg
#
#
#
# Undistorting image [4/552]
# data/mocap_small/images/02/000013.jpg
#
# data/mocap_small/images/02/000004.jpgUndistorted image found; copying to location:
#
# data/mocap_small/images/03/000006.jpg
#
#
# Undistorted image found; copying to location: Undistorting image [5/552]
#
# Undistorting image [6/552]
# Undistorting image [7/552]
# Undistorting image [8/552]
# Undistorting image [9/552]
# data/mocap_small/images/03/000002.jpg
# Undistorting image [10/552]
# Undistorting image [11/552]
# Undistorting image [12/552]
# Undistorting image [13/552]
# Undistorting image [14/552]
# Undistorting image [15/552]
# Undistorting image [16/552]
# Undistorting image [17/552]
# Undistorting image [18/552]
# Undistorting image [19/552]
# Undistorting image [20/552]
# Undistorting image [21/552]
# Undistorting image [22/552]
# Undistorting image [23/552]
# Undistorting image [24/552]
# Undistorting image [25/552]
# Undistorting image [26/552]
# Undistorting image [27/552]
# Undistorting image [28/552]
# Undistorting image [29/552]
# Undistorting image [30/552]
# Undistorting image [31/552]
# Undistorting image [32/552]
# Undistorting image [33/552]
# Undistorting image [34/552]
# Undistorting image [35/552]
# Undistorting image [36/552]
# Undistorting image [37/552]
# Undistorting image [38/552]
# Undistorting image [39/552]
# Undistorting image [40/552]
# Undistorting image [41/552]
# Undistorted image found; copying to location: data/mocap_small/images/03/000008.jpg
# Undistorting image [42/552]
# Undistorted image found; copying to location: data/mocap_small/images/03/000009.jpg
# Undistorted image found; copying to location: data/mocap_small/images/03/000010.jpg
# Undistorted image found; copying to location: data/mocap_small/images/03/000011.jpg
# Undistorted image found; copying to location: data/mocap_small/images/03/000012.jpg
# Undistorted image found; copying to location: Undistorted image found; copying to location: Undistorted image found; copying to location: data/mocap_small/images/03/000014.jpg
# Undistorted image found; copying to location: data/mocap_small/images/03/000013.jpgdata/mocap_small/images/03/000021.jpg
# Undistorted image found; copying to location: Undistorted image found; copying to location: Undistorted image found; copying to location: data/mocap_small/images/03/000020.jpgdata/mocap_small/images/03/000023.jpg
# data/mocap_small/images/03/000017.jpgUndistorted image found; copying to location:
#
#
# Undistorted image found; copying to location: Undistorted image found; copying to location: Undistorting image [43/552]Undistorted image found; copying to location: data/mocap_small/images/04/000003.jpgUndistorted image found; copying to location: data/mocap_small/images/03/000018.jpgUndistorted image found; copying to location: Undistorted image found; copying to location: data/mocap_small/images/03/000016.jpg
# data/mocap_small/images/04/000002.jpgdata/mocap_small/images/04/000004.jpg
# Undistorted image found; copying to location:
# data/mocap_small/images/04/000000.jpg
#
# Undistorted image found; copying to location: Undistorted image found; copying to location: data/mocap_small/images/04/000005.jpg
# Undistorted image found; copying to location: data/mocap_small/images/04/000001.jpgdata/mocap_small/images/03/000019.jpg
#
#
# Undistorted image found; copying to location: data/mocap_small/images/04/000007.jpg
# data/mocap_small/images/03/000022.jpg
#
# data/mocap_small/images/03/000015.jpgdata/mocap_small/images/04/000006.jpg
#
# Undistorted image found; copying to location: data/mocap_small/images/04/000008.jpg
# Undistorted image found; copying to location: data/mocap_small/images/04/000009.jpg
# Undistorted image found; copying to location: data/mocap_small/images/04/000010.jpg
# Undistorted image found; copying to location: Undistorting image [44/552]
# Undistorted image found; copying to location: Undistorted image found; copying to location: Undistorted image found; copying to location: Undistorting image [45/552]
# data/mocap_small/images/04/000018.jpg
# Undistorting image [46/552]Undistorted image found; copying to location: data/mocap_small/images/04/000013.jpgUndistorted image found; copying to location:
# Undistorted image found; copying to location: data/mocap_small/images/04/000023.jpgUndistorted image found; copying to location:
# Undistorted image found; copying to location: Undistorted image found; copying to location: data/mocap_small/images/04/000019.jpgdata/mocap_small/images/04/000014.jpgdata/mocap_small/images/04/000011.jpgdata/mocap_small/images/04/000015.jpgUndistorted image found; copying to location: Undistorted image found; copying to location:
# Undistorted image found; copying to location:
#
# data/mocap_small/images/04/000016.jpgUndistorted image found; copying to location: data/mocap_small/images/04/000022.jpgUndistorting image [47/552]
# data/mocap_small/images/04/000020.jpg
#
# data/mocap_small/images/04/000017.jpgdata/mocap_small/images/04/000021.jpgUndistorting image [48/552]
#
#
#
# data/mocap_small/images/05/000000.jpgdata/mocap_small/images/04/000012.jpg
#
#
#
# Undistorting image [49/552]
# Undistorting image [50/552]
# Undistorting image [51/552]
# Undistorting image [52/552]
# Undistorting image [53/552]
# Undistorting image [54/552]
# Undistorting image [55/552]
# Undistorting image [56/552]
# Undistorting image [57/552]
# Undistorting image [58/552]
# Undistorting image [59/552]
# Undistorting image [60/552]
# Undistorting image [61/552]
# Undistorting image [62/552]
# Undistorting image [63/552]
# Undistorting image [64/552]
# Undistorting image [65/552]
# Undistorting image [66/552]
# Undistorting image [67/552]
# Undistorting image [68/552]
# Undistorting image [69/552]
# Undistorting image [70/552]
# Undistorting image [71/552]
# Undistorting image [72/552]
# Undistorting image [73/552]
# Undistorting image [74/552]
# Undistorting image [75/552]
# Undistorting image [76/552]
# Undistorting image [77/552]
# Undistorting image [78/552]
# Undistorting image [79/552]
# Undistorting image [80/552]
# Undistorting image [81/552]
# Undistorting image [82/552]
# Undistorted image found; copying to location: data/mocap_small/images/05/000001.jpg
# Undistorted image found; copying to location: data/mocap_small/images/05/000003.jpg
# Undistorted image found; copying to location: data/mocap_small/images/05/000004.jpg
# Undistorted image found; copying to location: Undistorted image found; copying to location: data/mocap_small/images/05/000002.jpg
# Undistorted image found; copying to location: Undistorting image [83/552]Undistorted image found; copying to location: Undistorted image found; copying to location: data/mocap_small/images/05/000011.jpgUndistorted image found; copying to location: data/mocap_small/images/05/000010.jpg
# data/mocap_small/images/05/000012.jpgUndistorted image found; copying to location: data/mocap_small/images/05/000008.jpg
# data/mocap_small/images/05/000009.jpgUndistorted image found; copying to location: Undistorted image found; copying to location:
#
#
# data/mocap_small/images/05/000005.jpgdata/mocap_small/images/05/000007.jpg
# data/mocap_small/images/05/000006.jpg
#
#
# Undistorting image [84/552]
# Undistorting image [85/552]
# Undistorting image [86/552]
# Undistorted image found; copying to location: data/mocap_small/images/05/000013.jpg
# Undistorted image found; copying to location: data/mocap_small/images/05/000014.jpg
# Undistorted image found; copying to location: data/mocap_small/images/05/000015.jpg
# Undistorting image [87/552]
# Undistorted image found; copying to location: data/mocap_small/images/05/000017.jpg
# Undistorted image found; copying to location: Undistorted image found; copying to location: data/mocap_small/images/05/000019.jpgUndistorted image found; copying to location: data/mocap_small/images/05/000016.jpg
# data/mocap_small/images/05/000018.jpgUndistorted image found; copying to location:
# Undistorted image found; copying to location: Undistorted image found; copying to location: Undistorted image found; copying to location: Undistorting image [88/552]data/mocap_small/images/06/000000.jpg
# Undistorted image found; copying to location:
# Undistorted image found; copying to location: data/mocap_small/images/06/000003.jpg
#
# data/mocap_small/images/06/000002.jpgdata/mocap_small/images/05/000020.jpgdata/mocap_small/images/05/000021.jpgUndistorted image found; copying to location: data/mocap_small/images/05/000022.jpgUndistorting image [89/552]Undistorted image found; copying to location:
#
# data/mocap_small/images/06/000001.jpg
#
#
# Undistorting image [90/552]
# Undistorting image [91/552]
#
# data/mocap_small/images/05/000023.jpg
# Undistorting image [92/552]
# Undistorting image [93/552]
# Undistorting image [94/552]
# Undistorting image [95/552]
# Undistorting image [96/552]
# Undistorting image [97/552]
# Undistorting image [98/552]
# Undistorting image [99/552]
# Undistorting image [100/552]
# Undistorting image [101/552]
# Undistorting image [102/552]
# Undistorting image [103/552]
# Undistorting image [104/552]
# Undistorting image [105/552]
# Undistorting image [106/552]
# Undistorting image [107/552]
# Undistorting image [108/552]
# Undistorted image found; copying to location: data/mocap_small/images/06/000004.jpg
# Undistorted image found; copying to location: data/mocap_small/images/06/000006.jpg
# Undistorted image found; copying to location: data/mocap_small/images/06/000009.jpg
# Undistorted image found; copying to location: Undistorted image found; copying to location: Undistorted image found; copying to location: data/mocap_small/images/06/000008.jpgdata/mocap_small/images/06/000007.jpgdata/mocap_small/images/06/000010.jpgUndistorted image found; copying to location:
# Undistorted image found; copying to location: data/mocap_small/images/06/000011.jpgUndistorted image found; copying to location:
# Undistorted image found; copying to location: Undistorted image found; copying to location: Undistorted image found; copying to location: Undistorted image found; copying to location: Undistorted image found; copying to location: data/mocap_small/images/07/000002.jpgdata/mocap_small/images/06/000005.jpgUndistorted image found; copying to location: Undistorted image found; copying to location: data/mocap_small/images/06/000017.jpgdata/mocap_small/images/06/000012.jpg
# Undistorted image found; copying to location: data/mocap_small/images/06/000019.jpgUndistorted image found; copying to location: Undistorted image found; copying to location:
# data/mocap_small/images/07/000000.jpg
# data/mocap_small/images/07/000004.jpgdata/mocap_small/images/07/000001.jpg
#
# Undistorted image found; copying to location: data/mocap_small/images/06/000013.jpg
# Undistorted image found; copying to location: Undistorted image found; copying to location: data/mocap_small/images/06/000015.jpgdata/mocap_small/images/06/000016.jpgdata/mocap_small/images/06/000020.jpg
#
# Undistorted image found; copying to location: data/mocap_small/images/06/000021.jpgdata/mocap_small/images/06/000014.jpgUndistorted image found; copying to location: data/mocap_small/images/06/000022.jpg
#
#
#
# data/mocap_small/images/06/000023.jpg
#
#
#
# data/mocap_small/images/06/000018.jpg
#
# Undistorted image found; copying to location: data/mocap_small/images/07/000003.jpg
#
# Undistorting image [109/552]
# Undistorting image [110/552]
# Undistorting image [111/552]
# Undistorting image [112/552]
# Undistorting image [113/552]
# Undistorting image [114/552]
# Undistorting image [115/552]
# Undistorting image [116/552]
# Undistorting image [117/552]
# Undistorting image [118/552]
# Undistorting image [119/552]
# Undistorting image [120/552]
# Undistorting image [121/552]
# Undistorting image [122/552]
# Undistorting image [123/552]
# Undistorting image [124/552]
# Undistorting image [125/552]
# Undistorting image [126/552]
# Undistorting image [127/552]
# Undistorting image [128/552]
# Undistorting image [129/552]
# Undistorting image [130/552]
# Undistorting image [131/552]
# Undistorting image [132/552]
# Undistorting image [133/552]
# Undistorting image [134/552]
# Undistorted image found; copying to location: data/mocap_small/images/07/000005.jpg
# Undistorted image found; copying to location: Undistorted image found; copying to location: Undistorted image found; copying to location: data/mocap_small/images/07/000009.jpgUndistorted image found; copying to location: data/mocap_small/images/07/000008.jpg
# data/mocap_small/images/07/000006.jpg
# Undistorted image found; copying to location: Undistorted image found; copying to location: Undistorted image found; copying to location: Undistorted image found; copying to location: Undistorted image found; copying to location: data/mocap_small/images/07/000013.jpgUndistorted image found; copying to location: Undistorted image found; copying to location: data/mocap_small/images/07/000021.jpgUndistorted image found; copying to location:
# data/mocap_small/images/08/000000.jpgdata/mocap_small/images/07/000007.jpg
# data/mocap_small/images/07/000022.jpgUndistorted image found; copying to location: Undistorted image found; copying to location: data/mocap_small/images/07/000023.jpgUndistorted image found; copying to location: data/mocap_small/images/08/000002.jpg
# Undistorted image found; copying to location: data/mocap_small/images/08/000004.jpgdata/mocap_small/images/07/000012.jpgUndistorted image found; copying to location: Undistorted image found; copying to location: Undistorted image found; copying to location:
# data/mocap_small/images/07/000020.jpgUndistorted image found; copying to location: Undistorted image found; copying to location: data/mocap_small/images/07/000015.jpgUndistorted image found; copying to location:
# Undistorting image [135/552]data/mocap_small/images/08/000010.jpgUndistorted image found; copying to location: Undistorted image found; copying to location: Undistorted image found; copying to location: Undistorted image found; copying to location:
# data/mocap_small/images/08/000015.jpg
# Undistorted image found; copying to location:
# Undistorted image found; copying to location:
# Undistorted image found; copying to location:
# Undistorted image found; copying to location: data/mocap_small/images/07/000017.jpgdata/mocap_small/images/07/000011.jpg
# data/mocap_small/images/08/000006.jpg
# data/mocap_small/images/08/000020.jpgUndistorted image found; copying to location: Undistorted image found; copying to location: data/mocap_small/images/08/000011.jpgdata/mocap_small/images/08/000014.jpgdata/mocap_small/images/07/000019.jpg
# data/mocap_small/images/08/000009.jpg
#
# data/mocap_small/images/07/000016.jpgUndistorted image found; copying to location: data/mocap_small/images/08/000003.jpgUndistorted image found; copying to location:
#
# data/mocap_small/images/08/000001.jpgdata/mocap_small/images/08/000019.jpg
# Undistorted image found; copying to location: Undistorted image found; copying to location:
# Undistorting image [136/552]data/mocap_small/images/07/000014.jpgdata/mocap_small/images/08/000018.jpg
# Undistorted image found; copying to location:
#
#
# Undistorted image found; copying to location:
#
# data/mocap_small/images/07/000018.jpgdata/mocap_small/images/08/000007.jpgdata/mocap_small/images/08/000013.jpgdata/mocap_small/images/08/000017.jpgdata/mocap_small/images/08/000005.jpgdata/mocap_small/images/07/000010.jpg
#
#
# data/mocap_small/images/08/000016.jpg
#
#
# Undistorted image found; copying to location:
#
#
#
# Undistorting image [137/552]
#
#
# Undistorting image [138/552]
# data/mocap_small/images/08/000008.jpg
# Undistorting image [139/552]data/mocap_small/images/08/000012.jpg
#
# Undistorting image [140/552]
# Undistorting image [141/552]
# Undistorting image [142/552]
# Undistorting image [143/552]
# Undistorting image [144/552]
# Undistorting image [145/552]
# Undistorting image [146/552]
# Undistorting image [147/552]
# Undistorting image [148/552]
# Undistorting image [149/552]
# Undistorting image [150/552]
# Undistorting image [151/552]
# Undistorting image [152/552]
# Undistorting image [153/552]
# Undistorting image [154/552]
# Undistorting image [155/552]
# Undistorting image [156/552]
# Undistorting image [157/552]
# Undistorting image [158/552]
# Undistorting image [159/552]
# Undistorting image [160/552]
# Undistorting image [161/552]
# Undistorting image [162/552]
# Undistorting image [163/552]
# Undistorting image [164/552]
# Undistorting image [165/552]
# Undistorting image [166/552]
# Undistorting image [167/552]
# Undistorting image [168/552]
# Undistorting image [169/552]
# Undistorting image [170/552]
# Undistorting image [171/552]
# Undistorting image [172/552]
# Undistorting image [173/552]
# Undistorting image [174/552]
# Undistorted image found; copying to location: data/mocap_small/images/08/000021.jpg
# Undistorting image [175/552]
# Undistorted image found; copying to location: Undistorted image found; copying to location: data/mocap_small/images/08/000023.jpgdata/mocap_small/images/08/000022.jpg
# Undistorted image found; copying to location: Undistorted image found; copying to location: data/mocap_small/images/09/000005.jpgUndistorted image found; copying to location: Undistorted image found; copying to location:
# data/mocap_small/images/09/000010.jpgUndistorted image found; copying to location: Undistorted image found; copying to location: Undistorted image found; copying to location: Undistorted image found; copying to location: data/mocap_small/images/09/000019.jpg
# Undistorted image found; copying to location:
# data/mocap_small/images/09/000016.jpgUndistorted image found; copying to location: data/mocap_small/images/09/000013.jpgUndistorted image found; copying to location: Undistorted image found; copying to location: Undistorted image found; copying to location: Undistorted image found; copying to location: Undistorted image found; copying to location: data/mocap_small/images/09/000014.jpg
# data/mocap_small/images/09/000012.jpg
# Undistorting image [176/552]Undistorted image found; copying to location: data/mocap_small/images/09/000006.jpg
# data/mocap_small/images/09/000009.jpgdata/mocap_small/images/09/000011.jpg
#
#
#
# Undistorted image found; copying to location: data/mocap_small/images/09/000001.jpgUndistorted image found; copying to location: Undistorted image found; copying to location: Undistorted image found; copying to location: data/mocap_small/images/09/000008.jpgdata/mocap_small/images/09/000000.jpg
# Undistorted image found; copying to location: data/mocap_small/images/09/000004.jpg
#
# data/mocap_small/images/09/000015.jpg
# data/mocap_small/images/09/000007.jpgdata/mocap_small/images/09/000003.jpgdata/mocap_small/images/09/000020.jpg
#
# data/mocap_small/images/09/000002.jpg
# data/mocap_small/images/09/000017.jpg
#
#
# data/mocap_small/images/09/000018.jpg
#
#
# Undistorted image found; copying to location: data/mocap_small/images/09/000022.jpg
# Undistorted image found; copying to location: data/mocap_small/images/09/000021.jpg
# Undistorted image found; copying to location: data/mocap_small/images/10/000000.jpg
# Undistorted image found; copying to location: data/mocap_small/images/10/000001.jpgUndistorted image found; copying to location:
# Undistorted image found; copying to location: Undistorted image found; copying to location: data/mocap_small/images/10/000004.jpg
# Undistorted image found; copying to location: Undistorting image [177/552]data/mocap_small/images/10/000002.jpgUndistorted image found; copying to location: data/mocap_small/images/09/000023.jpgdata/mocap_small/images/10/000005.jpg
#
# Undistorted image found; copying to location: Undistorted image found; copying to location: Undistorted image found; copying to location:
# data/mocap_small/images/10/000010.jpgUndistorted image found; copying to location: Undistorted image found; copying to location: data/mocap_small/images/10/000003.jpg
# Undistorted image found; copying to location:
# data/mocap_small/images/10/000009.jpgdata/mocap_small/images/10/000007.jpgdata/mocap_small/images/10/000008.jpg
# Undistorting image [178/552]Undistorted image found; copying to location:
# Undistorted image found; copying to location: data/mocap_small/images/10/000012.jpg
# data/mocap_small/images/10/000006.jpgdata/mocap_small/images/10/000013.jpg
# Undistorting image [179/552]
#
# data/mocap_small/images/10/000011.jpg
#
#
#
# Undistorting image [180/552]
# Undistorting image [181/552]
# Undistorting image [182/552]
# Undistorting image [183/552]
# Undistorting image [184/552]
# Undistorting image [185/552]
# Undistorting image [186/552]
# Undistorting image [187/552]
# Undistorting image [188/552]
# Undistorting image [189/552]
# Undistorting image [190/552]
# Undistorting image [191/552]
# Undistorting image [192/552]
# Undistorting image [193/552]
# Undistorting image [194/552]
# Undistorting image [195/552]
# Undistorting image [196/552]
# Undistorting image [197/552]
# Undistorting image [198/552]
# Undistorting image [199/552]
# Undistorting image [200/552]
# Undistorting image [201/552]
# Undistorting image [202/552]
# Undistorting image [203/552]
# Undistorting image [204/552]
# Undistorting image [205/552]
# Undistorting image [206/552]
# Undistorting image [207/552]
# Undistorting image [208/552]
# Undistorting image [209/552]
# Undistorting image [210/552]
# Undistorting image [211/552]
# Undistorting image [212/552]
# Undistorting image [213/552]
# Undistorting image [214/552]
# Undistorting image [215/552]
# Undistorted image found; copying to location: data/mocap_small/images/10/000014.jpg
# Undistorted image found; copying to location: data/mocap_small/images/10/000018.jpg
# Undistorting image [216/552]Undistorted image found; copying to location: data/mocap_small/images/10/000017.jpg
#
# Undistorted image found; copying to location: Undistorted image found; copying to location: Undistorted image found; copying to location: Undistorted image found; copying to location: data/mocap_small/images/11/000000.jpg
# Undistorted image found; copying to location: data/mocap_small/images/10/000015.jpgUndistorted image found; copying to location: data/mocap_small/images/10/000021.jpg
#
# Undistorting image [217/552]data/mocap_small/images/11/000002.jpgUndistorted image found; copying to location: Undistorted image found; copying to location:
#
# data/mocap_small/images/10/000023.jpgUndistorted image found; copying to location: Undistorted image found; copying to location: Undistorted image found; copying to location: Undistorted image found; copying to location: data/mocap_small/images/10/000022.jpgUndistorting image [218/552]
# Undistorted image found; copying to location: data/mocap_small/images/11/000009.jpgUndistorted image found; copying to location: Undistorted image found; copying to location: data/mocap_small/images/10/000019.jpgdata/mocap_small/images/10/000016.jpgdata/mocap_small/images/11/000001.jpg
# Undistorted image found; copying to location:
# data/mocap_small/images/11/000012.jpgUndistorted image found; copying to location: data/mocap_small/images/11/000004.jpgUndistorting image [219/552]data/mocap_small/images/11/000008.jpg
# data/mocap_small/images/11/000010.jpg
#
#
# Undistorted image found; copying to location:
#
#
# data/mocap_small/images/11/000007.jpgdata/mocap_small/images/11/000003.jpg
# data/mocap_small/images/11/000006.jpgdata/mocap_small/images/10/000020.jpg
# Undistorting image [220/552]
# Undistorted image found; copying to location:
# Undistorted image found; copying to location: data/mocap_small/images/11/000011.jpgdata/mocap_small/images/11/000005.jpg
#
#
#
#
# Undistorting image [221/552]
# Undistorting image [222/552]
# Undistorting image [223/552]
# Undistorting image [224/552]
# Undistorting image [225/552]
# Undistorting image [226/552]
# Undistorting image [227/552]
# Undistorting image [228/552]
# Undistorting image [229/552]
# Undistorting image [230/552]
# Undistorting image [231/552]
# Undistorting image [232/552]
# Undistorting image [233/552]
# Undistorting image [234/552]
# Undistorting image [235/552]
# Undistorting image [236/552]
# Undistorting image [237/552]
# Undistorting image [238/552]
# Undistorted image found; copying to location: data/mocap_small/images/11/000013.jpg
# Undistorted image found; copying to location: data/mocap_small/images/11/000014.jpg
# Undistorted image found; copying to location: data/mocap_small/images/11/000015.jpg
# Undistorted image found; copying to location: Undistorting image [239/552]data/mocap_small/images/11/000016.jpg
#
# Undistorted image found; copying to location: Undistorted image found; copying to location: data/mocap_small/images/11/000021.jpgUndistorted image found; copying to location: Undistorted image found; copying to location: Undistorted image found; copying to location: Undistorting image [240/552]
# Undistorted image found; copying to location: Undistorted image found; copying to location: data/mocap_small/images/12/000003.jpgUndistorted image found; copying to location: data/mocap_small/images/11/000020.jpgdata/mocap_small/images/12/000001.jpgdata/mocap_small/images/12/000004.jpg
# Undistorted image found; copying to location: data/mocap_small/images/11/000023.jpgdata/mocap_small/images/11/000017.jpg
# Undistorted image found; copying to location: data/mocap_small/images/11/000019.jpgUndistorted image found; copying to location: data/mocap_small/images/12/000005.jpg
# Undistorted image found; copying to location: Undistorting image [241/552]
# data/mocap_small/images/11/000018.jpg
#
# Undistorted image found; copying to location: data/mocap_small/images/12/000000.jpg
#
# Undistorting image [242/552]
#
#
#
# data/mocap_small/images/12/000002.jpg
# data/mocap_small/images/11/000022.jpg
# Undistorting image [243/552]
# Undistorting image [244/552]
#
# Undistorting image [245/552]
# Undistorting image [246/552]
# Undistorting image [247/552]
# Undistorting image [248/552]
# Undistorting image [249/552]
# Undistorting image [250/552]
# Undistorting image [251/552]
# Undistorting image [252/552]
# Undistorting image [253/552]
# Undistorting image [254/552]
# Undistorting image [255/552]
# Undistorted image found; copying to location: data/mocap_small/images/12/000006.jpg
# Undistorted image found; copying to location: data/mocap_small/images/12/000008.jpg
# Undistorted image found; copying to location: Undistorted image found; copying to location: data/mocap_small/images/12/000010.jpg
# Undistorted image found; copying to location: data/mocap_small/images/12/000013.jpg
# Undistorting image [256/552]
# Undistorted image found; copying to location: Undistorted image found; copying to location: Undistorted image found; copying to location: data/mocap_small/images/12/000015.jpg
# Undistorting image [257/552]Undistorted image found; copying to location: Undistorted image found; copying to location: Undistorted image found; copying to location: Undistorted image found; copying to location:
# Undistorted image found; copying to location: Undistorted image found; copying to location: Undistorted image found; copying to location: Undistorted image found; copying to location: Undistorted image found; copying to location: Undistorted image found; copying to location: Undistorted image found; copying to location: data/mocap_small/images/13/000001.jpgdata/mocap_small/images/12/000017.jpg
# data/mocap_small/images/12/000021.jpgUndistorted image found; copying to location: data/mocap_small/images/12/000014.jpgUndistorted image found; copying to location: Undistorted image found; copying to location: data/mocap_small/images/13/000004.jpgdata/mocap_small/images/12/000016.jpg
# data/mocap_small/images/13/000000.jpgdata/mocap_small/images/12/000023.jpgdata/mocap_small/images/12/000018.jpgdata/mocap_small/images/13/000003.jpgdata/mocap_small/images/12/000012.jpgUndistorted image found; copying to location:
#
# data/mocap_small/images/12/000007.jpg
# data/mocap_small/images/13/000002.jpgdata/mocap_small/images/12/000020.jpg
# data/mocap_small/images/12/000022.jpg
# data/mocap_small/images/12/000011.jpg
#
#
#
# Undistorting image [258/552]
# data/mocap_small/images/12/000009.jpg
# data/mocap_small/images/12/000019.jpg
#
#
#
# Undistorting image [259/552]
#
# Undistorting image [260/552]
# Undistorting image [261/552]
# Undistorting image [262/552]
#
# Undistorting image [263/552]
# Undistorting image [264/552]
# Undistorting image [265/552]
# Undistorting image [266/552]
# Undistorting image [267/552]
# Undistorting image [268/552]
# Undistorting image [269/552]
# Undistorting image [270/552]
# Undistorting image [271/552]
# Undistorting image [272/552]
# Undistorting image [273/552]
# Undistorting image [274/552]
# Undistorting image [275/552]
# Undistorting image [276/552]
# Undistorting image [277/552]
# Undistorting image [278/552]
# Undistorted image found; copying to location: data/mocap_small/images/13/000005.jpg
# Undistorted image found; copying to location: data/mocap_small/images/13/000006.jpg
# Undistorting image [279/552]
# Undistorted image found; copying to location: data/mocap_small/images/13/000010.jpg
# Undistorted image found; copying to location: Undistorted image found; copying to location: Undistorted image found; copying to location: Undistorting image [280/552]Undistorted image found; copying to location: Undistorted image found; copying to location: Undistorted image found; copying to location: Undistorted image found; copying to location: data/mocap_small/images/13/000020.jpg
#
# Undistorted image found; copying to location: data/mocap_small/images/13/000019.jpg
# data/mocap_small/images/13/000015.jpgUndistorted image found; copying to location: Undistorted image found; copying to location: Undistorted image found; copying to location: data/mocap_small/images/13/000012.jpgUndistorted image found; copying to location: data/mocap_small/images/13/000014.jpgdata/mocap_small/images/13/000017.jpgdata/mocap_small/images/13/000007.jpg
# data/mocap_small/images/13/000013.jpg
# data/mocap_small/images/13/000011.jpgUndistorted image found; copying to location: data/mocap_small/images/13/000016.jpgdata/mocap_small/images/13/000009.jpg
#
# data/mocap_small/images/13/000018.jpgUndistorted image found; copying to location:
#
#
#
#
# data/mocap_small/images/13/000008.jpg
#
# Undistorting image [281/552]data/mocap_small/images/13/000021.jpg
# Undistorting image [282/552]
# Undistorting image [283/552]
#
# Undistorting image [284/552]
# Undistorting image [285/552]
# Undistorting image [286/552]
# Undistorting image [287/552]
# Undistorting image [288/552]
# Undistorting image [289/552]
# Undistorting image [290/552]
# Undistorting image [291/552]
# Undistorting image [292/552]
# Undistorting image [293/552]
# Undistorting image [294/552]
# Undistorting image [295/552]
# Undistorting image [296/552]
# Undistorted image found; copying to location: Undistorted image found; copying to location: data/mocap_small/images/14/000004.jpg
# data/mocap_small/images/14/000000.jpgUndistorted image found; copying to location: Undistorted image found; copying to location: Undistorted image found; copying to location: Undistorted image found; copying to location: data/mocap_small/images/13/000022.jpg
# Undistorted image found; copying to location: data/mocap_small/images/14/000003.jpgUndistorted image found; copying to location: Undistorting image [297/552]
# data/mocap_small/images/14/000011.jpg
#
# Undistorted image found; copying to location: data/mocap_small/images/14/000015.jpgUndistorted image found; copying to location: Undistorted image found; copying to location: Undistorted image found; copying to location:
# Undistorted image found; copying to location: Undistorted image found; copying to location: Undistorted image found; copying to location:
# Undistorted image found; copying to location: Undistorted image found; copying to location: data/mocap_small/images/14/000010.jpg
# data/mocap_small/images/14/000008.jpgdata/mocap_small/images/14/000005.jpgdata/mocap_small/images/14/000014.jpgdata/mocap_small/images/13/000023.jpg
# Undistorted image found; copying to location: data/mocap_small/images/14/000006.jpgdata/mocap_small/images/14/000013.jpgUndistorting image [298/552]data/mocap_small/images/14/000009.jpgUndistorted image found; copying to location:
#
# data/mocap_small/images/14/000018.jpgUndistorted image found; copying to location:
#
#
# Undistorted image found; copying to location: data/mocap_small/images/14/000019.jpg
# data/mocap_small/images/14/000001.jpg
# Undistorting image [299/552]
# data/mocap_small/images/14/000020.jpgdata/mocap_small/images/14/000002.jpgUndistorted image found; copying to location: data/mocap_small/images/14/000012.jpgdata/mocap_small/images/14/000017.jpg
#
#
#
# data/mocap_small/images/14/000016.jpgUndistorted image found; copying to location:
# Undistorting image [300/552]
#
#
# data/mocap_small/images/14/000007.jpg
# Undistorting image [301/552]
# Undistorting image [302/552]
#
# Undistorting image [303/552]
# Undistorting image [304/552]
# Undistorting image [305/552]
# Undistorting image [306/552]
# Undistorting image [307/552]
# Undistorting image [308/552]
# Undistorting image [309/552]
# Undistorting image [310/552]
# Undistorting image [311/552]
# Undistorting image [312/552]
# Undistorting image [313/552]
# Undistorting image [314/552]
# Undistorting image [315/552]
# Undistorting image [316/552]
# Undistorting image [317/552]
# Undistorting image [318/552]
# Undistorted image found; copying to location: data/mocap_small/images/14/000022.jpgUndistorted image found; copying to location:
# data/mocap_small/images/14/000021.jpg
# Undistorted image found; copying to location: data/mocap_small/images/14/000023.jpg
# Undistorted image found; copying to location: data/mocap_small/images/15/000000.jpg
# Undistorted image found; copying to location: data/mocap_small/images/15/000001.jpgUndistorted image found; copying to location: data/mocap_small/images/15/000003.jpg
#
# Undistorting image [319/552]Undistorted image found; copying to location: data/mocap_small/images/15/000007.jpgUndistorted image found; copying to location:
#
# Undistorted image found; copying to location: Undistorted image found; copying to location: data/mocap_small/images/15/000002.jpgUndistorted image found; copying to location: data/mocap_small/images/15/000013.jpg
# Undistorted image found; copying to location: Undistorted image found; copying to location: Undistorted image found; copying to location: data/mocap_small/images/15/000012.jpgdata/mocap_small/images/15/000006.jpgUndistorted image found; copying to location:
# Undistorted image found; copying to location: data/mocap_small/images/15/000005.jpgdata/mocap_small/images/15/000008.jpgdata/mocap_small/images/15/000004.jpgUndistorted image found; copying to location:
# Undistorting image [320/552]
#
#
# data/mocap_small/images/15/000010.jpgdata/mocap_small/images/15/000009.jpg
#
#
#
# data/mocap_small/images/15/000011.jpg
# Undistorting image [321/552]
# Undistorting image [322/552]
# Undistorting image [323/552]
# Undistorting image [324/552]
# Undistorting image [325/552]
# Undistorting image [326/552]
# Undistorting image [327/552]
# Undistorting image [328/552]
# Undistorting image [329/552]
# Undistorting image [330/552]
# Undistorting image [331/552]
# Undistorting image [332/552]
# Undistorting image [333/552]
# Undistorting image [334/552]
# Undistorting image [335/552]
# Undistorted image found; copying to location: data/mocap_small/images/15/000014.jpg
# Undistorted image found; copying to location: data/mocap_small/images/15/000015.jpgUndistorted image found; copying to location:
# data/mocap_small/images/15/000021.jpgUndistorted image found; copying to location: Undistorted image found; copying to location: data/mocap_small/images/15/000017.jpgdata/mocap_small/images/15/000016.jpg
# Undistorted image found; copying to location: Undistorted image found; copying to location: Undistorted image found; copying to location: Undistorting image [336/552]Undistorted image found; copying to location: data/mocap_small/images/15/000023.jpg
#
# Undistorted image found; copying to location: Undistorted image found; copying to location: data/mocap_small/images/15/000019.jpgUndistorted image found; copying to location: Undistorted image found; copying to location: Undistorted image found; copying to location: Undistorted image found; copying to location:
# Undistorted image found; copying to location:
# data/mocap_small/images/16/000002.jpgUndistorted image found; copying to location:
# data/mocap_small/images/16/000007.jpg
# data/mocap_small/images/15/000022.jpg
# Undistorted image found; copying to location: data/mocap_small/images/16/000004.jpgdata/mocap_small/images/15/000020.jpgUndistorted image found; copying to location: Undistorted image found; copying to location: data/mocap_small/images/16/000011.jpgUndistorted image found; copying to location: data/mocap_small/images/16/000012.jpgdata/mocap_small/images/16/000003.jpg
# data/mocap_small/images/16/000006.jpg
#
# data/mocap_small/images/16/000010.jpg
#
#
# Undistorted image found; copying to location: data/mocap_small/images/15/000018.jpgdata/mocap_small/images/16/000000.jpgdata/mocap_small/images/16/000009.jpgUndistorting image [337/552]
# data/mocap_small/images/16/000001.jpgUndistorted image found; copying to location:
#
#
#
#
# data/mocap_small/images/16/000005.jpg
# data/mocap_small/images/16/000008.jpg
# Undistorting image [338/552]
#
# Undistorting image [339/552]
# Undistorting image [340/552]
# Undistorting image [341/552]
# Undistorting image [342/552]
# Undistorting image [343/552]
# Undistorting image [344/552]
# Undistorting image [345/552]
# Undistorting image [346/552]
# Undistorting image [347/552]
# Undistorting image [348/552]
# Undistorting image [349/552]
# Undistorting image [350/552]
# Undistorting image [351/552]
# Undistorting image [352/552]
# Undistorting image [353/552]
# Undistorting image [354/552]
# Undistorting image [355/552]
# Undistorting image [356/552]
# Undistorting image [357/552]
# Undistorting image [358/552]
# Undistorted image found; copying to location: data/mocap_small/images/16/000014.jpg
# Undistorted image found; copying to location: data/mocap_small/images/16/000016.jpgUndistorted image found; copying to location: Undistorted image found; copying to location: Undistorted image found; copying to location: data/mocap_small/images/16/000019.jpgUndistorted image found; copying to location: data/mocap_small/images/16/000018.jpgUndistorted image found; copying to location: data/mocap_small/images/16/000023.jpg
# Undistorting image [359/552]data/mocap_small/images/16/000020.jpg
# Undistorted image found; copying to location: data/mocap_small/images/16/000017.jpg
# data/mocap_small/images/16/000015.jpg
#
#
#
# Undistorted image found; copying to location:
# Undistorted image found; copying to location: data/mocap_small/images/16/000021.jpg
# Undistorted image found; copying to location: data/mocap_small/images/17/000005.jpgdata/mocap_small/images/17/000002.jpgUndistorting image [360/552]
# Undistorted image found; copying to location: Undistorted image found; copying to location: Undistorting image [361/552]
# data/mocap_small/images/17/000000.jpgUndistorted image found; copying to location:
# data/mocap_small/images/17/000004.jpgUndistorted image found; copying to location:
# data/mocap_small/images/16/000022.jpg
#
# Undistorted image found; copying to location: data/mocap_small/images/17/000003.jpg
# Undistorting image [362/552]
# data/mocap_small/images/16/000013.jpgUndistorting image [363/552]
#
#
# Undistorted image found; copying to location: data/mocap_small/images/17/000001.jpgUndistorting image [364/552]
#
# Undistorting image [365/552]
# Undistorting image [366/552]
# Undistorting image [367/552]
# Undistorting image [368/552]
# Undistorting image [369/552]
# Undistorting image [370/552]
# Undistorting image [371/552]
# Undistorting image [372/552]
# Undistorting image [373/552]
# Undistorting image [374/552]
# Undistorting image [375/552]
# Undistorted image found; copying to location: data/mocap_small/images/17/000006.jpg
# Undistorting image [376/552]
# Undistorted image found; copying to location: data/mocap_small/images/17/000011.jpg
# Undistorting image [377/552]
# Undistorted image found; copying to location: Undistorted image found; copying to location: Undistorted image found; copying to location: Undistorted image found; copying to location: data/mocap_small/images/17/000012.jpgdata/mocap_small/images/17/000007.jpg
# Undistorted image found; copying to location: Undistorted image found; copying to location: data/mocap_small/images/17/000013.jpg
# Undistorted image found; copying to location: data/mocap_small/images/17/000020.jpgUndistorted image found; copying to location: data/mocap_small/images/17/000021.jpgUndistorted image found; copying to location:
#
# Undistorted image found; copying to location: Undistorted image found; copying to location: Undistorting image [378/552]data/mocap_small/images/17/000016.jpgUndistorted image found; copying to location: Undistorted image found; copying to location: data/mocap_small/images/17/000023.jpg
# Undistorted image found; copying to location: Undistorted image found; copying to location: data/mocap_small/images/17/000009.jpgUndistorted image found; copying to location: data/mocap_small/images/17/000022.jpgdata/mocap_small/images/17/000017.jpg
#
# Undistorted image found; copying to location:
# data/mocap_small/images/18/000000.jpgUndistorted image found; copying to location: Undistorted image found; copying to location: data/mocap_small/images/18/000001.jpgdata/mocap_small/images/17/000015.jpg
#
# data/mocap_small/images/17/000019.jpgdata/mocap_small/images/17/000008.jpg
#
#
#
# data/mocap_small/images/17/000018.jpgdata/mocap_small/images/17/000010.jpg
# data/mocap_small/images/17/000014.jpgUndistorted image found; copying to location:
#
# Undistorted image found; copying to location: data/mocap_small/images/18/000004.jpg
# data/mocap_small/images/18/000003.jpg
# data/mocap_small/images/18/000002.jpg
# Undistorting image [379/552]
#
# Undistorting image [380/552]
# Undistorting image [381/552]
#
# Undistorting image [382/552]
# Undistorting image [383/552]
# Undistorting image [384/552]
# Undistorting image [385/552]
# Undistorting image [386/552]
# Undistorting image [387/552]
# Undistorting image [388/552]
# Undistorting image [389/552]
# Undistorting image [390/552]
# Undistorting image [391/552]
# Undistorting image [392/552]
# Undistorting image [393/552]
# Undistorting image [394/552]
# Undistorting image [395/552]
# Undistorting image [396/552]
# Undistorting image [397/552]
# Undistorting image [398/552]
# Undistorted image found; copying to location: data/mocap_small/images/18/000005.jpg
# Undistorted image found; copying to location: data/mocap_small/images/18/000006.jpg
# Undistorted image found; copying to location: data/mocap_small/images/18/000008.jpg
# Undistorted image found; copying to location: data/mocap_small/images/18/000009.jpg
# Undistorted image found; copying to location: Undistorted image found; copying to location: data/mocap_small/images/18/000007.jpgdata/mocap_small/images/18/000010.jpg
#
# Undistorted image found; copying to location: data/mocap_small/images/18/000012.jpg
# Undistorted image found; copying to location: Undistorted image found; copying to location: data/mocap_small/images/18/000017.jpgUndistorted image found; copying to location: Undistorted image found; copying to location: Undistorted image found; copying to location: Undistorted image found; copying to location: data/mocap_small/images/18/000016.jpg
#
# Undistorted image found; copying to location: Undistorted image found; copying to location: data/mocap_small/images/18/000015.jpgdata/mocap_small/images/18/000019.jpgdata/mocap_small/images/18/000013.jpgdata/mocap_small/images/18/000020.jpgdata/mocap_small/images/18/000018.jpgUndistorted image found; copying to location:
#
#
# Undistorted image found; copying to location: Undistorting image [399/552]
#
# data/mocap_small/images/18/000014.jpg
# data/mocap_small/images/18/000021.jpg
#
# data/mocap_small/images/18/000011.jpg
# Undistorting image [400/552]
# Undistorting image [401/552]
# Undistorting image [402/552]
# Undistorting image [403/552]
# Undistorting image [404/552]
# Undistorting image [405/552]
# Undistorting image [406/552]
# Undistorting image [407/552]
# Undistorting image [408/552]
# Undistorting image [409/552]
# Undistorting image [410/552]
# Undistorting image [411/552]
# Undistorting image [412/552]
# Undistorting image [413/552]
# Undistorting image [414/552]
# Undistorting image [415/552]
# Undistorted image found; copying to location: data/mocap_small/images/18/000022.jpg
# Undistorted image found; copying to location: data/mocap_small/images/18/000023.jpg
# Undistorted image found; copying to location: data/mocap_small/images/19/000004.jpg
# Undistorted image found; copying to location: Undistorted image found; copying to location: Undistorted image found; copying to location: data/mocap_small/images/19/000000.jpgdata/mocap_small/images/19/000003.jpg
# Undistorted image found; copying to location: data/mocap_small/images/19/000001.jpgUndistorted image found; copying to location: Undistorted image found; copying to location: Undistorting image [416/552]Undistorted image found; copying to location: Undistorted image found; copying to location: Undistorted image found; copying to location: data/mocap_small/images/19/000002.jpg
#
# Undistorted image found; copying to location: data/mocap_small/images/19/000009.jpgUndistorting image [417/552]
# Undistorted image found; copying to location:
# data/mocap_small/images/19/000005.jpgUndistorted image found; copying to location: data/mocap_small/images/19/000011.jpgUndistorting image [418/552]
# data/mocap_small/images/19/000012.jpgdata/mocap_small/images/19/000010.jpgUndistorted image found; copying to location:
#
# Undistorted image found; copying to location: data/mocap_small/images/19/000006.jpgdata/mocap_small/images/19/000008.jpg
#
# data/mocap_small/images/19/000015.jpgUndistorted image found; copying to location:
#
#
#
#
# data/mocap_small/images/19/000007.jpgdata/mocap_small/images/19/000014.jpg
# data/mocap_small/images/19/000013.jpg
#
# Undistorted image found; copying to location: Undistorted image found; copying to location: data/mocap_small/images/19/000019.jpg
# Undistorted image found; copying to location: data/mocap_small/images/19/000018.jpg
# Undistorted image found; copying to location: Undistorted image found; copying to location: Undistorted image found; copying to location: data/mocap_small/images/20/000006.jpgUndistorted image found; copying to location:
# Undistorted image found; copying to location: Undistorted image found; copying to location: Undistorted image found; copying to location: data/mocap_small/images/20/000000.jpgdata/mocap_small/images/20/000002.jpg
# Undistorted image found; copying to location: Undistorted image found; copying to location: Undistorted image found; copying to location: Undistorted image found; copying to location: data/mocap_small/images/20/000005.jpgdata/mocap_small/images/19/000016.jpg
# data/mocap_small/images/20/000003.jpgdata/mocap_small/images/20/000012.jpgUndistorted image found; copying to location:
# Undistorted image found; copying to location: Undistorted image found; copying to location:
# data/mocap_small/images/20/000010.jpgdata/mocap_small/images/20/000001.jpg
# Undistorted image found; copying to location: data/mocap_small/images/20/000011.jpgdata/mocap_small/images/20/000008.jpgUndistorted image found; copying to location: data/mocap_small/images/19/000020.jpgUndistorted image found; copying to location:
#
# data/mocap_small/images/20/000013.jpgUndistorted image found; copying to location: data/mocap_small/images/19/000021.jpg
# data/mocap_small/images/19/000023.jpgUndistorting image [419/552]
# data/mocap_small/images/19/000017.jpg
#
# Undistorted image found; copying to location: data/mocap_small/images/20/000007.jpgdata/mocap_small/images/19/000022.jpgdata/mocap_small/images/20/000009.jpg
#
#
#
#
# data/mocap_small/images/20/000004.jpg
#
#
# Undistorting image [420/552]
#
# Undistorting image [421/552]
# Undistorting image [422/552]
# Undistorting image [423/552]
# Undistorting image [424/552]
# Undistorting image [425/552]
# Undistorting image [426/552]
# Undistorting image [427/552]
# Undistorting image [428/552]
# Undistorting image [429/552]
# Undistorting image [430/552]
# Undistorting image [431/552]
# Undistorting image [432/552]
# Undistorting image [433/552]
# Undistorting image [434/552]
# Undistorting image [435/552]
# Undistorting image [436/552]
# Undistorting image [437/552]
# Undistorting image [438/552]
# Undistorting image [439/552]
# Undistorting image [440/552]
# Undistorting image [441/552]
# Undistorting image [442/552]
# Undistorting image [443/552]
# Undistorting image [444/552]
# Undistorting image [445/552]
# Undistorting image [446/552]
# Undistorting image [447/552]
# Undistorting image [448/552]
# Undistorting image [449/552]
# Undistorting image [450/552]
# Undistorting image [451/552]
# Undistorting image [452/552]
# Undistorting image [453/552]
# Undistorting image [454/552]
# Undistorting image [455/552]
# Undistorted image found; copying to location: data/mocap_small/images/20/000015.jpgUndistorted image found; copying to location:
# data/mocap_small/images/20/000014.jpgUndistorted image found; copying to location: data/mocap_small/images/20/000017.jpg
#
# Undistorted image found; copying to location: Undistorted image found; copying to location: Undistorted image found; copying to location: Undistorted image found; copying to location: data/mocap_small/images/20/000021.jpgUndistorted image found; copying to location: Undistorted image found; copying to location: Undistorted image found; copying to location: data/mocap_small/images/20/000018.jpgdata/mocap_small/images/20/000022.jpgdata/mocap_small/images/21/000001.jpg
#
# Undistorting image [456/552]Undistorted image found; copying to location:
# data/mocap_small/images/20/000023.jpgUndistorted image found; copying to location: Undistorted image found; copying to location: data/mocap_small/images/21/000000.jpg
# Undistorted image found; copying to location:
# data/mocap_small/images/20/000019.jpgdata/mocap_small/images/21/000005.jpg
#
#
#
# Undistorted image found; copying to location: Undistorted image found; copying to location: Undistorted image found; copying to location: data/mocap_small/images/21/000003.jpgdata/mocap_small/images/21/000004.jpgdata/mocap_small/images/21/000002.jpgdata/mocap_small/images/20/000020.jpg
#
# Undistorted image found; copying to location: Undistorting image [457/552]
#
#
# Undistorting image [458/552]data/mocap_small/images/20/000016.jpgdata/mocap_small/images/21/000007.jpgdata/mocap_small/images/21/000006.jpg
#
#
#
# Undistorting image [459/552]
# Undistorting image [460/552]
# Undistorting image [461/552]
# Undistorting image [462/552]
# Undistorting image [463/552]
# Undistorting image [464/552]
# Undistorting image [465/552]
# Undistorting image [466/552]
# Undistorting image [467/552]
# Undistorting image [468/552]
# Undistorting image [469/552]
# Undistorting image [470/552]
# Undistorting image [471/552]
# Undistorting image [472/552]
# Undistorting image [473/552]
# Undistorted image found; copying to location: data/mocap_small/images/21/000009.jpg
# Undistorted image found; copying to location: data/mocap_small/images/21/000010.jpg
# Undistorted image found; copying to location: data/mocap_small/images/21/000008.jpg
# Undistorted image found; copying to location: data/mocap_small/images/21/000011.jpg
# Undistorted image found; copying to location: data/mocap_small/images/21/000013.jpg
# Undistorted image found; copying to location: data/mocap_small/images/21/000014.jpg
# Undistorted image found; copying to location: data/mocap_small/images/21/000012.jpgUndistorting image [474/552]
# Undistorted image found; copying to location: Undistorted image found; copying to location: Undistorted image found; copying to location: data/mocap_small/images/21/000017.jpgUndistorted image found; copying to location:
# data/mocap_small/images/22/000000.jpgUndistorting image [475/552]
# data/mocap_small/images/21/000021.jpgUndistorted image found; copying to location: Undistorted image found; copying to location: Undistorted image found; copying to location: Undistorted image found; copying to location: Undistorted image found; copying to location: data/mocap_small/images/21/000023.jpgUndistorted image found; copying to location: data/mocap_small/images/21/000020.jpgUndistorted image found; copying to location: Undistorted image found; copying to location: data/mocap_small/images/22/000001.jpg
# Undistorted image found; copying to location: data/mocap_small/images/22/000006.jpg
#
# Undistorted image found; copying to location: Undistorted image found; copying to location: data/mocap_small/images/22/000003.jpgUndistorted image found; copying to location: Undistorted image found; copying to location: data/mocap_small/images/22/000016.jpgUndistorted image found; copying to location: Undistorted image found; copying to location:
# Undistorted image found; copying to location: data/mocap_small/images/22/000018.jpg
#
# data/mocap_small/images/21/000022.jpgdata/mocap_small/images/22/000004.jpg
# Undistorted image found; copying to location: data/mocap_small/images/22/000009.jpg
#
# data/mocap_small/images/22/000014.jpg
# Undistorted image found; copying to location: data/mocap_small/images/22/000012.jpgdata/mocap_small/images/21/000016.jpgdata/mocap_small/images/21/000015.jpgUndistorted image found; copying to location: data/mocap_small/images/22/000005.jpgdata/mocap_small/images/21/000018.jpgUndistorted image found; copying to location: Undistorted image found; copying to location: data/mocap_small/images/22/000002.jpgUndistorting image [476/552]data/mocap_small/images/22/000008.jpgUndistorted image found; copying to location:
#
#
# Undistorted image found; copying to location: data/mocap_small/images/22/000020.jpg
#
#
# data/mocap_small/images/22/000023.jpg
# Undistorted image found; copying to location: data/mocap_small/images/22/000010.jpg
#
# Undistorted image found; copying to location: data/mocap_small/images/21/000019.jpgUndistorted image found; copying to location:
# data/mocap_small/images/22/000007.jpgUndistorted image found; copying to location: data/mocap_small/images/22/000013.jpg
# Undistorted image found; copying to location:
# data/mocap_small/images/22/000021.jpg
#
# data/mocap_small/images/22/000015.jpg
#
#
# Undistorting image [477/552]
# data/mocap_small/images/22/000011.jpg
#
# Undistorted image found; copying to location: data/mocap_small/images/22/000017.jpg
# data/mocap_small/images/22/000022.jpg
# data/mocap_small/images/22/000019.jpg
#
#
# Undistorting image [478/552]
# Undistorting image [479/552]
# Undistorting image [480/552]
# Undistorting image [481/552]
# Undistorting image [482/552]
# Undistorting image [483/552]
# Undistorting image [484/552]
# Undistorting image [485/552]
# Undistorting image [486/552]
# Undistorting image [487/552]
# Undistorting image [488/552]
# Undistorting image [489/552]
# Undistorting image [490/552]
# Undistorting image [491/552]
# Undistorting image [492/552]
# Undistorting image [493/552]
# Undistorting image [494/552]
# Undistorting image [495/552]
# Undistorting image [496/552]
# Undistorting image [497/552]
# Undistorting image [498/552]
# Undistorting image [499/552]
# Undistorting image [500/552]
# Undistorting image [501/552]
# Undistorting image [502/552]
# Undistorting image [503/552]
# Undistorting image [504/552]
# Undistorting image [505/552]
# Undistorting image [506/552]
# Undistorting image [507/552]
# Undistorting image [508/552]
# Undistorting image [509/552]
# Undistorting image [510/552]
# Undistorting image [511/552]
# Undistorting image [512/552]
# Undistorting image [513/552]
# Undistorting image [514/552]
# Undistorting image [515/552]
# Undistorting image [516/552]
# Undistorting image [517/552]
# Undistorting image [518/552]
# Undistorting image [519/552]
# Undistorting image [520/552]
# Undistorting image [521/552]
# Undistorting image [522/552]
# Undistorting image [523/552]
# Undistorting image [524/552]
# Undistorting image [525/552]
# Undistorting image [526/552]
# Undistorting image [527/552]
# Undistorting image [528/552]
# Undistorting image [529/552]
# Undistorting image [530/552]
# Undistorting image [531/552]
# Undistorting image [532/552]
# Undistorting image [533/552]
# Undistorting image [534/552]
# Undistorting image [535/552]
# Undistorting image [536/552]
# Undistorting image [537/552]
# Undistorting image [538/552]
# Undistorting image [539/552]
# Undistorting image [540/552]
# Undistorting image [541/552]
# Undistorting image [542/552]
# Undistorting image [543/552]
# Undistorting image [544/552]
# Undistorting image [545/552]
# Undistorting image [546/552]
# Undistorting image [547/552]
# Undistorting image [548/552]
# Undistorting image [549/552]
# Undistorting image [550/552]
# Undistorting image [551/552]
# Undistorting image [552/552]
# Writing reconstruction...
# Writing configuration...
# Writing scripts...
# Elapsed time: 0.036 [minutes]
# 0

# %% [markdown]
# #### Extra Code

# %%
command = f"colmap point_triangulator \
    --database_path {rootdir}/database.db \
    --image_path {imagedir}\
    --input_path  {sparsedir}\
    --output_path {sparsedir}"
os.system(command)
# Out:
# ==============================================================================
# Loading model
# ==============================================================================
#
#
# ==============================================================================
# Loading database
# ==============================================================================
#
# Loading cameras... 552 in 0.000s
# Loading matches... 138824 in 0.235s
# Loading images... 552 in 0.023s (connected 552)
# Building correspondence graph... in 1.375s (ignored 0)
#
# Elapsed time: 0.027 [minutes]
#
#
# ==============================================================================
# Triangulating image #549 (0)
# ==============================================================================
#
#   => Image sees 0 / 952 points
#   => Triangulated 658 points
#
# ==============================================================================
# Triangulating image #548 (1)
# ==============================================================================
#
#   => Image sees 546 / 954 points
#   => Triangulated 152 points
#
# ==============================================================================
# Triangulating image #540 (2)
# ==============================================================================
#
#   => Image sees 642 / 959 points
#   => Triangulated 106 points
#
# ==============================================================================
# Triangulating image #550 (3)
# ==============================================================================
#
#   => Image sees 685 / 941 points
#   => Triangulated 81 points
#
# ==============================================================================
# Triangulating image #552 (4)
# ==============================================================================
#
#   => Image sees 726 / 970 points
#   => Triangulated 70 points
#
# ==============================================================================
# Triangulating image #551 (5)
# ==============================================================================
#
#   => Image sees 731 / 939 points
#   => Triangulated 55 points
#
# ==============================================================================
# Triangulating image #545 (6)
# ==============================================================================
#
#   => Image sees 745 / 924 points
#   => Triangulated 36 points
#
# ==============================================================================
# Triangulating image #538 (7)
# ==============================================================================
#
#   => Image sees 761 / 937 points
#   => Triangulated 38 points
#
# ==============================================================================
# Triangulating image #539 (8)
# ==============================================================================
#
#   => Image sees 762 / 924 points
#   => Triangulated 36 points
#
# ==============================================================================
# Triangulating image #541 (9)
# ==============================================================================
#
#   => Image sees 775 / 939 points
#   => Triangulated 39 points
#
# ==============================================================================
# Triangulating image #543 (10)
# ==============================================================================
#
#   => Image sees 794 / 946 points
#   => Triangulated 27 points
#
# ==============================================================================
# Triangulating image #256 (11)
# ==============================================================================
#
#   => Image sees 78 / 735 points
#   => Triangulated 508 points
#
# ==============================================================================
# Triangulating image #257 (12)
# ==============================================================================
#
#   => Image sees 497 / 726 points
#   => Triangulated 119 points
#
# ==============================================================================
# Triangulating image #254 (13)
# ==============================================================================
#
#   => Image sees 540 / 702 points
#   => Triangulated 70 points
#
# ==============================================================================
# Triangulating image #255 (14)
# ==============================================================================
#
#   => Image sees 563 / 715 points
#   => Triangulated 64 points
#
# ==============================================================================
# Triangulating image #253 (15)
# ==============================================================================
#
#   => Image sees 603 / 723 points
#   => Triangulated 38 points
#
# ==============================================================================
# Triangulating image #248 (16)
# ==============================================================================
#
#   => Image sees 616 / 736 points
#   => Triangulated 47 points
#
# ==============================================================================
# Triangulating image #247 (17)
# ==============================================================================
#
#   => Image sees 604 / 706 points
#   => Triangulated 31 points
#
# ==============================================================================
# Triangulating image #252 (18)
# ==============================================================================
#
#   => Image sees 619 / 711 points
#   => Triangulated 25 points
#
# ==============================================================================
# Triangulating image #244 (19)
# ==============================================================================
#
#   => Image sees 615 / 711 points
#   => Triangulated 24 points
#
# ==============================================================================
# Triangulating image #242 (20)
# ==============================================================================
#
#   => Image sees 619 / 718 points
#   => Triangulated 31 points
#
# ==============================================================================
# Triangulating image #249 (21)
# ==============================================================================
#
#   => Image sees 627 / 722 points
#   => Triangulated 27 points
#
# ==============================================================================
# Triangulating image #251 (22)
# ==============================================================================
#
#   => Image sees 637 / 731 points
#   => Triangulated 29 points
#
# ==============================================================================
# Triangulating image #245 (23)
# ==============================================================================
#
#   => Image sees 623 / 722 points
#   => Triangulated 31 points
#
# ==============================================================================
# Triangulating image #246 (24)
# ==============================================================================
#
#   => Image sees 634 / 721 points
#   => Triangulated 23 points
#
# ==============================================================================
# Triangulating image #250 (25)
# ==============================================================================
#
#   => Image sees 640 / 726 points
#   => Triangulated 22 points
#
# ==============================================================================
# Triangulating image #243 (26)
# ==============================================================================
#
#   => Image sees 647 / 730 points
#   => Triangulated 19 points
#
# ==============================================================================
# Triangulating image #241 (27)
# ==============================================================================
#
#   => Image sees 646 / 734 points
#   => Triangulated 26 points
#
# ==============================================================================
# Triangulating image #239 (28)
# ==============================================================================
#
#   => Image sees 253 / 941 points
#   => Triangulated 505 points
#
# ==============================================================================
# Triangulating image #237 (29)
# ==============================================================================
#
#   => Image sees 606 / 928 points
#   => Triangulated 178 points
#
# ==============================================================================
# Triangulating image #231 (30)
# ==============================================================================
#
#   => Image sees 691 / 940 points
#   => Triangulated 132 points
#
# ==============================================================================
# Triangulating image #240 (31)
# ==============================================================================
#
#   => Image sees 735 / 952 points
#   => Triangulated 103 points
#
# ==============================================================================
# Triangulating image #232 (32)
# ==============================================================================
#
#   => Image sees 751 / 931 points
#   => Triangulated 78 points
#
# ==============================================================================
# Triangulating image #221 (33)
# ==============================================================================
#
#   => Image sees 749 / 920 points
#   => Triangulated 76 points
#
# ==============================================================================
# Triangulating image #220 (34)
# ==============================================================================
#
#   => Image sees 799 / 945 points
#   => Triangulated 62 points
#
# ==============================================================================
# Triangulating image #225 (35)
# ==============================================================================
#
#   => Image sees 778 / 919 points
#   => Triangulated 51 points
#
# ==============================================================================
# Triangulating image #233 (36)
# ==============================================================================
#
#   => Image sees 794 / 944 points
#   => Triangulated 58 points
#
# ==============================================================================
# Triangulating image #228 (37)
# ==============================================================================
#
#   => Image sees 784 / 934 points
#   => Triangulated 53 points
#
# ==============================================================================
# Triangulating image #229 (38)
# ==============================================================================
#
#   => Image sees 793 / 918 points
#   => Triangulated 46 points
#
# ==============================================================================
# Triangulating image #230 (39)
# ==============================================================================
#
#   => Image sees 810 / 941 points
#   => Triangulated 48 points
#
# ==============================================================================
# Triangulating image #219 (40)
# ==============================================================================
#
#   => Image sees 824 / 952 points
#   => Triangulated 52 points
#
# ==============================================================================
# Triangulating image #236 (41)
# ==============================================================================
#
#   => Image sees 795 / 924 points
#   => Triangulated 50 points
#
# ==============================================================================
# Triangulating image #223 (42)
# ==============================================================================
#
#   => Image sees 793 / 913 points
#   => Triangulated 53 points
#
# ==============================================================================
# Triangulating image #222 (43)
# ==============================================================================
#
#   => Image sees 840 / 967 points
#   => Triangulated 48 points
#
# ==============================================================================
# Triangulating image #227 (44)
# ==============================================================================
#
#   => Image sees 830 / 942 points
#   => Triangulated 40 points
#
# ==============================================================================
# Triangulating image #238 (45)
# ==============================================================================
#
#   => Image sees 812 / 930 points
#   => Triangulated 45 points
#
# ==============================================================================
# Triangulating image #224 (46)
# ==============================================================================
#
#   => Image sees 830 / 940 points
#   => Triangulated 38 points
#
# ==============================================================================
# Triangulating image #226 (47)
# ==============================================================================
#
#   => Image sees 825 / 920 points
#   => Triangulated 30 points
#
# ==============================================================================
# Triangulating image #235 (48)
# ==============================================================================
#
#   => Image sees 841 / 962 points
#   => Triangulated 38 points
#
# ==============================================================================
# Triangulating image #234 (49)
# ==============================================================================
#
#   => Image sees 797 / 900 points
#   => Triangulated 40 points
#
# ==============================================================================
# Triangulating image #218 (50)
# ==============================================================================
#
#   => Image sees 829 / 940 points
#   => Triangulated 38 points
#
# ==============================================================================
# Triangulating image #216 (51)
# ==============================================================================
#
#   => Image sees 839 / 936 points
#   => Triangulated 34 points
#
# ==============================================================================
# Triangulating image #217 (52)
# ==============================================================================
#
#   => Image sees 406 / 988 points
#   => Triangulated 412 points
#
# ==============================================================================
# Triangulating image #214 (53)
# ==============================================================================
#
#   => Image sees 685 / 989 points
#   => Triangulated 170 points
#
# ==============================================================================
# Triangulating image #215 (54)
# ==============================================================================
#
#   => Image sees 747 / 985 points
#   => Triangulated 126 points
#
# ==============================================================================
# Triangulating image #209 (55)
# ==============================================================================
#
#   => Image sees 791 / 994 points
#   => Triangulated 98 points
#
# ==============================================================================
# Triangulating image #212 (56)
# ==============================================================================
#
#   => Image sees 792 / 989 points
#   => Triangulated 96 points
#
# ==============================================================================
# Triangulating image #204 (57)
# ==============================================================================
#
#   => Image sees 818 / 989 points
#   => Triangulated 76 points
#
# ==============================================================================
# Triangulating image #207 (58)
# ==============================================================================
#
#   => Image sees 845 / 988 points
#   => Triangulated 62 points
#
# ==============================================================================
# Triangulating image #210 (59)
# ==============================================================================
#
#   => Image sees 841 / 999 points
#   => Triangulated 65 points
#
# ==============================================================================
# Triangulating image #205 (60)
# ==============================================================================
#
#   => Image sees 853 / 993 points
#   => Triangulated 59 points
#
# ==============================================================================
# Triangulating image #202 (61)
# ==============================================================================
#
#   => Image sees 862 / 1003 points
#   => Triangulated 63 points
#
# ==============================================================================
# Triangulating image #206 (62)
# ==============================================================================
#
#   => Image sees 857 / 983 points
#   => Triangulated 46 points
#
# ==============================================================================
# Triangulating image #211 (63)
# ==============================================================================
#
#   => Image sees 869 / 992 points
#   => Triangulated 43 points
#
# ==============================================================================
# Triangulating image #201 (64)
# ==============================================================================
#
#   => Image sees 873 / 989 points
#   => Triangulated 41 points
#
# ==============================================================================
# Triangulating image #203 (65)
# ==============================================================================
#
#   => Image sees 895 / 1017 points
#   => Triangulated 44 points
#
# ==============================================================================
# Triangulating image #213 (66)
# ==============================================================================
#
#   => Image sees 878 / 988 points
#   => Triangulated 45 points
#
# ==============================================================================
# Triangulating image #208 (67)
# ==============================================================================
#
#   => Image sees 862 / 969 points
#   => Triangulated 39 points
#
# ==============================================================================
# Triangulating image #192 (68)
# ==============================================================================
#
#   => Image sees 877 / 983 points
#   => Triangulated 37 points
#
# ==============================================================================
# Triangulating image #185 (69)
# ==============================================================================
#
#   => Image sees 873 / 980 points
#   => Triangulated 44 points
#
# ==============================================================================
# Triangulating image #195 (70)
# ==============================================================================
#
#   => Image sees 902 / 995 points
#   => Triangulated 25 points
#
# ==============================================================================
# Triangulating image #194 (71)
# ==============================================================================
#
#   => Image sees 873 / 968 points
#   => Triangulated 34 points
#
# ==============================================================================
# Triangulating image #180 (72)
# ==============================================================================
#
#   => Image sees 874 / 973 points
#   => Triangulated 37 points
#
# ==============================================================================
# Triangulating image #178 (73)
# ==============================================================================
#
#   => Image sees 878 / 985 points
#   => Triangulated 37 points
#
# ==============================================================================
# Triangulating image #187 (74)
# ==============================================================================
#
#   => Image sees 896 / 994 points
#   => Triangulated 42 points
#
# ==============================================================================
# Triangulating image #193 (75)
# ==============================================================================
#
#   => Image sees 901 / 993 points
#   => Triangulated 35 points
#
# ==============================================================================
# Triangulating image #198 (76)
# ==============================================================================
#
#   => Image sees 360 / 1022 points
#   => Triangulated 434 points
#
# ==============================================================================
# Triangulating image #189 (77)
# ==============================================================================
#
#   => Image sees 646 / 1024 points
#   => Triangulated 187 points
#
# ==============================================================================
# Triangulating image #190 (78)
# ==============================================================================
#
#   => Image sees 716 / 1028 points
#   => Triangulated 147 points
#
# ==============================================================================
# Triangulating image #179 (79)
# ==============================================================================
#
#   => Image sees 751 / 1020 points
#   => Triangulated 111 points
#
# ==============================================================================
# Triangulating image #177 (80)
# ==============================================================================
#
#   => Image sees 762 / 1021 points
#   => Triangulated 112 points
#
# ==============================================================================
# Triangulating image #183 (81)
# ==============================================================================
#
#   => Image sees 803 / 1027 points
#   => Triangulated 88 points
#
# ==============================================================================
# Triangulating image #196 (82)
# ==============================================================================
#
#   => Image sees 810 / 1029 points
#   => Triangulated 90 points
#
# ==============================================================================
# Triangulating image #188 (83)
# ==============================================================================
#
#   => Image sees 835 / 1029 points
#   => Triangulated 68 points
#
# ==============================================================================
# Triangulating image #200 (84)
# ==============================================================================
#
#   => Image sees 835 / 1030 points
#   => Triangulated 75 points
#
# ==============================================================================
# Triangulating image #191 (85)
# ==============================================================================
#
#   => Image sees 851 / 1051 points
#   => Triangulated 76 points
#
# ==============================================================================
# Triangulating image #186 (86)
# ==============================================================================
#
#   => Image sees 854 / 1037 points
#   => Triangulated 67 points
#
# ==============================================================================
# Triangulating image #182 (87)
# ==============================================================================
#
#   => Image sees 857 / 1027 points
#   => Triangulated 59 points
#
# ==============================================================================
# Triangulating image #199 (88)
# ==============================================================================
#
#   => Image sees 856 / 1029 points
#   => Triangulated 60 points
#
# ==============================================================================
# Triangulating image #181 (89)
# ==============================================================================
#
#   => Image sees 853 / 1025 points
#   => Triangulated 65 points
#
# ==============================================================================
# Triangulating image #184 (90)
# ==============================================================================
#
#   => Image sees 862 / 1030 points
#   => Triangulated 65 points
#
# ==============================================================================
# Triangulating image #197 (91)
# ==============================================================================
#
#   => Image sees 853 / 1026 points
#   => Triangulated 69 points
#
# ==============================================================================
# Triangulating image #176 (92)
# ==============================================================================
#
#   => Image sees 852 / 1012 points
#   => Triangulated 50 points
#
# ==============================================================================
# Triangulating image #174 (93)
# ==============================================================================
#
#   => Image sees 864 / 1032 points
#   => Triangulated 56 points
#
# ==============================================================================
# Triangulating image #175 (94)
# ==============================================================================
#
#   => Image sees 881 / 1028 points
#   => Triangulated 52 points
#
# ==============================================================================
# Triangulating image #173 (95)
# ==============================================================================
#
#   => Image sees 885 / 1045 points
#   => Triangulated 55 points
#
# ==============================================================================
# Triangulating image #162 (96)
# ==============================================================================
#
#   => Image sees 877 / 1036 points
#   => Triangulated 60 points
#
# ==============================================================================
# Triangulating image #161 (97)
# ==============================================================================
#
#   => Image sees 849 / 1002 points
#   => Triangulated 53 points
#
# ==============================================================================
# Triangulating image #171 (98)
# ==============================================================================
#
#   => Image sees 876 / 1012 points
#   => Triangulated 50 points
#
# ==============================================================================
# Triangulating image #172 (99)
# ==============================================================================
#
#   => Image sees 878 / 1029 points
#   => Triangulated 60 points
#
# ==============================================================================
# Triangulating image #166 (100)
# ==============================================================================
#
#   => Image sees 487 / 1402 points
#   => Triangulated 530 points
#
# ==============================================================================
# Triangulating image #164 (101)
# ==============================================================================
#
#   => Image sees 710 / 1392 points
#   => Triangulated 321 points
#
# ==============================================================================
# Triangulating image #169 (102)
# ==============================================================================
#
#   => Image sees 796 / 1403 points
#   => Triangulated 276 points
#
# ==============================================================================
# Triangulating image #165 (103)
# ==============================================================================
#
#   => Image sees 820 / 1394 points
#   => Triangulated 244 points
#
# ==============================================================================
# Triangulating image #168 (104)
# ==============================================================================
#
#   => Image sees 862 / 1405 points
#   => Triangulated 222 points
#
# ==============================================================================
# Triangulating image #163 (105)
# ==============================================================================
#
#   => Image sees 866 / 1361 points
#   => Triangulated 196 points
#
# ==============================================================================
# Triangulating image #170 (106)
# ==============================================================================
#
#   => Image sees 893 / 1397 points
#   => Triangulated 195 points
#
# ==============================================================================
# Triangulating image #167 (107)
# ==============================================================================
#
#   => Image sees 924 / 1407 points
#   => Triangulated 179 points
#
# ==============================================================================
# Triangulating image #148 (108)
# ==============================================================================
#
#   => Image sees 933 / 1387 points
#   => Triangulated 171 points
#
# ==============================================================================
# Triangulating image #150 (109)
# ==============================================================================
#
#   => Image sees 945 / 1409 points
#   => Triangulated 175 points
#
# ==============================================================================
# Triangulating image #159 (110)
# ==============================================================================
#
#   => Image sees 914 / 1381 points
#   => Triangulated 184 points
#
# ==============================================================================
# Triangulating image #155 (111)
# ==============================================================================
#
#   => Image sees 929 / 1385 points
#   => Triangulated 176 points
#
# ==============================================================================
# Triangulating image #154 (112)
# ==============================================================================
#
#   => Image sees 944 / 1380 points
#   => Triangulated 158 points
#
# ==============================================================================
# Triangulating image #112 (113)
# ==============================================================================
#
#   => Image sees 939 / 1390 points
#   => Triangulated 183 points
#
# ==============================================================================
# Triangulating image #157 (114)
# ==============================================================================
#
#   => Image sees 964 / 1399 points
#   => Triangulated 163 points
#
# ==============================================================================
# Triangulating image #108 (115)
# ==============================================================================
#
#   => Image sees 948 / 1384 points
#   => Triangulated 166 points
#
# ==============================================================================
# Triangulating image #119 (116)
# ==============================================================================
#
#   => Image sees 944 / 1379 points
#   => Triangulated 151 points
#
# ==============================================================================
# Triangulating image #149 (117)
# ==============================================================================
#
#   => Image sees 974 / 1367 points
#   => Triangulated 137 points
#
# ==============================================================================
# Triangulating image #147 (118)
# ==============================================================================
#
#   => Image sees 979 / 1396 points
#   => Triangulated 159 points
#
# ==============================================================================
# Triangulating image #151 (119)
# ==============================================================================
#
#   => Image sees 954 / 1376 points
#   => Triangulated 157 points
#
# ==============================================================================
# Triangulating image #156 (120)
# ==============================================================================
#
#   => Image sees 976 / 1393 points
#   => Triangulated 153 points
#
# ==============================================================================
# Triangulating image #160 (121)
# ==============================================================================
#
#   => Image sees 964 / 1380 points
#   => Triangulated 152 points
#
# ==============================================================================
# Triangulating image #143 (122)
# ==============================================================================
#
#   => Image sees 985 / 1407 points
#   => Triangulated 161 points
#
# ==============================================================================
# Triangulating image #138 (123)
# ==============================================================================
#
#   => Image sees 1013 / 1387 points
#   => Triangulated 133 points
#
# ==============================================================================
# Triangulating image #137 (124)
# ==============================================================================
#
#   => Image sees 496 / 1238 points
#   => Triangulated 489 points
#
# ==============================================================================
# Triangulating image #145 (125)
# ==============================================================================
#
#   => Image sees 709 / 1257 points
#   => Triangulated 315 points
#
# ==============================================================================
# Triangulating image #139 (126)
# ==============================================================================
#
#   => Image sees 806 / 1261 points
#   => Triangulated 234 points
#
# ==============================================================================
# Triangulating image #140 (127)
# ==============================================================================
#
#   => Image sees 842 / 1240 points
#   => Triangulated 195 points
#
# ==============================================================================
# Triangulating image #146 (128)
# ==============================================================================
#
#   => Image sees 864 / 1255 points
#   => Triangulated 194 points
#
# ==============================================================================
# Triangulating image #142 (129)
# ==============================================================================
#
#   => Image sees 883 / 1254 points
#   => Triangulated 185 points
#
# ==============================================================================
# Triangulating image #152 (130)
# ==============================================================================
#
#   => Image sees 912 / 1260 points
#   => Triangulated 173 points
#
# ==============================================================================
# Triangulating image #136 (131)
# ==============================================================================
#
#   => Image sees 918 / 1271 points
#   => Triangulated 158 points
#
# ==============================================================================
# Triangulating image #141 (132)
# ==============================================================================
#
#   => Image sees 923 / 1242 points
#   => Triangulated 147 points
#
# ==============================================================================
# Triangulating image #134 (133)
# ==============================================================================
#
#   => Image sees 929 / 1258 points
#   => Triangulated 143 points
#
# ==============================================================================
# Triangulating image #135 (134)
# ==============================================================================
#
#   => Image sees 918 / 1228 points
#   => Triangulated 147 points
#
# ==============================================================================
# Triangulating image #133 (135)
# ==============================================================================
#
#   => Image sees 957 / 1257 points
#   => Triangulated 134 points
#
# ==============================================================================
# Triangulating image #131 (136)
# ==============================================================================
#
#   => Image sees 962 / 1260 points
#   => Triangulated 131 points
#
# ==============================================================================
# Triangulating image #132 (137)
# ==============================================================================
#
#   => Image sees 956 / 1256 points
#   => Triangulated 131 points
#
# ==============================================================================
# Triangulating image #128 (138)
# ==============================================================================
#
#   => Image sees 964 / 1257 points
#   => Triangulated 136 points
#
# ==============================================================================
# Triangulating image #127 (139)
# ==============================================================================
#
#   => Image sees 966 / 1251 points
#   => Triangulated 120 points
#
# ==============================================================================
# Triangulating image #121 (140)
# ==============================================================================
#
#   => Image sees 972 / 1265 points
#   => Triangulated 134 points
#
# ==============================================================================
# Triangulating image #58 (141)
# ==============================================================================
#
#   => Image sees 262 / 679 points
#   => Triangulated 293 points
#
# ==============================================================================
# Triangulating image #54 (142)
# ==============================================================================
#
#   => Image sees 441 / 670 points
#   => Triangulated 115 points
#
# ==============================================================================
# Triangulating image #52 (143)
# ==============================================================================
#
#   => Image sees 474 / 660 points
#   => Triangulated 85 points
#
# ==============================================================================
# Triangulating image #53 (144)
# ==============================================================================
#
#   => Image sees 490 / 685 points
#   => Triangulated 83 points
#
# ==============================================================================
# Triangulating image #55 (145)
# ==============================================================================
#
#   => Image sees 486 / 675 points
#   => Triangulated 79 points
#
# ==============================================================================
# Triangulating image #48 (146)
# ==============================================================================
#
#   => Image sees 514 / 687 points
#   => Triangulated 69 points
#
# ==============================================================================
# Triangulating image #50 (147)
# ==============================================================================
#
#   => Image sees 510 / 674 points
#   => Triangulated 68 points
#
# ==============================================================================
# Triangulating image #51 (148)
# ==============================================================================
#
#   => Image sees 518 / 672 points
#   => Triangulated 60 points
#
# ==============================================================================
# Triangulating image #49 (149)
# ==============================================================================
#
#   => Image sees 271 / 492 points
#   => Triangulated 149 points
#
# ==============================================================================
# Triangulating image #46 (150)
# ==============================================================================
#
#   => Image sees 339 / 482 points
#   => Triangulated 78 points
#
# ==============================================================================
# Triangulating image #47 (151)
# ==============================================================================
#
#   => Image sees 367 / 483 points
#   => Triangulated 54 points
#
# ==============================================================================
# Triangulating image #42 (152)
# ==============================================================================
#
#   => Image sees 352 / 474 points
#   => Triangulated 61 points
#
# ==============================================================================
# Triangulating image #45 (153)
# ==============================================================================
#
#   => Image sees 379 / 492 points
#   => Triangulated 50 points
#
# ==============================================================================
# Triangulating image #44 (154)
# ==============================================================================
#
#   => Image sees 380 / 485 points
#   => Triangulated 43 points
#
# ==============================================================================
# Triangulating image #41 (155)
# ==============================================================================
#
#   => Image sees 378 / 497 points
#   => Triangulated 60 points
#
# ==============================================================================
# Triangulating image #43 (156)
# ==============================================================================
#
#   => Image sees 376 / 483 points
#   => Triangulated 50 points
#
# ==============================================================================
# Triangulating image #40 (157)
# ==============================================================================
#
#   => Image sees 387 / 491 points
#   => Triangulated 44 points
#
# ==============================================================================
# Triangulating image #36 (158)
# ==============================================================================
#
#   => Image sees 378 / 482 points
#   => Triangulated 47 points
#
# ==============================================================================
# Triangulating image #39 (159)
# ==============================================================================
#
#   => Image sees 386 / 481 points
#   => Triangulated 41 points
#
# ==============================================================================
# Triangulating image #38 (160)
# ==============================================================================
#
#   => Image sees 387 / 478 points
#   => Triangulated 39 points
#
# ==============================================================================
# Triangulating image #37 (161)
# ==============================================================================
#
#   => Image sees 402 / 491 points
#   => Triangulated 34 points
#
# ==============================================================================
# Triangulating image #31 (162)
# ==============================================================================
#
#   => Image sees 406 / 500 points
#   => Triangulated 35 points
#
# ==============================================================================
# Triangulating image #158 (163)
# ==============================================================================
#
#   => Image sees 617 / 1291 points
#   => Triangulated 449 points
#
# ==============================================================================
# Triangulating image #29 (164)
# ==============================================================================
#
#   => Image sees 397 / 485 points
#   => Triangulated 34 points
#
# ==============================================================================
# Triangulating image #34 (165)
# ==============================================================================
#
#   => Image sees 392 / 478 points
#   => Triangulated 31 points
#
# ==============================================================================
# Triangulating image #33 (166)
# ==============================================================================
#
#   => Image sees 397 / 486 points
#   => Triangulated 35 points
#
# ==============================================================================
# Triangulating image #32 (167)
# ==============================================================================
#
#   => Image sees 385 / 470 points
#   => Triangulated 35 points
#
# ==============================================================================
# Triangulating image #20 (168)
# ==============================================================================
#
#   => Image sees 381 / 469 points
#   => Triangulated 32 points
#
# ==============================================================================
# Triangulating image #72 (169)
# ==============================================================================
#
#   => Image sees 527 / 673 points
#   => Triangulated 61 points
#
# ==============================================================================
# Triangulating image #13 (170)
# ==============================================================================
#
#   => Image sees 573 / 1402 points
#   => Triangulated 486 points
#
# ==============================================================================
# Triangulating image #26 (171)
# ==============================================================================
#
#   => Image sees 675 / 1408 points
#   => Triangulated 408 points
#
# ==============================================================================
# Triangulating image #153 (172)
# ==============================================================================
#
#   => Image sees 751 / 1237 points
#   => Triangulated 301 points
#
# ==============================================================================
# Triangulating image #24 (173)
# ==============================================================================
#
#   => Image sees 719 / 1402 points
#   => Triangulated 367 points
#
# ==============================================================================
# Triangulating image #11 (174)
# ==============================================================================
#
#   => Image sees 762 / 1423 points
#   => Triangulated 346 points
#
# ==============================================================================
# Triangulating image #8 (175)
# ==============================================================================
#
#   => Image sees 763 / 1413 points
#   => Triangulated 346 points
#
# ==============================================================================
# Triangulating image #4 (176)
# ==============================================================================
#
#   => Image sees 767 / 1399 points
#   => Triangulated 333 points
#
# ==============================================================================
# Triangulating image #66 (177)
# ==============================================================================
#
#   => Image sees 540 / 694 points
#   => Triangulated 68 points
#
# ==============================================================================
# Triangulating image #7 (178)
# ==============================================================================
#
#   => Image sees 809 / 1398 points
#   => Triangulated 307 points
#
# ==============================================================================
# Triangulating image #6 (179)
# ==============================================================================
#
#   => Image sees 809 / 1405 points
#   => Triangulated 323 points
#
# ==============================================================================
# Triangulating image #547 (180)
# ==============================================================================
#
#   => Image sees 826 / 962 points
#   => Triangulated 39 points
#
# ==============================================================================
# Triangulating image #35 (181)
# ==============================================================================
#
#   => Image sees 814 / 1363 points
#   => Triangulated 284 points
#
# ==============================================================================
# Triangulating image #5 (182)
# ==============================================================================
#
#   => Image sees 842 / 1434 points
#   => Triangulated 313 points
#
# ==============================================================================
# Triangulating image #546 (183)
# ==============================================================================
#
#   => Image sees 815 / 949 points
#   => Triangulated 32 points
#
# ==============================================================================
# Triangulating image #2 (184)
# ==============================================================================
#
#   => Image sees 848 / 1398 points
#   => Triangulated 288 points
#
# ==============================================================================
# Triangulating image #129 (185)
# ==============================================================================
#
#   => Image sees 967 / 1238 points
#   => Triangulated 131 points
#
# ==============================================================================
# Triangulating image #14 (186)
# ==============================================================================
#
#   => Image sees 856 / 1422 points
#   => Triangulated 308 points
#
# ==============================================================================
# Triangulating image #60 (187)
# ==============================================================================
#
#   => Image sees 526 / 654 points
#   => Triangulated 45 points
#
# ...
# Triangulating image #509 (533)
# ==============================================================================
#
#   => Image sees 687 / 1034 points
#   => Triangulated 237 points
#
# ==============================================================================
# Triangulating image #511 (534)
# ==============================================================================
#
#   => Image sees 697 / 1031 points
#   => Triangulated 229 points
#
# ==============================================================================
# Triangulating image #530 (535)
# ==============================================================================
#
#   => Image sees 669 / 1021 points
#   => Triangulated 252 points
#
# ==============================================================================
# Triangulating image #524 (536)
# ==============================================================================
#
#   => Image sees 664 / 1017 points
#   => Triangulated 251 points
#
# ==============================================================================
# Triangulating image #534 (537)
# ==============================================================================
#
#   => Image sees 685 / 1026 points
#   => Triangulated 242 points
#
# ==============================================================================
# Triangulating image #523 (538)
# ==============================================================================
#
#   => Image sees 676 / 1016 points
#   => Triangulated 242 points
#
# ==============================================================================
# Triangulating image #525 (539)
# ==============================================================================
#
#   => Image sees 678 / 1017 points
#   => Triangulated 233 points
#
# ==============================================================================
# Triangulating image #521 (540)
# ==============================================================================
#
#   => Image sees 673 / 1016 points
#   => Triangulated 236 points
#
# ==============================================================================
# Triangulating image #522 (541)
# ==============================================================================
#
#   => Image sees 687 / 1041 points
#   => Triangulated 242 points
#
# ==============================================================================
# Triangulating image #535 (542)
# ==============================================================================
#
#   => Image sees 688 / 1041 points
#   => Triangulated 246 points
#
# ==============================================================================
# Triangulating image #537 (543)
# ==============================================================================
#
#   => Image sees 812 / 942 points
#   => Triangulated 37 points
#
# ==============================================================================
# Triangulating image #532 (544)
# ==============================================================================
#
#   => Image sees 799 / 922 points
#   => Triangulated 41 points
#
# ==============================================================================
# Triangulating image #526 (545)
# ==============================================================================
#
#   => Image sees 813 / 941 points
#   => Triangulated 41 points
#
# ==============================================================================
# Triangulating image #527 (546)
# ==============================================================================
#
#   => Image sees 814 / 931 points
#   => Triangulated 38 points
#
# ==============================================================================
# Triangulating image #531 (547)
# ==============================================================================
#
#   => Image sees 814 / 944 points
#   => Triangulated 44 points
#
# ==============================================================================
# Triangulating image #528 (548)
# ==============================================================================
#
#   => Image sees 803 / 944 points
#   => Triangulated 55 points
#
# ==============================================================================
# Triangulating image #529 (549)
# ==============================================================================
#
#   => Image sees 813 / 937 points
#   => Triangulated 36 points
#
# ==============================================================================
# Triangulating image #536 (550)
# ==============================================================================
#
#   => Image sees 805 / 931 points
#   => Triangulated 44 points
#
# ==============================================================================
# Triangulating image #533 (551)
# ==============================================================================
#
#   => Image sees 839 / 970 points
#   => Triangulated 51 points
#
# ==============================================================================
# Retriangulation
# ==============================================================================
#
#   => Completed observations: 1244
#   => Merged observations: 16614
#
# ==============================================================================
# Bundle adjustment
# ==============================================================================
#
# iter      cost      cost_change  |gradient|   |step|    tr_ratio  tr_radius  ls_iter  iter_time  total_time
#    0  7.325681e+07    0.00e+00    2.53e+06   0.00e+00   0.00e+00  1.00e+04        0    9.42e-02    5.48e-01
#    1  4.421562e+07    2.90e+07    3.05e+06   5.04e+01   9.89e-01  3.00e+04        0    1.26e-01    6.74e-01
#    2  4.391704e+07    2.99e+05    5.39e+05   1.02e+02   9.07e-01  6.52e+04        0    1.13e-01    7.87e-01
#    3  4.389430e+07    2.27e+04    4.44e+05   1.71e+02   7.20e-01  7.12e+04        0    1.12e-01    8.99e-01
#    4  4.390436e+07   -1.01e+04    4.44e+05   7.67e+02  -1.11e+00  3.56e+04        0    3.66e-02    9.36e-01
#    5  4.390437e+07   -1.01e+04    4.44e+05   7.67e+02  -1.11e+00  8.91e+03        0    2.81e-02    9.64e-01
#    6  4.390437e+07   -1.01e+04    4.44e+05   7.67e+02  -1.11e+00  1.11e+03        0    2.86e-02    9.92e-01
#    7  4.390437e+07   -1.01e+04    4.44e+05   7.67e+02  -1.11e+00  6.96e+01        0    2.86e-02    1.02e+00
#    8  4.390444e+07   -1.01e+04    4.44e+05   7.61e+02  -1.12e+00  2.17e+00        0    2.84e-02    1.05e+00
#    9  4.390581e+07   -1.15e+04    4.44e+05   6.19e+02  -1.34e+00  3.40e-02        0    2.86e-02    1.08e+00
#   10  4.389310e+07    1.20e+03    4.30e+05   4.86e+01   1.18e+00  1.02e-01        0    1.02e-01    1.18e+00
#   11  4.389008e+07    3.02e+03    3.91e+05   7.65e+01   1.32e+00  3.06e-01        0    1.11e-01    1.29e+00
#   12  4.388694e+07    3.14e+03    3.00e+05   6.33e+02   1.14e+00  9.17e-01        0    1.12e-01    1.40e+00
#   13  4.388623e+07    7.10e+02    1.57e+05   2.94e+03   5.29e-01  9.17e-01        0    1.12e-01    1.51e+00
#   14  4.388586e+07    3.75e+02    8.23e+04   4.72e+03   4.80e-01  9.17e-01        0    1.12e-01    1.63e+00
#   15  4.388559e+07    2.75e+02    4.30e+04   1.36e+03   1.19e+00  2.75e+00        0    1.13e-01    1.74e+00
#   16  4.389015e+07   -4.56e+03    4.30e+04   4.79e+03  -1.76e+01  1.38e+00        0    3.65e-02    1.78e+00
#   17  4.388556e+07    2.19e+01    1.81e+04   3.86e+03   9.46e-02  8.98e-01        0    1.04e-01    1.88e+00
#   18  4.388535e+07    2.10e+02    9.51e+03   2.14e+02   9.39e-01  2.69e+00        0    1.12e-01    1.99e+00
#   19  4.388530e+07    4.84e+01    2.53e+03   1.71e+02   9.81e-01  8.08e+00        0    1.13e-01    2.11e+00
#   20  4.388529e+07    1.25e+01    1.03e+03   5.52e+01   1.02e+00  2.42e+01        0    1.13e-01    2.22e+00
#   21  4.388527e+07    1.72e+01    1.65e+03   5.07e+00   1.03e+00  7.27e+01        0    1.13e-01    2.33e+00
#   22  4.388525e+07    2.48e+01    1.51e+03   1.32e-01   1.04e+00  2.18e+02        0    1.13e-01    2.44e+00
#   23  4.388522e+07    2.85e+01    2.05e+03   9.08e-02   1.06e+00  6.54e+02        0    1.13e-01    2.56e+00
#   24  4.388520e+07    2.03e+01    2.19e+03   1.03e-01   1.15e+00  1.96e+03        0    1.13e-01    2.67e+00
#   25  4.388519e+07    9.25e+00    1.36e+03   8.80e-02   1.30e+00  5.89e+03        0    1.13e-01    2.78e+00
#   26  4.388519e+07    3.73e+00    6.26e+02   6.97e-02   1.39e+00  1.77e+04        0    1.13e-01    2.90e+00
#   27  4.388519e+07    2.19e+00    5.00e+02   5.17e-02   1.30e+00  5.30e+04        0    1.12e-01    3.01e+00
#   28  4.388518e+07    2.64e+00    2.01e+03   4.06e-02   1.12e+00  1.59e+05        0    1.13e-01    3.12e+00
#   29  4.388518e+07    3.67e+00    5.18e+03   3.48e-02   1.05e+00  4.77e+05        0    1.13e-01    3.23e+00
#   30  4.388518e+07    3.23e+00    1.60e+03   2.99e-02   1.03e+00  1.43e+06        0    1.13e-01    3.35e+00
#   31  4.388518e+07    1.47e+00    1.65e+04   2.27e-02   1.05e+00  4.29e+06        0    1.13e-01    3.46e+00
#   32  4.388517e+07    5.13e-01    6.06e+04   1.78e-02   1.11e+00  1.29e+07        0    1.13e-01    3.57e+00
#   33  4.388517e+07    2.20e-01    4.20e+05   1.45e-02   1.18e+00  3.86e+07        0    1.13e-01    3.69e+00
#   34  4.388517e+07    9.46e-02    2.25e+06   1.19e-02   1.29e+00  1.16e+08        0    1.13e-01    3.80e+00
#   35  4.388517e+07    4.34e-02    1.49e+07   9.75e-03   1.17e+00  3.48e+08        0    1.13e-01    3.91e+00
#   36  4.388517e+07    5.18e-03    7.96e+07   8.00e-03   1.91e-01  2.81e+08        0    1.13e-01    4.02e+00
#   37  4.388517e+07    4.71e-02    2.22e+07   6.58e-03   1.13e+00  8.44e+08        0    1.13e-01    4.14e+00
#   38  4.388517e+07    1.22e-02    3.30e+07   5.40e-03   1.43e+00  2.53e+09        0    1.12e-01    4.25e+00
#   39  4.388517e+07   -2.80e-04    3.30e+07   4.45e-03  -4.70e-02  1.27e+09        0    3.64e-02    4.29e+00
#   40  4.388517e+07    8.37e-03    3.12e+07   4.45e-03   1.52e+00  3.80e+09        0    1.05e-01    4.39e+00
#   41  4.388517e+07    3.63e-03    2.42e+08   3.65e-03   1.01e+00  1.14e+10        0    1.13e-01    4.50e+00
#   42  4.388517e+07   -7.03e-04    2.42e+08   3.01e-03  -1.72e-01  5.70e+09        0    3.77e-02    4.54e+00
#   43  4.388517e+07    5.05e-03    1.63e+08   3.01e-03   1.26e+00  1.71e+10        0    1.02e-01    4.64e+00
#   44  4.388517e+07    1.25e-03    8.46e+08   2.47e-03   7.03e-01  1.83e+10        0    1.12e-01    4.75e+00
#   45  4.388517e+07    2.89e-03    3.65e+08   2.03e-03   1.22e+00  5.50e+10        0    1.11e-01    4.87e+00
#   46  4.388517e+07    9.52e-04    1.02e+09   1.67e-03   1.28e+00  1.65e+11        0    1.11e-01    4.98e+00
#   47  4.388517e+07   -1.11e-03    1.02e+09   1.38e-03  -1.72e+00  8.25e+10        0    3.62e-02    5.01e+00
#   48  4.388517e+07    8.60e-04    9.54e+08   1.38e-03   1.35e+00  2.47e+11        0    1.04e-01    5.12e+00
#   49  4.388517e+07    9.19e-05    7.38e+09   1.13e-03   2.62e-01  2.23e+11        0    1.12e-01    5.23e+00
#   50  4.388517e+07    7.60e-04    2.15e+09   9.31e-04   1.18e+00  6.70e+11        0    1.11e-01    5.34e+00
#
#
# Bundle adjustment report
# ------------------------
#     Residuals : 920686
#    Parameters : 138711
#    Iterations : 51
#          Time : 5.36058 [s]
#  Initial cost : 8.92007 [px]
#    Final cost : 6.90404 [px]
#   Termination : No convergence
#
#   => Completed observations: 1116
#   => Merged observations: 11338
#   => Filtered observations: 273942
#   => Changed observations: 0.622136
#
# ==============================================================================
# Bundle adjustment
# ==============================================================================
#
# iter      cost      cost_change  |gradient|   |step|    tr_ratio  tr_radius  ls_iter  iter_time  total_time
#    0  1.048135e+05    0.00e+00    7.91e+04   0.00e+00   0.00e+00  1.00e+04        0    8.50e-03    4.17e-02
#    1  9.546298e+04    9.35e+03    5.10e+02   3.93e-01   1.00e+00  3.00e+04        0    1.33e-02    5.50e-02
#    2  9.546247e+04    5.09e-01    1.87e+01   9.03e-03   1.00e+00  9.00e+04        0    1.31e-02    6.81e-02
#    3  9.546247e+04    3.46e-05    2.02e-01   1.87e-04   1.00e+00  2.70e+05        0    1.34e-02    8.15e-02
#
#
# Bundle adjustment report
# ------------------------
#     Residuals : 123076
#    Parameters : 13665
#    Iterations : 4
#          Time : 0.083761 [s]
#  Initial cost : 0.92283 [px]
#    Final cost : 0.880703 [px]
#   Termination : Convergence
#
#   => Completed observations: 73262
#   => Merged observations: 1832
#   => Filtered observations: 546
#   => Changed observations: 1.229159
#
# ==============================================================================
# Bundle adjustment
# ==============================================================================
#
# iter      cost      cost_change  |gradient|   |step|    tr_ratio  tr_radius  ls_iter  iter_time  total_time
#    0  2.395496e+05    0.00e+00    1.46e+05   0.00e+00   0.00e+00  1.00e+04        0    1.63e-02    1.07e-01
#    1  1.981998e+05    4.13e+04    1.81e+02   3.18e-01   1.00e+00  3.00e+04        0    2.79e-02    1.35e-01
#    2  1.981984e+05    1.36e+00    1.28e+02   3.73e-02   9.99e-01  9.00e+04        0    2.68e-02    1.62e-01
#    3  1.981984e+05    7.42e-03    1.79e+01   2.17e-03   1.03e+00  2.70e+05        0    2.74e-02    1.89e-01
#    4  1.981984e+05    1.25e-04    7.52e+00   2.40e-04   1.02e+00  8.10e+05        0    2.70e-02    2.16e-01
#    5  1.981984e+05    1.96e-06    1.18e+00   2.29e-05   1.02e+00  2.43e+06        0    2.69e-02    2.43e-01
#    6  1.981984e+05    1.01e-08    7.10e-02   1.92e-06   1.05e+00  7.29e+06        0    2.69e-02    2.70e-01
#
#
# Bundle adjustment report
# ------------------------
#     Residuals : 265324
#    Parameters : 13245
#    Iterations : 7
#          Time : 0.27505 [s]
#  Initial cost : 0.950188 [px]
#    Final cost : 0.864295 [px]
#   Termination : Convergence
#
#   => Completed observations: 918
#   => Merged observations: 375
#   => Filtered observations: 2045
#   => Changed observations: 0.025162
#
# ==============================================================================
# Bundle adjustment
# ==============================================================================
#
# iter      cost      cost_change  |gradient|   |step|    tr_ratio  tr_radius  ls_iter  iter_time  total_time
#    0  1.774992e+05    0.00e+00    3.50e+04   0.00e+00   0.00e+00  1.00e+04        0    1.62e-02    1.00e-01
#    1  1.758576e+05    1.64e+03    4.47e+02   8.89e-02   1.00e+00  3.00e+04        0    3.17e-02    1.32e-01
#    2  1.758576e+05    1.50e-02    8.00e+00   7.88e-04   1.00e+00  9.00e+04        0    2.80e-02    1.60e-01
#    3  1.758576e+05    1.36e-05    9.34e-01   4.83e-05   1.01e+00  2.70e+05        0    2.60e-02    1.86e-01
#
#
# Bundle adjustment report
# ------------------------
#     Residuals : 250884
#    Parameters : 12198
#    Iterations : 4
#          Time : 0.191136 [s]
#  Initial cost : 0.841127 [px]
#    Final cost : 0.837229 [px]
#   Termination : Convergence
#
#   => Completed observations: 1859
#   => Merged observations: 31
#   => Filtered observations: 279
#   => Changed observations: 0.017291
#
# ==============================================================================
# Bundle adjustment
# ==============================================================================
#
# iter      cost      cost_change  |gradient|   |step|    tr_ratio  tr_radius  ls_iter  iter_time  total_time
#    0  1.772227e+05    0.00e+00    4.47e+04   0.00e+00   0.00e+00  1.00e+04        0    1.50e-02    9.84e-02
#    1  1.756644e+05    1.56e+03    1.43e+02   5.43e-02   1.00e+00  3.00e+04        0    2.59e-02    1.24e-01
#    2  1.756644e+05    1.49e-02    1.24e+01   1.05e-03   1.00e+00  9.00e+04        0    2.57e-02    1.50e-01
#    3  1.756644e+05    4.12e-06    5.36e-01   2.67e-05   1.02e+00  2.70e+05        0    2.59e-02    1.76e-01
#
#
# Bundle adjustment report
# ------------------------
#     Residuals : 252606
#    Parameters : 12072
#    Iterations : 4
#          Time : 0.181522 [s]
#  Initial cost : 0.837602 [px]
#    Final cost : 0.833912 [px]
#   Termination : Convergence
#
#   => Completed observations: 297
#   => Merged observations: 0
#   => Filtered observations: 157
#   => Changed observations: 0.003595
#
# ==============================================================================
# Extracting colors
# ==============================================================================
# 0

# %%
mapper_cmd = ("colmap" + " mapper \
        --database_path " + rootdir + "/database.db \
        --image_path "  +  imagedir + \
        " --output_path "  + rootdir + "/sparse \
        --Mapper.ba_global_function_tolerance=0.000001")
os.system(mapper_cmd)

# %%
from database import COLMAPDatabase, blob_to_array
import numpy as np

# Specify the path to your COLMAP database
database_path = f'{rootdir}/database.db'

# Connect to the database
db = COLMAPDatabase.connect(database_path)

# Execute a query to fetch all cameras
images = db.execute("SELECT * FROM images").fetchall()

images = db.execute("SELECT image_id, name, camera_id, prior_qw, prior_qx FROM images").fetchall()

for image in images:
    image_id, name, camera_id, qw, qx = image
    # print(f"Image ID: {image_id}, Name: {name}, Camera ID: {camera_id}, qw:{qw}, qx:{qx}")

# %%
cursor = db.execute('SELECT * FROM images LIMIT 0')
column_names = [desc[0] for desc in cursor.description]
print("Column names:", column_names)
# Out:
# Column names: ['image_id', 'name', 'camera_id', 'prior_qw', 'prior_qx', 'prior_qy', 'prior_qz', 'prior_tx', 'prior_ty', 'prior_tz']

# %%
db.commit()
db.close()

# %%
def read_extrinsics_text(path):
    """
    Taken from https://github.com/colmap/colmap/blob/dev/scripts/python/read_write_model.py
    """
    images = {}
    with open(path, "r") as fid:
        while True:
            line = fid.readline()
            if not line:
                break
            line = line.strip()
            if len(line) > 0 and line[0] != "#":
                elems = line.split()
                image_id = int(elems[0])
                qvec = np.array(tuple(map(float, elems[1:5])))
                tvec = np.array(tuple(map(float, elems[5:8])))
                camera_id = int(elems[8])
                image_name = elems[9]
                elems = fid.readline().split()
                xys = np.column_stack([tuple(map(float, elems[0::3])),
                                       tuple(map(float, elems[1::3]))])
                point3D_ids = np.array(tuple(map(int, elems[2::3])))
                images[image_id] = Image(
                    id=image_id, qvec=qvec, tvec=tvec,
                    camera_id=camera_id, name=image_name,
                    xys=xys, point3D_ids=point3D_ids)
    return images

# %%
read_extrinsics_text(f"{rootdir}/output/images.bin")
# Out:
# ---------------------------------------------------------------------------
# UnicodeDecodeError                        Traceback (most recent call last)
# /tmp/ipykernel_2866928/1993731680.py in <module>
# ----> 1 read_extrinsics_text(f"{rootdir}/output/images.bin")
#
# /tmp/ipykernel_2866928/634703155.py in read_extrinsics_text(path)
#       6     with open(path, "r") as fid:
#       7         while True:
# ----> 8             line = fid.readline()
#       9             if not line:
#      10                 break
#
# ~/anaconda3/envs/stylegan_stit/lib/python3.7/codecs.py in decode(self, input, final)
#     320         # decode input (taking the buffer into account)
#     321         data = self.buffer + input
# --> 322         (result, consumed) = self._buffer_decode(data, self.errors, final)
#     323         # keep undecoded input until the next call
#     324         self.buffer = data[consumed:]
#
# UnicodeDecodeError: 'utf-8' codec can't decode byte 0xaf in position 12: invalid start byte
